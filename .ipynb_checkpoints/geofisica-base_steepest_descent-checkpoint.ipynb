# %% [markdown]
# # Steepest descent aplicado à função geofísica

# %% [markdown]
# Algoritmo de Steepest Descent aplicado a um problema geofísico para estimar o raio e a coordenada z da base de um prisma de base poligonal próximo de um cilindro.

# %% [markdown]
# # Importando pacotes

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
from visual import histeq
from fatiando import utils
from fatiando.mesher import PolygonalPrism
from IPython.display import Image as img
from fatiando.gravmag import polyprism
from copy import deepcopy
from fatiando.vis import myv
from fatiando.gridder import regular
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# # Funções para o prisma de base polygonal do fatiando

# %%
def pol2cart(l, M, L):
    '''
    This function transforms polar coordinates of the prisms
    into Cartesian coordinates and returns a list of polygonal
    prisms of the Fatiando a Terra.

    input

    l: list - each element is a list of [r, x0, y0, z1, z2, 'magnetization'],
              whrere r is an array with the radial distances of the vertices,
              x0 and y0 are the origin cartesian coordinates of each prism,
              z1 and z2 are the top and bottom of each prism and
              magnetization is physical property
    M: int - number of vertices per prism
    L: int - number of prisms

    output

    mk: list - list of objects of the class
    fatiando.mesher.PolygonalPrism
    '''

    lk = []
    r = np.zeros(M)  # it contains radial distances of the vertices in polar coordinates
    verts = [] # it contains radial distances of the vertices in Cartesian coordinates

    assert len(l) == L, 'The size of m and the number of prisms must be equal'

    for lv in l:
        assert len(lv[0]) == M, 'All prisms must have M vertices'

    ang = 2*np.pi/M # angle between two vertices

    for lv in l:
        r = lv[0]
        verts=[]
        for i in range(M):
            verts.append([r[i]*np.cos(i*ang) + lv[1], r[i]*np.sin(i*ang) + lv[2]])
        lk.append(PolygonalPrism(verts, lv[3], lv[4], lv[5]))

    return lk

def param2polyprism(m, M, L, z0, dz, props):
    '''
    Returns a lis of objects of the class
    fatiando.mesher.PolygonalPrism

    input

    m: 1D array - parameter vector
    M: int - number of vertices
    L: int - number of prisms
    z0: float - top of the model
    dz: float - thickness of each prism
    props: dictionary - physical property

    output

    mv: list - list of fatiando.mesher.PolygonalPrism
    '''
    P = L*(M + 2)
    assert m.size == P, 'The size of m must be equal to L*(M + 2)'
    for i in range(P):
        assert m[i:i+M].all >= 0., 'The radial distances must be positives'

    r = np.zeros(M) # vector for radial distances
    mv = [] # list of prisms

    k = 0.
    for i in range(0, P, M + 2):
        r = m[i:M+i]
        mv.append([r, m[i+M], m[i+M+1], z0 + dz*k, z0 + dz*(k + 1.), props])
        k = k + 1.

    mv = pol2cart(mv, M, L)

    return mv

# %% [markdown]
# # Modelagem direta

# %%
M = 10 # number of vertices per prism
L = 1 # number of prisms
P = L*(M+2) # number of parameters

z0 = 100.    # depth of the top the shallowest prism
dz_true = 500.    # thickness of each prism

inc = -60.  # inclination
dec = 50.   # declination
intensity = 0.035 # intensity

props={'magnetization': utils.ang2vec(intensity, inc, dec)} # physical property: magnetization

r_true = 500.

r = np.zeros(M) + r_true # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

l = [[r, x0, y0, z0, z0 + dz_true, props]]   # list of parameters of the prisms

# criando os prismas do fatiando
prisms = pol2cart(l, M, L)

# %%
img(filename='bolacha.png')

# %% [markdown]
# # Pontos de observação

# %%
area = [-2000, 2000, -2000, 2000] #x minimum, x maximum, y minimum and y maximum
shape = (50,50) #number of data along the y and x directions
N = shape[0]*shape[1] #total number of data

#coordinates x and y of the data
xp, yp = regular(area, shape)

zp = np.zeros(N) - 100.

# %% [markdown]
# # Dados observados

# %%
data = polyprism.tf(xp, yp, zp, prisms, inc, dec) # predict data
amp_noise = 0.01*np.max(data)
data_noise = data + np.random.normal(loc=0., scale=amp_noise, size=shape[0]*shape[1]) # noise corrupted data

# %% [markdown]
# # Plot função desajuste

# %%
r_plot = np.linspace(100., 1000., 20)
dz_plot = np.linspace(10., 1000., 20)
r_plot,z0_plot = np.meshgrid(r_plot, dz_plot)
r_plot = r_plot.ravel()
dz_plot = z0_plot.ravel()
phi_plot = np.zeros_like(r_plot)

for i, (r, dz) in enumerate(zip(r_plot,dz_plot)):
    m = np.zeros(M) + r
    m = np.hstack((m,np.zeros(2)))
    l = param2polyprism(m, M, L, z0, z0 + dz, props)
    d_pred = polyprism.tf(xp, yp, zp, l, inc, dec)
    phi_plot[i] = np.sum((data - d_pred)**2)

r_plot = r_plot.reshape((20,20))
dz_plot = dz_plot.reshape((20,20))
phi_plot = phi_plot.reshape((20,20))

# equalizando as cores
phi_eq = histeq(phi_plot)
phi_eq = np.reshape(phi_eq,(20,20))
phi_eq = phi_eq

# %%
plt.figure(figsize=(5,5))
plt.plot(r_true, dz_true, 'og')
plt.title('Funcao objetivo', fontsize=18)
plt.contourf(r_plot, dz_plot, phi_eq, 50, cmap='jet')
plt.xlabel('$r$ (m)', fontsize=18)
plt.ylabel('$dz$ (m)', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.show()

# %% [markdown]
# # Funções

# %%
def derivative_tf_z(xp, yp, zp, prism, M, deltaz, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of one fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    delta: float - increment in x coordinate in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - deltaa
    prism_plus[0].z2 += deltaz
    prism_minus[0].z2 -= deltaz

    df = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df -= polyprism.tf(xp, yp, zp, prism_minus, inc, dec)
    df /= (2.*deltaz)

    return df

def derivative_tf_radiall(xp, yp, zp, prism, M, deltar, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of a fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in radial distance in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'
    
    ang = 2.*np.pi/M # angle between two vertices
    
    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - delta

    for i in range(M):
        deltax = deltar*np.cos(i*ang)
        deltay = deltar*np.sin(i*ang)
        prism_plus[0].x[i] += deltax
        prism_plus[0].y[i] += deltay
        prism_minus[0].x[i] -= deltax
        prism_minus[0].y[i] -= deltay

    df = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df -= polyprism.tf(xp, yp, zp, prism_minus, inc, dec)
    df /= (2.*deltar)

    return df

# calculando jacobiana de phi
def jacobi_geo(xp, yp, zp, prism, M, deltar, deltaz, inc, dec):
    '''
    Returns the sensitivity matrix for polygonal prisms using finite
    differences.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in meters for radial distance
    deltaz: float - increment in meters for depth
    inc: float - inclination of the local-geomagnetic field
    dec: declination of the local-geomagnetic field

    output

    G: 2D array - sensitivity matrix
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    G = np.zeros((xp.size, 2))

    G[:, 0] = derivative_tf_radiall(xp, yp, zp, prism[0], M, deltar, inc, dec)
    G[:, 1] = derivative_tf_z(xp, yp, zp, prism[0], M, deltaz, inc, dec)

    return G

# %% [markdown]
# # Modelo interpretativo

# %%
# chute inicial
p01 = 100.
p02 = 400.

# incremento para as derivadas
deltar = 0.01*p01
deltaz = 0.01*p02

r = np.zeros(M) + p01 # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

l = [[r, x0, y0, z0, z0 + p02, props]]

prism0 = pol2cart(l, M, L)

d0 = polyprism.tf(xp, yp, zp, prism0, inc, dec)

# vetor do chute inicial
p0 = np.array([p01,p02]) 

# parâmetros para o critério de Armijo
alfa = 0.0001
beta = 0.4

# critério de parada
epsilon = 0.00000001

# calculando o valor da função e do resíduo em p0
res0 = data_noise - d0
phi0 = np.sum(res0*res0)

# listas para armazenar as estimativas
p1_list = [p01]
p2_list = [p02]
phi_list = [phi0]

# iterações do algoritmo
itmax = 1000

# %% [markdown]
# # Algoritmo Steepest Descent

# %%
for i in range(itmax):
    # calculando a Jacobiana e o gradiente
    G = jacobi_geo(xp, yp, zp, prism0, M, deltar, deltaz, inc, dec)
    grad = -2.*np.dot(G.T, res0) + mi*p0
    #print grad
    # calculando p e atualizando para a próxima iteração
    p = p0 - lamb*grad
    #print p, p0
    l = [[np.zeros(M) + p[0], x0, y0, z0, z0 + p[1], props]]
    prism = pol2cart(l, M, L)
    d = polyprism.tf(xp, yp, zp, prism, inc, dec)
    res = data_noise - d
    phi = np.sum(res*res) + mi*np.dot(p0, p0)
    
    # printa os valores
    print 'itreação: %3d   r: %.2f   dz: %.2f   misfit: %.2e' % (i, p0[0], p0[1], phi0)
    
    # armazenando a última estimativa
    phi_list.append(phi)
    p1_list.append(p[0])
    p2_list.append(p[1])
    
    if (abs(phi - phi0)/phi0 <= epsilon):
        break
    else:
        # atualizando parâmetros
        p0 = p
        d0 = d
        res0 = res
        phi0 = phi
        prim0 = prism
# Out:
# itreação:   0   r: 109.40   z0: 400.60   misfit: 4.52e+03
# itreação:   1   r: 119.45   z0: 401.32   misfit: 4.42e+03
# itreação:   2   r: 130.17   z0: 402.15   misfit: 4.30e+03
# itreação:   3   r: 141.52   z0: 403.11   misfit: 4.17e+03
# itreação:   4   r: 153.49   z0: 404.22   misfit: 4.02e+03
# itreação:   5   r: 166.03   z0: 405.49   misfit: 3.86e+03
# itreação:   6   r: 179.09   z0: 406.93   misfit: 3.68e+03
# itreação:   7   r: 192.61   z0: 408.53   misfit: 3.49e+03
# itreação:   8   r: 206.53   z0: 410.31   misfit: 3.29e+03
# itreação:   9   r: 220.76   z0: 412.26   misfit: 3.08e+03
# itreação:  10   r: 235.23   z0: 414.38   misfit: 2.87e+03
# itreação:  11   r: 249.84   z0: 416.64   misfit: 2.65e+03
# itreação:  12   r: 264.50   z0: 419.05   misfit: 2.43e+03
# itreação:  13   r: 279.13   z0: 421.57   misfit: 2.21e+03
# itreação:  14   r: 293.62   z0: 424.19   misfit: 1.99e+03
# itreação:  15   r: 307.89   z0: 426.88   misfit: 1.79e+03
# itreação:  16   r: 321.84   z0: 429.61   misfit: 1.59e+03
# itreação:  17   r: 335.40   z0: 432.36   misfit: 1.40e+03
# itreação:  18   r: 348.50   z0: 435.10   misfit: 1.22e+03
# itreação:  19   r: 361.06   z0: 437.80   misfit: 1.06e+03
# itreação:  20   r: 373.03   z0: 440.44   misfit: 9.14e+02
# itreação:  21   r: 384.38   z0: 443.00   misfit: 7.82e+02
# itreação:  22   r: 395.06   z0: 445.47   misfit: 6.66e+02
# itreação:  23   r: 405.08   z0: 447.83   misfit: 5.63e+02
# itreação:  24   r: 414.41   z0: 450.06   misfit: 4.75e+02
# itreação:  25   r: 423.07   z0: 452.17   misfit: 3.98e+02
# itreação:  26   r: 431.06   z0: 454.15   misfit: 3.33e+02
# itreação:  27   r: 438.41   z0: 456.00   misfit: 2.78e+02
# itreação:  28   r: 445.15   z0: 457.72   misfit: 2.32e+02
# itreação:  29   r: 451.30   z0: 459.30   misfit: 1.93e+02
# itreação:  30   r: 456.90   z0: 460.77   misfit: 1.61e+02
# itreação:  31   r: 461.98   z0: 462.12   misfit: 1.35e+02
# itreação:  32   r: 466.59   z0: 463.35   misfit: 1.13e+02
# itreação:  33   r: 470.75   z0: 464.49   misfit: 9.54e+01
# itreação:  34   r: 474.51   z0: 465.52   misfit: 8.09e+01
# itreação:  35   r: 477.89   z0: 466.46   misfit: 6.92e+01
# itreação:  36   r: 480.92   z0: 467.32   misfit: 5.98e+01
# itreação:  37   r: 483.65   z0: 468.10   misfit: 5.21e+01
# itreação:  38   r: 486.10   z0: 468.81   misfit: 4.60e+01
# itreação:  39   r: 488.29   z0: 469.45   misfit: 4.10e+01
# itreação:  40   r: 490.25   z0: 470.04   misfit: 3.71e+01
# itreação:  41   r: 492.00   z0: 470.57   misfit: 3.39e+01
# itreação:  42   r: 493.57   z0: 471.05   misfit: 3.13e+01
# itreação:  43   r: 494.97   z0: 471.49   misfit: 2.93e+01
# itreação:  44   r: 496.21   z0: 471.89   misfit: 2.77e+01
# itreação:  45   r: 497.32   z0: 472.26   misfit: 2.64e+01
# itreação:  46   r: 498.31   z0: 472.59   misfit: 2.54e+01
# itreação:  47   r: 499.19   z0: 472.90   misfit: 2.46e+01
# itreação:  48   r: 499.97   z0: 473.18   misfit: 2.39e+01
# itreação:  49   r: 500.67   z0: 473.43   misfit: 2.34e+01
# itreação:  50   r: 501.29   z0: 473.67   misfit: 2.30e+01
# itreação:  51   r: 501.83   z0: 473.88   misfit: 2.26e+01
# itreação:  52   r: 502.32   z0: 474.08   misfit: 2.24e+01
# itreação:  53   r: 502.75   z0: 474.27   misfit: 2.22e+01
# itreação:  54   r: 503.13   z0: 474.44   misfit: 2.20e+01
# itreação:  55   r: 503.47   z0: 474.60   misfit: 2.19e+01
# itreação:  56   r: 503.77   z0: 474.75   misfit: 2.18e+01
# itreação:  57   r: 504.04   z0: 474.89   misfit: 2.17e+01
# itreação:  58   r: 504.27   z0: 475.02   misfit: 2.16e+01
# itreação:  59   r: 504.48   z0: 475.14   misfit: 2.16e+01
# itreação:  60   r: 504.66   z0: 475.26   misfit: 2.15e+01
# itreação:  61   r: 504.82   z0: 475.37   misfit: 2.15e+01
# itreação:  62   r: 504.96   z0: 475.47   misfit: 2.14e+01
# itreação:  63   r: 505.08   z0: 475.57   misfit: 2.14e+01
# itreação:  64   r: 505.19   z0: 475.67   misfit: 2.14e+01
# itreação:  65   r: 505.28   z0: 475.76   misfit: 2.14e+01
# itreação:  66   r: 505.36   z0: 475.85   misfit: 2.14e+01
# itreação:  67   r: 505.44   z0: 475.94   misfit: 2.14e+01
# itreação:  68   r: 505.50   z0: 476.02   misfit: 2.14e+01
# itreação:  69   r: 505.55   z0: 476.10   misfit: 2.13e+01
# itreação:  70   r: 505.59   z0: 476.18   misfit: 2.13e+01
# itreação:  71   r: 505.63   z0: 476.25   misfit: 2.13e+01
# itreação:  72   r: 505.67   z0: 476.33   misfit: 2.13e+01
# itreação:  73   r: 505.69   z0: 476.40   misfit: 2.13e+01
# itreação:  74   r: 505.71   z0: 476.47   misfit: 2.13e+01
# itreação:  75   r: 505.73   z0: 476.54   misfit: 2.13e+01
# itreação:  76   r: 505.75   z0: 476.61   misfit: 2.13e+01
# itreação:  77   r: 505.76   z0: 476.67   misfit: 2.13e+01
# itreação:  78   r: 505.77   z0: 476.74   misfit: 2.13e+01
# itreação:  79   r: 505.77   z0: 476.80   misfit: 2.13e+01
# itreação:  80   r: 505.78   z0: 476.87   misfit: 2.13e+01
# itreação:  81   r: 505.78   z0: 476.93   misfit: 2.13e+01
# itreação:  82   r: 505.78   z0: 477.00   misfit: 2.13e+01
# itreação:  83   r: 505.77   z0: 477.06   misfit: 2.13e+01
# itreação:  84   r: 505.77   z0: 477.12   misfit: 2.13e+01
# itreação:  85   r: 505.76   z0: 477.18   misfit: 2.13e+01
# itreação:  86   r: 505.76   z0: 477.24   misfit: 2.13e+01
# itreação:  87   r: 505.75   z0: 477.30   misfit: 2.13e+01
# itreação:  88   r: 505.74   z0: 477.36   misfit: 2.13e+01
# itreação:  89   r: 505.73   z0: 477.42   misfit: 2.12e+01
# itreação:  90   r: 505.73   z0: 477.48   misfit: 2.12e+01
# itreação:  91   r: 505.72   z0: 477.54   misfit: 2.12e+01
# itreação:  92   r: 505.71   z0: 477.59   misfit: 2.12e+01
# itreação:  93   r: 505.69   z0: 477.65   misfit: 2.12e+01
# itreação:  94   r: 505.68   z0: 477.71   misfit: 2.12e+01
# itreação:  95   r: 505.67   z0: 477.77   misfit: 2.12e+01
# itreação:  96   r: 505.66   z0: 477.82   misfit: 2.12e+01
# itreação:  97   r: 505.65   z0: 477.88   misfit: 2.12e+01
# itreação:  98   r: 505.63   z0: 477.94   misfit: 2.12e+01
# itreação:  99   r: 505.62   z0: 477.99   misfit: 2.12e+01
# itreação: 100   r: 505.61   z0: 478.05   misfit: 2.12e+01
# itreação: 101   r: 505.60   z0: 478.10   misfit: 2.12e+01
# itreação: 102   r: 505.58   z0: 478.16   misfit: 2.12e+01
# itreação: 103   r: 505.57   z0: 478.21   misfit: 2.12e+01
# itreação: 104   r: 505.56   z0: 478.27   misfit: 2.12e+01
# itreação: 105   r: 505.54   z0: 478.32   misfit: 2.12e+01
# itreação: 106   r: 505.53   z0: 478.38   misfit: 2.12e+01
# itreação: 107   r: 505.52   z0: 478.43   misfit: 2.12e+01
# itreação: 108   r: 505.50   z0: 478.48   misfit: 2.12e+01
# itreação: 109   r: 505.49   z0: 478.54   misfit: 2.12e+01
# itreação: 110   r: 505.48   z0: 478.59   misfit: 2.12e+01
# itreação: 111   r: 505.46   z0: 478.64   misfit: 2.12e+01
# itreação: 112   r: 505.45   z0: 478.70   misfit: 2.12e+01
# itreação: 113   r: 505.43   z0: 478.75   misfit: 2.12e+01
# itreação: 114   r: 505.42   z0: 478.80   misfit: 2.12e+01
# itreação: 115   r: 505.41   z0: 478.85   misfit: 2.12e+01
# itreação: 116   r: 505.39   z0: 478.91   misfit: 2.12e+01
# itreação: 117   r: 505.38   z0: 478.96   misfit: 2.12e+01
# itreação: 118   r: 505.37   z0: 479.01   misfit: 2.12e+01
# itreação: 119   r: 505.35   z0: 479.06   misfit: 2.12e+01
# itreação: 120   r: 505.34   z0: 479.11   misfit: 2.12e+01
# itreação: 121   r: 505.33   z0: 479.17   misfit: 2.11e+01
# itreação: 122   r: 505.31   z0: 479.22   misfit: 2.11e+01
# itreação: 123   r: 505.30   z0: 479.27   misfit: 2.11e+01
# itreação: 124   r: 505.29   z0: 479.32   misfit: 2.11e+01
# itreação: 125   r: 505.27   z0: 479.37   misfit: 2.11e+01
# itreação: 126   r: 505.26   z0: 479.42   misfit: 2.11e+01
# itreação: 127   r: 505.25   z0: 479.47   misfit: 2.11e+01
# itreação: 128   r: 505.23   z0: 479.52   misfit: 2.11e+01
# itreação: 129   r: 505.22   z0: 479.57   misfit: 2.11e+01
# itreação: 130   r: 505.21   z0: 479.62   misfit: 2.11e+01
# itreação: 131   r: 505.19   z0: 479.67   misfit: 2.11e+01
# itreação: 132   r: 505.18   z0: 479.72   misfit: 2.11e+01
# itreação: 133   r: 505.17   z0: 479.77   misfit: 2.11e+01
# itreação: 134   r: 505.16   z0: 479.82   misfit: 2.11e+01
# itreação: 135   r: 505.14   z0: 479.86   misfit: 2.11e+01
# itreação: 136   r: 505.13   z0: 479.91   misfit: 2.11e+01
# itreação: 137   r: 505.12   z0: 479.96   misfit: 2.11e+01
# itreação: 138   r: 505.10   z0: 480.01   misfit: 2.11e+01
# itreação: 139   r: 505.09   z0: 480.06   misfit: 2.11e+01
# itreação: 140   r: 505.08   z0: 480.11   misfit: 2.11e+01
# itreação: 141   r: 505.07   z0: 480.15   misfit: 2.11e+01
# itreação: 142   r: 505.05   z0: 480.20   misfit: 2.11e+01
# itreação: 143   r: 505.04   z0: 480.25   misfit: 2.11e+01
# itreação: 144   r: 505.03   z0: 480.30   misfit: 2.11e+01
# itreação: 145   r: 505.02   z0: 480.34   misfit: 2.11e+01
# itreação: 146   r: 505.00   z0: 480.39   misfit: 2.11e+01
# itreação: 147   r: 504.99   z0: 480.44   misfit: 2.11e+01
# itreação: 148   r: 504.98   z0: 480.48   misfit: 2.11e+01
# itreação: 149   r: 504.97   z0: 480.53   misfit: 2.11e+01
# itreação: 150   r: 504.95   z0: 480.58   misfit: 2.11e+01
# itreação: 151   r: 504.94   z0: 480.62   misfit: 2.11e+01
# itreação: 152   r: 504.93   z0: 480.67   misfit: 2.11e+01
# itreação: 153   r: 504.92   z0: 480.72   misfit: 2.11e+01
# itreação: 154   r: 504.91   z0: 480.76   misfit: 2.11e+01
# itreação: 155   r: 504.89   z0: 480.81   misfit: 2.11e+01
# itreação: 156   r: 504.88   z0: 480.85   misfit: 2.11e+01
# itreação: 157   r: 504.87   z0: 480.90   misfit: 2.11e+01
# itreação: 158   r: 504.86   z0: 480.94   misfit: 2.11e+01
# itreação: 159   r: 504.85   z0: 480.99   misfit: 2.11e+01
# itreação: 160   r: 504.83   z0: 481.03   misfit: 2.11e+01
# itreação: 161   r: 504.82   z0: 481.08   misfit: 2.10e+01
# itreação: 162   r: 504.81   z0: 481.12   misfit: 2.10e+01
# itreação: 163   r: 504.80   z0: 481.17   misfit: 2.10e+01
# itreação: 164   r: 504.79   z0: 481.21   misfit: 2.10e+01
# itreação: 165   r: 504.78   z0: 481.25   misfit: 2.10e+01
# itreação: 166   r: 504.76   z0: 481.30   misfit: 2.10e+01
# itreação: 167   r: 504.75   z0: 481.34   misfit: 2.10e+01
# itreação: 168   r: 504.74   z0: 481.38   misfit: 2.10e+01
# itreação: 169   r: 504.73   z0: 481.43   misfit: 2.10e+01
# itreação: 170   r: 504.72   z0: 481.47   misfit: 2.10e+01
# itreação: 171   r: 504.71   z0: 481.51   misfit: 2.10e+01
# itreação: 172   r: 504.70   z0: 481.56   misfit: 2.10e+01
# itreação: 173   r: 504.68   z0: 481.60   misfit: 2.10e+01
# itreação: 174   r: 504.67   z0: 481.64   misfit: 2.10e+01
# itreação: 175   r: 504.66   z0: 481.69   misfit: 2.10e+01
# itreação: 176   r: 504.65   z0: 481.73   misfit: 2.10e+01
# itreação: 177   r: 504.64   z0: 481.77   misfit: 2.10e+01
# itreação: 178   r: 504.63   z0: 481.81   misfit: 2.10e+01
# itreação: 179   r: 504.62   z0: 481.85   misfit: 2.10e+01
# itreação: 180   r: 504.61   z0: 481.90   misfit: 2.10e+01
# itreação: 181   r: 504.60   z0: 481.94   misfit: 2.10e+01
# itreação: 182   r: 504.58   z0: 481.98   misfit: 2.10e+01
# itreação: 183   r: 504.57   z0: 482.02   misfit: 2.10e+01
# itreação: 184   r: 504.56   z0: 482.06   misfit: 2.10e+01
# itreação: 185   r: 504.55   z0: 482.10   misfit: 2.10e+01
# itreação: 186   r: 504.54   z0: 482.15   misfit: 2.10e+01
# itreação: 187   r: 504.53   z0: 482.19   misfit: 2.10e+01
# itreação: 188   r: 504.52   z0: 482.23   misfit: 2.10e+01
# itreação: 189   r: 504.51   z0: 482.27   misfit: 2.10e+01
# itreação: 190   r: 504.50   z0: 482.31   misfit: 2.10e+01
# itreação: 191   r: 504.49   z0: 482.35   misfit: 2.10e+01
# itreação: 192   r: 504.48   z0: 482.39   misfit: 2.10e+01
# itreação: 193   r: 504.47   z0: 482.43   misfit: 2.10e+01
# itreação: 194   r: 504.46   z0: 482.47   misfit: 2.10e+01
# itreação: 195   r: 504.45   z0: 482.51   misfit: 2.10e+01
# itreação: 196   r: 504.44   z0: 482.55   misfit: 2.10e+01
# itreação: 197   r: 504.43   z0: 482.59   misfit: 2.10e+01
# itreação: 198   r: 504.42   z0: 482.63   misfit: 2.10e+01
# itreação: 199   r: 504.40   z0: 482.67   misfit: 2.10e+01
# itreação: 200   r: 504.39   z0: 482.71   misfit: 2.10e+01
# itreação: 201   r: 504.38   z0: 482.74   misfit: 2.10e+01
# itreação: 202   r: 504.37   z0: 482.78   misfit: 2.10e+01
# itreação: 203   r: 504.36   z0: 482.82   misfit: 2.10e+01
# itreação: 204   r: 504.35   z0: 482.86   misfit: 2.10e+01
# itreação: 205   r: 504.34   z0: 482.90   misfit: 2.10e+01
# itreação: 206   r: 504.33   z0: 482.94   misfit: 2.10e+01
# itreação: 207   r: 504.32   z0: 482.98   misfit: 2.10e+01
# itreação: 208   r: 504.31   z0: 483.01   misfit: 2.10e+01
# itreação: 209   r: 504.30   z0: 483.05   misfit: 2.10e+01
# itreação: 210   r: 504.29   z0: 483.09   misfit: 2.10e+01
# itreação: 211   r: 504.28   z0: 483.13   misfit: 2.10e+01
# itreação: 212   r: 504.27   z0: 483.17   misfit: 2.10e+01
# itreação: 213   r: 504.26   z0: 483.20   misfit: 2.10e+01
# itreação: 214   r: 504.25   z0: 483.24   misfit: 2.10e+01
# itreação: 215   r: 504.24   z0: 483.28   misfit: 2.10e+01
# itreação: 216   r: 504.24   z0: 483.31   misfit: 2.10e+01
# itreação: 217   r: 504.23   z0: 483.35   misfit: 2.10e+01
# itreação: 218   r: 504.22   z0: 483.39   misfit: 2.09e+01
# itreação: 219   r: 504.21   z0: 483.43   misfit: 2.09e+01
# itreação: 220   r: 504.20   z0: 483.46   misfit: 2.09e+01
# itreação: 221   r: 504.19   z0: 483.50   misfit: 2.09e+01
# itreação: 222   r: 504.18   z0: 483.53   misfit: 2.09e+01
# itreação: 223   r: 504.17   z0: 483.57   misfit: 2.09e+01
# itreação: 224   r: 504.16   z0: 483.61   misfit: 2.09e+01
# itreação: 225   r: 504.15   z0: 483.64   misfit: 2.09e+01
# itreação: 226   r: 504.14   z0: 483.68   misfit: 2.09e+01
# itreação: 227   r: 504.13   z0: 483.71   misfit: 2.09e+01
# itreação: 228   r: 504.12   z0: 483.75   misfit: 2.09e+01
# itreação: 229   r: 504.11   z0: 483.79   misfit: 2.09e+01
# itreação: 230   r: 504.10   z0: 483.82   misfit: 2.09e+01
# itreação: 231   r: 504.09   z0: 483.86   misfit: 2.09e+01
# itreação: 232   r: 504.08   z0: 483.89   misfit: 2.09e+01
# itreação: 233   r: 504.08   z0: 483.93   misfit: 2.09e+01
# itreação: 234   r: 504.07   z0: 483.96   misfit: 2.09e+01
# itreação: 235   r: 504.06   z0: 484.00   misfit: 2.09e+01
# itreação: 236   r: 504.05   z0: 484.03   misfit: 2.09e+01
# itreação: 237   r: 504.04   z0: 484.07   misfit: 2.09e+01
# itreação: 238   r: 504.03   z0: 484.10   misfit: 2.09e+01
# itreação: 239   r: 504.02   z0: 484.14   misfit: 2.09e+01
# itreação: 240   r: 504.01   z0: 484.17   misfit: 2.09e+01
# itreação: 241   r: 504.00   z0: 484.20   misfit: 2.09e+01
# itreação: 242   r: 503.99   z0: 484.24   misfit: 2.09e+01
# itreação: 243   r: 503.99   z0: 484.27   misfit: 2.09e+01
# itreação: 244   r: 503.98   z0: 484.31   misfit: 2.09e+01
# itreação: 245   r: 503.97   z0: 484.34   misfit: 2.09e+01
# itreação: 246   r: 503.96   z0: 484.37   misfit: 2.09e+01
# itreação: 247   r: 503.95   z0: 484.41   misfit: 2.09e+01
# itreação: 248   r: 503.94   z0: 484.44   misfit: 2.09e+01
# itreação: 249   r: 503.93   z0: 484.47   misfit: 2.09e+01
# itreação: 250   r: 503.92   z0: 484.51   misfit: 2.09e+01
# itreação: 251   r: 503.92   z0: 484.54   misfit: 2.09e+01
# itreação: 252   r: 503.91   z0: 484.57   misfit: 2.09e+01
# itreação: 253   r: 503.90   z0: 484.61   misfit: 2.09e+01
# itreação: 254   r: 503.89   z0: 484.64   misfit: 2.09e+01
# itreação: 255   r: 503.88   z0: 484.67   misfit: 2.09e+01
# itreação: 256   r: 503.87   z0: 484.70   misfit: 2.09e+01
# itreação: 257   r: 503.86   z0: 484.74   misfit: 2.09e+01
# itreação: 258   r: 503.86   z0: 484.77   misfit: 2.09e+01
# itreação: 259   r: 503.85   z0: 484.80   misfit: 2.09e+01
# itreação: 260   r: 503.84   z0: 484.83   misfit: 2.09e+01
# itreação: 261   r: 503.83   z0: 484.86   misfit: 2.09e+01
# itreação: 262   r: 503.82   z0: 484.90   misfit: 2.09e+01
# itreação: 263   r: 503.81   z0: 484.93   misfit: 2.09e+01
# itreação: 264   r: 503.81   z0: 484.96   misfit: 2.09e+01
# itreação: 265   r: 503.80   z0: 484.99   misfit: 2.09e+01
# itreação: 266   r: 503.79   z0: 485.02   misfit: 2.09e+01
# itreação: 267   r: 503.78   z0: 485.05   misfit: 2.09e+01
# itreação: 268   r: 503.77   z0: 485.09   misfit: 2.09e+01
# itreação: 269   r: 503.76   z0: 485.12   misfit: 2.09e+01
# itreação: 270   r: 503.76   z0: 485.15   misfit: 2.09e+01
# itreação: 271   r: 503.75   z0: 485.18   misfit: 2.09e+01
# itreação: 272   r: 503.74   z0: 485.21   misfit: 2.09e+01
# itreação: 273   r: 503.73   z0: 485.24   misfit: 2.09e+01
# itreação: 274   r: 503.72   z0: 485.27   misfit: 2.09e+01
# itreação: 275   r: 503.72   z0: 485.30   misfit: 2.09e+01
# itreação: 276   r: 503.71   z0: 485.33   misfit: 2.09e+01
# itreação: 277   r: 503.70   z0: 485.36   misfit: 2.09e+01
# itreação: 278   r: 503.69   z0: 485.39   misfit: 2.09e+01
# itreação: 279   r: 503.69   z0: 485.42   misfit: 2.09e+01
# itreação: 280   r: 503.68   z0: 485.45   misfit: 2.09e+01
# itreação: 281   r: 503.67   z0: 485.48   misfit: 2.09e+01
# itreação: 282   r: 503.66   z0: 485.51   misfit: 2.09e+01
# itreação: 283   r: 503.65   z0: 485.54   misfit: 2.09e+01
# itreação: 284   r: 503.65   z0: 485.57   misfit: 2.09e+01
# itreação: 285   r: 503.64   z0: 485.60   misfit: 2.09e+01
# itreação: 286   r: 503.63   z0: 485.63   misfit: 2.09e+01
# itreação: 287   r: 503.62   z0: 485.66   misfit: 2.09e+01
# itreação: 288   r: 503.62   z0: 485.69   misfit: 2.09e+01
# itreação: 289   r: 503.61   z0: 485.72   misfit: 2.09e+01
# itreação: 290   r: 503.60   z0: 485.75   misfit: 2.09e+01
# itreação: 291   r: 503.59   z0: 485.78   misfit: 2.09e+01
# itreação: 292   r: 503.59   z0: 485.81   misfit: 2.09e+01
# itreação: 293   r: 503.58   z0: 485.84   misfit: 2.09e+01
# itreação: 294   r: 503.57   z0: 485.87   misfit: 2.09e+01
# itreação: 295   r: 503.56   z0: 485.89   misfit: 2.09e+01
# itreação: 296   r: 503.56   z0: 485.92   misfit: 2.09e+01
# itreação: 297   r: 503.55   z0: 485.95   misfit: 2.09e+01
# itreação: 298   r: 503.54   z0: 485.98   misfit: 2.09e+01
# itreação: 299   r: 503.53   z0: 486.01   misfit: 2.09e+01
# itreação: 300   r: 503.53   z0: 486.04   misfit: 2.09e+01
# itreação: 301   r: 503.52   z0: 486.06   misfit: 2.09e+01
# itreação: 302   r: 503.51   z0: 486.09   misfit: 2.09e+01
# itreação: 303   r: 503.50   z0: 486.12   misfit: 2.09e+01
# itreação: 304   r: 503.50   z0: 486.15   misfit: 2.09e+01
# itreação: 305   r: 503.49   z0: 486.18   misfit: 2.09e+01
# itreação: 306   r: 503.48   z0: 486.20   misfit: 2.09e+01
# itreação: 307   r: 503.48   z0: 486.23   misfit: 2.09e+01
# itreação: 308   r: 503.47   z0: 486.26   misfit: 2.09e+01
# itreação: 309   r: 503.46   z0: 486.29   misfit: 2.09e+01
# itreação: 310   r: 503.45   z0: 486.31   misfit: 2.08e+01
# itreação: 311   r: 503.45   z0: 486.34   misfit: 2.08e+01
# itreação: 312   r: 503.44   z0: 486.37   misfit: 2.08e+01
# itreação: 313   r: 503.43   z0: 486.40   misfit: 2.08e+01
# itreação: 314   r: 503.43   z0: 486.42   misfit: 2.08e+01
# itreação: 315   r: 503.42   z0: 486.45   misfit: 2.08e+01
# itreação: 316   r: 503.41   z0: 486.48   misfit: 2.08e+01
# itreação: 317   r: 503.40   z0: 486.50   misfit: 2.08e+01
# itreação: 318   r: 503.40   z0: 486.53   misfit: 2.08e+01
# itreação: 319   r: 503.39   z0: 486.56   misfit: 2.08e+01
# itreação: 320   r: 503.38   z0: 486.58   misfit: 2.08e+01
# itreação: 321   r: 503.38   z0: 486.61   misfit: 2.08e+01
# itreação: 322   r: 503.37   z0: 486.64   misfit: 2.08e+01
# itreação: 323   r: 503.36   z0: 486.66   misfit: 2.08e+01
# itreação: 324   r: 503.36   z0: 486.69   misfit: 2.08e+01
# itreação: 325   r: 503.35   z0: 486.71   misfit: 2.08e+01
# itreação: 326   r: 503.34   z0: 486.74   misfit: 2.08e+01
# itreação: 327   r: 503.34   z0: 486.77   misfit: 2.08e+01
# itreação: 328   r: 503.33   z0: 486.79   misfit: 2.08e+01
# itreação: 329   r: 503.32   z0: 486.82   misfit: 2.08e+01
# itreação: 330   r: 503.32   z0: 486.84   misfit: 2.08e+01
# itreação: 331   r: 503.31   z0: 486.87   misfit: 2.08e+01
# itreação: 332   r: 503.30   z0: 486.89   misfit: 2.08e+01
# itreação: 333   r: 503.30   z0: 486.92   misfit: 2.08e+01
# itreação: 334   r: 503.29   z0: 486.95   misfit: 2.08e+01
# itreação: 335   r: 503.28   z0: 486.97   misfit: 2.08e+01
# itreação: 336   r: 503.28   z0: 487.00   misfit: 2.08e+01
# itreação: 337   r: 503.27   z0: 487.02   misfit: 2.08e+01
# itreação: 338   r: 503.26   z0: 487.05   misfit: 2.08e+01
# itreação: 339   r: 503.26   z0: 487.07   misfit: 2.08e+01
# itreação: 340   r: 503.25   z0: 487.10   misfit: 2.08e+01
# itreação: 341   r: 503.24   z0: 487.12   misfit: 2.08e+01
# itreação: 342   r: 503.24   z0: 487.15   misfit: 2.08e+01
# itreação: 343   r: 503.23   z0: 487.17   misfit: 2.08e+01
# itreação: 344   r: 503.23   z0: 487.19   misfit: 2.08e+01
# itreação: 345   r: 503.22   z0: 487.22   misfit: 2.08e+01
# itreação: 346   r: 503.21   z0: 487.24   misfit: 2.08e+01
# itreação: 347   r: 503.21   z0: 487.27   misfit: 2.08e+01
# itreação: 348   r: 503.20   z0: 487.29   misfit: 2.08e+01
# itreação: 349   r: 503.19   z0: 487.32   misfit: 2.08e+01
# itreação: 350   r: 503.19   z0: 487.34   misfit: 2.08e+01
# itreação: 351   r: 503.18   z0: 487.36   misfit: 2.08e+01
# itreação: 352   r: 503.18   z0: 487.39   misfit: 2.08e+01
# itreação: 353   r: 503.17   z0: 487.41   misfit: 2.08e+01
# itreação: 354   r: 503.16   z0: 487.44   misfit: 2.08e+01
# itreação: 355   r: 503.16   z0: 487.46   misfit: 2.08e+01
# itreação: 356   r: 503.15   z0: 487.48   misfit: 2.08e+01
# itreação: 357   r: 503.15   z0: 487.51   misfit: 2.08e+01
# itreação: 358   r: 503.14   z0: 487.53   misfit: 2.08e+01
# itreação: 359   r: 503.13   z0: 487.55   misfit: 2.08e+01
# itreação: 360   r: 503.13   z0: 487.58   misfit: 2.08e+01
# itreação: 361   r: 503.12   z0: 487.60   misfit: 2.08e+01
# itreação: 362   r: 503.11   z0: 487.62   misfit: 2.08e+01
# itreação: 363   r: 503.11   z0: 487.65   misfit: 2.08e+01
# itreação: 364   r: 503.10   z0: 487.67   misfit: 2.08e+01
# itreação: 365   r: 503.10   z0: 487.69   misfit: 2.08e+01
# itreação: 366   r: 503.09   z0: 487.72   misfit: 2.08e+01
# itreação: 367   r: 503.09   z0: 487.74   misfit: 2.08e+01
# itreação: 368   r: 503.08   z0: 487.76   misfit: 2.08e+01
# itreação: 369   r: 503.07   z0: 487.78   misfit: 2.08e+01
# itreação: 370   r: 503.07   z0: 487.81   misfit: 2.08e+01
# itreação: 371   r: 503.06   z0: 487.83   misfit: 2.08e+01
# itreação: 372   r: 503.06   z0: 487.85   misfit: 2.08e+01
# itreação: 373   r: 503.05   z0: 487.87   misfit: 2.08e+01
# itreação: 374   r: 503.04   z0: 487.90   misfit: 2.08e+01
# itreação: 375   r: 503.04   z0: 487.92   misfit: 2.08e+01
# itreação: 376   r: 503.03   z0: 487.94   misfit: 2.08e+01
# itreação: 377   r: 503.03   z0: 487.96   misfit: 2.08e+01
# itreação: 378   r: 503.02   z0: 487.99   misfit: 2.08e+01
# itreação: 379   r: 503.02   z0: 488.01   misfit: 2.08e+01
# itreação: 380   r: 503.01   z0: 488.03   misfit: 2.08e+01
# itreação: 381   r: 503.00   z0: 488.05   misfit: 2.08e+01
# itreação: 382   r: 503.00   z0: 488.07   misfit: 2.08e+01
# itreação: 383   r: 502.99   z0: 488.10   misfit: 2.08e+01
# itreação: 384   r: 502.99   z0: 488.12   misfit: 2.08e+01
# itreação: 385   r: 502.98   z0: 488.14   misfit: 2.08e+01
# itreação: 386   r: 502.98   z0: 488.16   misfit: 2.08e+01
# itreação: 387   r: 502.97   z0: 488.18   misfit: 2.08e+01
# itreação: 388   r: 502.97   z0: 488.20   misfit: 2.08e+01
# itreação: 389   r: 502.96   z0: 488.22   misfit: 2.08e+01
# itreação: 390   r: 502.95   z0: 488.25   misfit: 2.08e+01
# itreação: 391   r: 502.95   z0: 488.27   misfit: 2.08e+01
# itreação: 392   r: 502.94   z0: 488.29   misfit: 2.08e+01
# itreação: 393   r: 502.94   z0: 488.31   misfit: 2.08e+01
# itreação: 394   r: 502.93   z0: 488.33   misfit: 2.08e+01
# itreação: 395   r: 502.93   z0: 488.35   misfit: 2.08e+01
# itreação: 396   r: 502.92   z0: 488.37   misfit: 2.08e+01
# itreação: 397   r: 502.92   z0: 488.39   misfit: 2.08e+01
# itreação: 398   r: 502.91   z0: 488.41   misfit: 2.08e+01
# itreação: 399   r: 502.91   z0: 488.43   misfit: 2.08e+01
# itreação: 400   r: 502.90   z0: 488.45   misfit: 2.08e+01
# itreação: 401   r: 502.90   z0: 488.47   misfit: 2.08e+01
# itreação: 402   r: 502.89   z0: 488.50   misfit: 2.08e+01
# itreação: 403   r: 502.88   z0: 488.52   misfit: 2.08e+01
# itreação: 404   r: 502.88   z0: 488.54   misfit: 2.08e+01
# itreação: 405   r: 502.87   z0: 488.56   misfit: 2.08e+01
# itreação: 406   r: 502.87   z0: 488.58   misfit: 2.08e+01
# itreação: 407   r: 502.86   z0: 488.60   misfit: 2.08e+01
# itreação: 408   r: 502.86   z0: 488.62   misfit: 2.08e+01
# itreação: 409   r: 502.85   z0: 488.64   misfit: 2.08e+01
# itreação: 410   r: 502.85   z0: 488.66   misfit: 2.08e+01
# itreação: 411   r: 502.84   z0: 488.68   misfit: 2.08e+01
# itreação: 412   r: 502.84   z0: 488.70   misfit: 2.08e+01
# itreação: 413   r: 502.83   z0: 488.72   misfit: 2.08e+01
# itreação: 414   r: 502.83   z0: 488.74   misfit: 2.08e+01
# itreação: 415   r: 502.82   z0: 488.76   misfit: 2.08e+01
# itreação: 416   r: 502.82   z0: 488.78   misfit: 2.08e+01
# itreação: 417   r: 502.81   z0: 488.80   misfit: 2.08e+01
# itreação: 418   r: 502.81   z0: 488.81   misfit: 2.08e+01
# itreação: 419   r: 502.80   z0: 488.83   misfit: 2.08e+01
# itreação: 420   r: 502.80   z0: 488.85   misfit: 2.08e+01
# itreação: 421   r: 502.79   z0: 488.87   misfit: 2.08e+01
# itreação: 422   r: 502.79   z0: 488.89   misfit: 2.08e+01
# itreação: 423   r: 502.78   z0: 488.91   misfit: 2.08e+01
# itreação: 424   r: 502.78   z0: 488.93   misfit: 2.08e+01
# itreação: 425   r: 502.77   z0: 488.95   misfit: 2.08e+01
# itreação: 426   r: 502.77   z0: 488.97   misfit: 2.08e+01
# itreação: 427   r: 502.76   z0: 488.99   misfit: 2.08e+01
# itreação: 428   r: 502.76   z0: 489.01   misfit: 2.08e+01
# itreação: 429   r: 502.75   z0: 489.03   misfit: 2.08e+01
# itreação: 430   r: 502.75   z0: 489.04   misfit: 2.08e+01
# itreação: 431   r: 502.74   z0: 489.06   misfit: 2.08e+01
# itreação: 432   r: 502.74   z0: 489.08   misfit: 2.08e+01
# itreação: 433   r: 502.73   z0: 489.10   misfit: 2.08e+01
# itreação: 434   r: 502.73   z0: 489.12   misfit: 2.08e+01
# itreação: 435   r: 502.72   z0: 489.14   misfit: 2.08e+01
# itreação: 436   r: 502.72   z0: 489.16   misfit: 2.08e+01
# itreação: 437   r: 502.72   z0: 489.17   misfit: 2.08e+01
# itreação: 438   r: 502.71   z0: 489.19   misfit: 2.08e+01
# itreação: 439   r: 502.71   z0: 489.21   misfit: 2.08e+01
# itreação: 440   r: 502.70   z0: 489.23   misfit: 2.08e+01
# itreação: 441   r: 502.70   z0: 489.25   misfit: 2.08e+01
# itreação: 442   r: 502.69   z0: 489.27   misfit: 2.08e+01
# itreação: 443   r: 502.69   z0: 489.28   misfit: 2.08e+01
# itreação: 444   r: 502.68   z0: 489.30   misfit: 2.08e+01
# itreação: 445   r: 502.68   z0: 489.32   misfit: 2.08e+01
# itreação: 446   r: 502.67   z0: 489.34   misfit: 2.08e+01
# itreação: 447   r: 502.67   z0: 489.35   misfit: 2.08e+01
# itreação: 448   r: 502.66   z0: 489.37   misfit: 2.08e+01
# itreação: 449   r: 502.66   z0: 489.39   misfit: 2.08e+01
# itreação: 450   r: 502.66   z0: 489.41   misfit: 2.08e+01
# itreação: 451   r: 502.65   z0: 489.43   misfit: 2.08e+01
# itreação: 452   r: 502.65   z0: 489.44   misfit: 2.08e+01
# itreação: 453   r: 502.64   z0: 489.46   misfit: 2.08e+01
# itreação: 454   r: 502.64   z0: 489.48   misfit: 2.08e+01
# itreação: 455   r: 502.63   z0: 489.50   misfit: 2.08e+01
# itreação: 456   r: 502.63   z0: 489.51   misfit: 2.08e+01
# itreação: 457   r: 502.62   z0: 489.53   misfit: 2.08e+01
# itreação: 458   r: 502.62   z0: 489.55   misfit: 2.08e+01
# itreação: 459   r: 502.62   z0: 489.56   misfit: 2.08e+01
# itreação: 460   r: 502.61   z0: 489.58   misfit: 2.08e+01
# itreação: 461   r: 502.61   z0: 489.60   misfit: 2.08e+01
# itreação: 462   r: 502.60   z0: 489.62   misfit: 2.08e+01
# itreação: 463   r: 502.60   z0: 489.63   misfit: 2.08e+01
# itreação: 464   r: 502.59   z0: 489.65   misfit: 2.08e+01
# itreação: 465   r: 502.59   z0: 489.67   misfit: 2.08e+01
# itreação: 466   r: 502.58   z0: 489.68   misfit: 2.08e+01
# itreação: 467   r: 502.58   z0: 489.70   misfit: 2.08e+01
# itreação: 468   r: 502.58   z0: 489.72   misfit: 2.08e+01
# itreação: 469   r: 502.57   z0: 489.73   misfit: 2.08e+01
# itreação: 470   r: 502.57   z0: 489.75   misfit: 2.08e+01
# itreação: 471   r: 502.56   z0: 489.77   misfit: 2.08e+01
# itreação: 472   r: 502.56   z0: 489.78   misfit: 2.08e+01
# itreação: 473   r: 502.55   z0: 489.80   misfit: 2.08e+01
# itreação: 474   r: 502.55   z0: 489.82   misfit: 2.08e+01
# itreação: 475   r: 502.55   z0: 489.83   misfit: 2.08e+01
# itreação: 476   r: 502.54   z0: 489.85   misfit: 2.08e+01
# itreação: 477   r: 502.54   z0: 489.87   misfit: 2.08e+01
# itreação: 478   r: 502.53   z0: 489.88   misfit: 2.08e+01
# itreação: 479   r: 502.53   z0: 489.90   misfit: 2.08e+01
# itreação: 480   r: 502.53   z0: 489.91   misfit: 2.08e+01
# itreação: 481   r: 502.52   z0: 489.93   misfit: 2.08e+01
# itreação: 482   r: 502.52   z0: 489.95   misfit: 2.08e+01
# itreação: 483   r: 502.51   z0: 489.96   misfit: 2.08e+01
# itreação: 484   r: 502.51   z0: 489.98   misfit: 2.08e+01
# itreação: 485   r: 502.51   z0: 489.99   misfit: 2.08e+01
# itreação: 486   r: 502.50   z0: 490.01   misfit: 2.08e+01
# itreação: 487   r: 502.50   z0: 490.03   misfit: 2.08e+01
# itreação: 488   r: 502.49   z0: 490.04   misfit: 2.08e+01
# itreação: 489   r: 502.49   z0: 490.06   misfit: 2.08e+01
# itreação: 490   r: 502.48   z0: 490.07   misfit: 2.08e+01
# itreação: 491   r: 502.48   z0: 490.09   misfit: 2.08e+01
# itreação: 492   r: 502.48   z0: 490.10   misfit: 2.08e+01
# itreação: 493   r: 502.47   z0: 490.12   misfit: 2.08e+01
# itreação: 494   r: 502.47   z0: 490.13   misfit: 2.08e+01
# itreação: 495   r: 502.46   z0: 490.15   misfit: 2.08e+01
# itreação: 496   r: 502.46   z0: 490.17   misfit: 2.08e+01
# itreação: 497   r: 502.46   z0: 490.18   misfit: 2.08e+01
# itreação: 498   r: 502.45   z0: 490.20   misfit: 2.08e+01
# itreação: 499   r: 502.45   z0: 490.21   misfit: 2.08e+01
# itreação: 500   r: 502.45   z0: 490.23   misfit: 2.08e+01
# itreação: 501   r: 502.44   z0: 490.24   misfit: 2.08e+01
# itreação: 502   r: 502.44   z0: 490.26   misfit: 2.08e+01
# itreação: 503   r: 502.43   z0: 490.27   misfit: 2.08e+01
# itreação: 504   r: 502.43   z0: 490.29   misfit: 2.08e+01
# itreação: 505   r: 502.43   z0: 490.30   misfit: 2.08e+01
# itreação: 506   r: 502.42   z0: 490.32   misfit: 2.08e+01
# itreação: 507   r: 502.42   z0: 490.33   misfit: 2.08e+01
# itreação: 508   r: 502.41   z0: 490.35   misfit: 2.08e+01
# itreação: 509   r: 502.41   z0: 490.36   misfit: 2.08e+01
# itreação: 510   r: 502.41   z0: 490.38   misfit: 2.08e+01
# itreação: 511   r: 502.40   z0: 490.39   misfit: 2.08e+01
# itreação: 512   r: 502.40   z0: 490.40   misfit: 2.08e+01
# itreação: 513   r: 502.40   z0: 490.42   misfit: 2.08e+01
# itreação: 514   r: 502.39   z0: 490.43   misfit: 2.08e+01
# itreação: 515   r: 502.39   z0: 490.45   misfit: 2.08e+01
# itreação: 516   r: 502.38   z0: 490.46   misfit: 2.08e+01
# itreação: 517   r: 502.38   z0: 490.48   misfit: 2.08e+01
# itreação: 518   r: 502.38   z0: 490.49   misfit: 2.08e+01
# itreação: 519   r: 502.37   z0: 490.51   misfit: 2.08e+01
# itreação: 520   r: 502.37   z0: 490.52   misfit: 2.08e+01
# itreação: 521   r: 502.37   z0: 490.53   misfit: 2.08e+01
# itreação: 522   r: 502.36   z0: 490.55   misfit: 2.08e+01
# itreação: 523   r: 502.36   z0: 490.56   misfit: 2.08e+01
# itreação: 524   r: 502.36   z0: 490.58   misfit: 2.08e+01
# itreação: 525   r: 502.35   z0: 490.59   misfit: 2.08e+01
# itreação: 526   r: 502.35   z0: 490.61   misfit: 2.08e+01
# itreação: 527   r: 502.34   z0: 490.62   misfit: 2.08e+01

# %% [markdown]
# # Plots de resultados

# %%
res_norm = (res - np.mean(res))/np.std(res)
res_plot = res.reshape(shape)
xp = xp.reshape(shape)
yp = yp.reshape(shape)
dpred = data.reshape(shape)
dobs = data_noise.reshape(shape)

# %%
#plot
plt.figure(figsize=(5,5))
plt.plot(r_true, dz_true, 'oy')
plt.plot(p1_list, p2_list, '.w-', markersize=5)
plt.title('SD - geofisica', fontsize=18)
plt.contourf(r_plot, z0_plot, phi_eq, 40, cmap='jet')
plt.xlabel('$r$', fontsize=18)
plt.ylabel('$dz$', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Convergencia', fontsize = 18)
plt.xlabel('Iteration number')
plt.plot(phi_list, 'o')

plt.subplot(1, 3, 2)
plt.title('Estimativas de  r', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('r')
plt.plot(p1_list, 'o')
plt.plot(np.zeros(len(p1_list)) + r_true, '-')

plt.subplot(1, 3, 3)
plt.title('Estimativas de  dz', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('z0')
plt.plot(p2_list, 'o')
plt.plot(np.zeros(len(p1_list)) + dz_true, '-')
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Dado predito', fontsize=20)
plt.contourf(yp, xp, dpred, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 2)
plt.title('Dado observado', fontsize=20)
plt.contourf(yp, xp, dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 3)
plt.title('SD - ajuste', fontsize=20)
plt.contourf(yp, xp, res_plot, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)
plt.show()

# %%
plt.plot(figsize=(20,5))
plt.title('Histogram', fontsize = 20)
plt.xlabel('$\mu$ = %.7f  $\sigma$ = %.7f' % (np.mean(res_norm), np.std(res_norm)), fontsize=20)
nbins = int((np.max(res_norm) - np.min(res_norm)))
plt.hist(res_norm,bins=nbins, normed=True)
plt.ylim(0.,0.5)
plt.xlim(-10., 10.)
plt.show()
