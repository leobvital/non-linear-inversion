# %% [markdown]
# # Steepest descent aplicado à função geofísica

# %% [markdown]
# Este algoritmo aplica o método de otimização Steepest descent à função matemática de Rosenbrock, a qual é definida pela equação geral:

# %% [markdown]
# \begin{equation}
# f(x,y) = (a - x)^2 + b(y - x^2)^2 ,
# \end{equation}

# %% [markdown]
# onde $a$ e $b$ são constantes e o mínimo dessa função é $(x,y)=(a,a^2)$, onde $f(a,a^2)=0$. Normalmente $a$ e $b$ são iguais a 1 e a 100, respectivamente, nesse caso, o mínimo dessa função é $(x,y)=(1,1)$.

# %% [markdown]
# Então a função a ser minimizada através do método steepest descente é:

# %% [markdown]
# \begin{equation}
# f(p_1,p_2) = 100(p_2 - p_1^2)^2 + (p_1 - 1)^2 ,
# \end{equation}

# %% [markdown]
# A proposta do código é encontrar o mínimo da função através de muitas iterações.

# %% [markdown]
# O método steepest descent é um método de convergência global, o qual se aproxima do mínimo com a direção de $-\nabla \boldsymbol{\phi}(\mathbf{p})$, que é menos o gradiente da função objetivo e $\mathbf{p}$ é o vetor de parâmentros. O método possui o seguinte algoritmo:

# %% [markdown]
# 1) estabelece um chute inicial $\mathbf{p}_i$
#
# 2) determina a direção $\mathbf{a}_i$ que diminua $\boldsymbol{\phi}$ em torno de $\mathbf{p}_i$
#
# 3) calcula $\mathbf{p}_{i+1} = \mathbf{p}_i + \rho _i \mathbf{a}_i$, onde $\rho_i$ é um escalar que modula o passo em direção ao mínimo e $\mathbf{a}_i = -\nabla \boldsymbol{\phi}(\mathbf{p})$
#
# 4) testa a convergência, se for satisfeita o algoritmo para, caso contrário retorna para 1)

# %% [markdown]
# # Importando pacotes

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
from visual import histeq
from fatiando.mesher import PolygonalPrism
from IPython.display import Image as img
from fatiando.gravmag import polyprism
from copy import deepcopy
from fatiando.vis import mpl, myv

import sys
sys.path.insert(0, '../magnetic-radial-inversion/code')

import mag_polyprism_functions as mfun
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# # Modelagem direta

# %%
with open('data/cylinder_model.pickle') as w:
        cylinder_model = pickle.load(w)
with open('data/cylinder_bottom_data.pickle') as w:
        cylinder_bottom_data = pickle.load(w)
with open('data/regular_grid.pickle') as w:
        regular_grid = pickle.load(w)

# %% [raw]
# bounds = [-800., 800., -800., 800., -200.0, 800.]
#
# red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
# white, black = (1, 1, 1), (0, 0, 0),
#
# # Show the model
# scene = myv.figure()
# myv.polyprisms(cylinder_model['prisms'], 'magnetization', color=blue, opacity=1.)
#
# ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
# ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (m)', 'y (m)', 'z (m)'
# ax.axes.font_factor = 1.5
# scene.scene.camera.position = [-0.089204656936016313, -0.066107174155361687, -0.04083578885723696]
# scene.scene.camera.focal_point = [1.1820671636724554e-16, 1.3134079596360617e-17, -1.9701119394540926e-17]
# scene.scene.camera.view_angle = 30.0
# scene.scene.camera.view_up = [0.24683390337942718, 0.24593292331329802, -0.93733132955911114]
# scene.scene.camera.clipping_range = [0.057117737884348194, 0.1956040854922288]
# scene.scene.camera.compute_view_plane_normal()
#
# myv.wall_bottom(ax.axes.bounds, opacity=0.2)
# myv.wall_north(ax.axes.bounds)
# myv.savefig('bolacha.png')
# myv.show()

# %%
img(filename='bolacha.png')

# %% [markdown]
# ## Plotando a função

# %%
plt.figure(figsize=(5,5))
plt.plot(cylinder_model['r'], cylinder_model['z0'] + cylinder_model['dz'], 'og')
plt.title('Funcao objetivo', fontsize=18)
plt.contourf(cylinder_bottom_data['p1'], cylinder_bottom_data['p2'], cylinder_bottom_data['phi_eq'], 50, cmap='jet')
plt.xlabel('$r$ (m)', fontsize=18)
plt.ylabel('$z$ (m)', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.savefig('plot_geo-base_prob.png', pad_inches=0.0)
plt.show()

# %% [markdown]
# # Funções

# %%
def derivative_tf_z(xp, yp, zp, prism, M, deltaz, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of one fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    delta: float - increment in x coordinate in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - deltaa
    prism_plus[0].z2 += deltaz
    prism_minus[0].z2 -= deltaz

    df = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df -= polyprism.tf(xp, yp, zp, prism_minus, inc, dec)
    df /= (2.*deltaz)

    return df

def derivative_tf_radiall(xp, yp, zp, prism, M, deltar, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of a fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in radial distance in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'
    
    ang = 2.*np.pi/M # angle between two vertices
    
    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - delta

    for i in range(M):
        deltax = deltar*np.cos(i*ang)
        deltay = deltar*np.sin(i*ang)
        prism_plus[0].x[i] += deltax
        prism_plus[0].y[i] += deltay
        prism_minus[0].x[i] -= deltax
        prism_minus[0].y[i] -= deltay

    df = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df -= polyprism.tf(xp, yp, zp, prism_minus, inc, dec)
    df /= (2.*deltar)

    return df

# calculando jacobiana de phi
def jacobi_geo(xp, yp, zp, prism, M, deltar, deltaz, inc, dec):
    '''
    Returns the sensitivity matrix for polygonal prisms using finite
    differences.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in meters for radial distance
    deltaz: float - increment in meters for depth
    inc: float - inclination of the local-geomagnetic field
    dec: declination of the local-geomagnetic field

    output

    G: 2D array - sensitivity matrix
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    G = np.zeros((xp.size, 2))

    G[:, 0] = derivative_tf_radiall(xp, yp, zp, prism[0], M, deltar, inc, dec)
    G[:, 1] = derivative_tf_z(xp, yp, zp, prism[0], M, deltaz, inc, dec)

    return G

# %% [markdown]
# # Modelo interpretativo

# %%
# chute inicial
p01 = 200.
p02 = 200.

# incremento para as derivadas
deltar = 0.01*p01
deltaz = 0.01*p02

r = np.zeros(cylinder_model['M']) + p01 # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

l = [[r, x0, y0, cylinder_model['z0'], p02, cylinder_model['props']]]

# %%
prism0 = mfun.pol2cart(l, cylinder_model['M'], cylinder_model['L'])

d0 = polyprism.tf(regular_grid['xp'], regular_grid['yp'], regular_grid['zp'],
                    prism0, cylinder_model['inc'], cylinder_model['dec'])

# vetor do chute inicial
p0 = np.array([p01,p02]) 

# parâmetros para o critério de Armijo
mi = 0.0000001
lamb = 10.
epsilon = 0.000000001

# calculando o valor da função e do resíduo em p0
res0 = cylinder_bottom_data['data_noise'] - d0
phi0 = np.sum(res0*res0)


p1_list = [p01]
p2_list = [p02]
phi_list = [phi0]

# %% [markdown]
# # Algoritmo Steepest Descent

# %%
for i in range(10000):
    # calculando a Jacobiana e o gradiente
    G = jacobi_geo(regular_grid['xp'], regular_grid['yp'], regular_grid['zp'], prism0, cylinder_model['M'],
                   deltar, deltaz, cylinder_model['inc'], cylinder_model['dec'])
    grad = -2.*np.dot(G.T, res0) + mi*p0
    #print grad
    # calculando p e atualizando para a próxima iteração
    p = p0 - lamb*grad
    #print p, p0
    l = [[np.zeros(cylinder_model['M']) + p[0], x0, y0, cylinder_model['z0'], p[1], cylinder_model['props']]]
    prism = mfun.pol2cart(l, cylinder_model['M'], cylinder_model['L'])
    d = polyprism.tf(regular_grid['xp'], regular_grid['yp'], regular_grid['zp'],
                    prism, cylinder_model['inc'], cylinder_model['dec'])
    res = cylinder_bottom_data['data_noise'] - d
    phi = np.sum(res*res)
    
    if (abs(phi-phi0)/phi0 <= epsilon):
        break
    else:
        # armazenando os resultados em listas para o plot
        phi_list.append(phi)
        p1_list.append(p[0])
        p2_list.append(p[1])
        
        # atualizando parâmetros
        p0 = p
        d0 = d
        res0 = res
        phi0 = phi
        prism0 = prism
        
        # printa os valores
        print 'itreação: %3d   r: %.2f   z: %.2f   misfit: %.2e' % (i, p0[0], p0[1], phi0)
# Out:
# itreação:   0   r: 264.07   z: 255.71   misfit: 3.62e+03
# itreação:   1   r: 362.84   z: 322.97   misfit: 2.06e+03
# itreação:   2   r: 476.76   z: 392.80   misfit: 5.51e+02
# itreação:   3   r: 541.78   z: 437.98   misfit: 1.67e+02
# itreação:   4   r: 547.48   z: 454.84   misfit: 1.43e+02
# itreação:   5   r: 543.22   z: 465.25   misfit: 1.32e+02
# itreação:   6   r: 539.65   z: 474.27   misfit: 1.23e+02
# itreação:   7   r: 536.62   z: 482.21   misfit: 1.16e+02
# itreação:   8   r: 534.02   z: 489.28   misfit: 1.11e+02
# itreação:   9   r: 531.75   z: 495.63   misfit: 1.06e+02
# itreação:  10   r: 529.75   z: 501.37   misfit: 1.03e+02
# itreação:  11   r: 527.96   z: 506.61   misfit: 9.99e+01
# itreação:  12   r: 526.35   z: 511.40   misfit: 9.75e+01
# itreação:  13   r: 524.90   z: 515.81   misfit: 9.54e+01
# itreação:  14   r: 523.58   z: 519.88   misfit: 9.36e+01
# itreação:  15   r: 522.37   z: 523.66   misfit: 9.21e+01
# itreação:  16   r: 521.26   z: 527.18   misfit: 9.08e+01
# itreação:  17   r: 520.23   z: 530.46   misfit: 8.97e+01
# itreação:  18   r: 519.28   z: 533.54   misfit: 8.86e+01
# itreação:  19   r: 518.40   z: 536.42   misfit: 8.78e+01
# itreação:  20   r: 517.58   z: 539.13   misfit: 8.70e+01
# itreação:  21   r: 516.82   z: 541.68   misfit: 8.63e+01
# itreação:  22   r: 516.10   z: 544.09   misfit: 8.57e+01
# itreação:  23   r: 515.43   z: 546.37   misfit: 8.51e+01
# itreação:  24   r: 514.79   z: 548.53   misfit: 8.46e+01
# itreação:  25   r: 514.20   z: 550.57   misfit: 8.42e+01
# itreação:  26   r: 513.64   z: 552.51   misfit: 8.38e+01
# itreação:  27   r: 513.11   z: 554.36   misfit: 8.34e+01
# itreação:  28   r: 512.60   z: 556.12   misfit: 8.31e+01
# itreação:  29   r: 512.13   z: 557.79   misfit: 8.28e+01
# itreação:  30   r: 511.68   z: 559.38   misfit: 8.26e+01
# itreação:  31   r: 511.25   z: 560.91   misfit: 8.23e+01
# itreação:  32   r: 510.84   z: 562.36   misfit: 8.21e+01
# itreação:  33   r: 510.45   z: 563.75   misfit: 8.19e+01
# itreação:  34   r: 510.08   z: 565.08   misfit: 8.17e+01
# itreação:  35   r: 509.73   z: 566.36   misfit: 8.15e+01
# itreação:  36   r: 509.39   z: 567.58   misfit: 8.14e+01
# itreação:  37   r: 509.07   z: 568.75   misfit: 8.12e+01
# itreação:  38   r: 508.76   z: 569.87   misfit: 8.11e+01
# itreação:  39   r: 508.47   z: 570.95   misfit: 8.10e+01
# itreação:  40   r: 508.19   z: 571.98   misfit: 8.09e+01
# itreação:  41   r: 507.92   z: 572.98   misfit: 8.07e+01
# itreação:  42   r: 507.66   z: 573.94   misfit: 8.07e+01
# itreação:  43   r: 507.41   z: 574.86   misfit: 8.06e+01
# itreação:  44   r: 507.17   z: 575.74   misfit: 8.05e+01
# itreação:  45   r: 506.95   z: 576.59   misfit: 8.04e+01
# itreação:  46   r: 506.73   z: 577.41   misfit: 8.03e+01
# itreação:  47   r: 506.52   z: 578.20   misfit: 8.03e+01
# itreação:  48   r: 506.31   z: 578.97   misfit: 8.02e+01
# itreação:  49   r: 506.12   z: 579.70   misfit: 8.01e+01
# itreação:  50   r: 505.93   z: 580.41   misfit: 8.01e+01
# itreação:  51   r: 505.75   z: 581.09   misfit: 8.00e+01
# itreação:  52   r: 505.58   z: 581.75   misfit: 8.00e+01
# itreação:  53   r: 505.41   z: 582.39   misfit: 8.00e+01
# itreação:  54   r: 505.25   z: 583.01   misfit: 7.99e+01
# itreação:  55   r: 505.09   z: 583.60   misfit: 7.99e+01
# itreação:  56   r: 504.94   z: 584.17   misfit: 7.98e+01
# itreação:  57   r: 504.80   z: 584.73   misfit: 7.98e+01
# itreação:  58   r: 504.66   z: 585.26   misfit: 7.98e+01
# itreação:  59   r: 504.52   z: 585.78   misfit: 7.98e+01
# itreação:  60   r: 504.39   z: 586.28   misfit: 7.97e+01
# itreação:  61   r: 504.26   z: 586.77   misfit: 7.97e+01
# itreação:  62   r: 504.14   z: 587.24   misfit: 7.97e+01
# itreação:  63   r: 504.03   z: 587.69   misfit: 7.97e+01
# itreação:  64   r: 503.91   z: 588.13   misfit: 7.96e+01
# itreação:  65   r: 503.80   z: 588.55   misfit: 7.96e+01
# itreação:  66   r: 503.70   z: 588.97   misfit: 7.96e+01
# itreação:  67   r: 503.59   z: 589.37   misfit: 7.96e+01
# itreação:  68   r: 503.49   z: 589.75   misfit: 7.96e+01
# itreação:  69   r: 503.40   z: 590.12   misfit: 7.96e+01
# itreação:  70   r: 503.31   z: 590.49   misfit: 7.95e+01
# itreação:  71   r: 503.22   z: 590.84   misfit: 7.95e+01
# itreação:  72   r: 503.13   z: 591.18   misfit: 7.95e+01
# itreação:  73   r: 503.04   z: 591.51   misfit: 7.95e+01
# itreação:  74   r: 502.96   z: 591.83   misfit: 7.95e+01
# itreação:  75   r: 502.88   z: 592.14   misfit: 7.95e+01
# itreação:  76   r: 502.81   z: 592.44   misfit: 7.95e+01
# itreação:  77   r: 502.73   z: 592.73   misfit: 7.95e+01
# itreação:  78   r: 502.66   z: 593.01   misfit: 7.95e+01
# itreação:  79   r: 502.59   z: 593.28   misfit: 7.95e+01
# itreação:  80   r: 502.52   z: 593.55   misfit: 7.94e+01
# itreação:  81   r: 502.46   z: 593.81   misfit: 7.94e+01
# itreação:  82   r: 502.39   z: 594.06   misfit: 7.94e+01
# itreação:  83   r: 502.33   z: 594.30   misfit: 7.94e+01
# itreação:  84   r: 502.27   z: 594.54   misfit: 7.94e+01
# itreação:  85   r: 502.21   z: 594.76   misfit: 7.94e+01
# itreação:  86   r: 502.16   z: 594.99   misfit: 7.94e+01
# itreação:  87   r: 502.10   z: 595.20   misfit: 7.94e+01
# itreação:  88   r: 502.05   z: 595.41   misfit: 7.94e+01
# itreação:  89   r: 502.00   z: 595.61   misfit: 7.94e+01
# itreação:  90   r: 501.95   z: 595.81   misfit: 7.94e+01
# itreação:  91   r: 501.90   z: 596.00   misfit: 7.94e+01
# itreação:  92   r: 501.85   z: 596.19   misfit: 7.94e+01
# itreação:  93   r: 501.81   z: 596.37   misfit: 7.94e+01
# itreação:  94   r: 501.77   z: 596.54   misfit: 7.94e+01
# itreação:  95   r: 501.72   z: 596.71   misfit: 7.94e+01
# itreação:  96   r: 501.68   z: 596.88   misfit: 7.94e+01
# itreação:  97   r: 501.64   z: 597.04   misfit: 7.94e+01
# itreação:  98   r: 501.60   z: 597.19   misfit: 7.94e+01
# itreação:  99   r: 501.56   z: 597.34   misfit: 7.94e+01
# itreação: 100   r: 501.53   z: 597.49   misfit: 7.94e+01
# itreação: 101   r: 501.49   z: 597.63   misfit: 7.94e+01
# itreação: 102   r: 501.46   z: 597.77   misfit: 7.94e+01
# itreação: 103   r: 501.42   z: 597.91   misfit: 7.94e+01
# itreação: 104   r: 501.39   z: 598.04   misfit: 7.94e+01
# itreação: 105   r: 501.36   z: 598.17   misfit: 7.94e+01
# itreação: 106   r: 501.33   z: 598.29   misfit: 7.93e+01
# itreação: 107   r: 501.30   z: 598.41   misfit: 7.93e+01
# itreação: 108   r: 501.27   z: 598.53   misfit: 7.93e+01
# itreação: 109   r: 501.24   z: 598.64   misfit: 7.93e+01
# itreação: 110   r: 501.21   z: 598.75   misfit: 7.93e+01
# itreação: 111   r: 501.18   z: 598.86   misfit: 7.93e+01
# itreação: 112   r: 501.16   z: 598.96   misfit: 7.93e+01
# itreação: 113   r: 501.13   z: 599.06   misfit: 7.93e+01
# itreação: 114   r: 501.11   z: 599.16   misfit: 7.93e+01
# itreação: 115   r: 501.08   z: 599.26   misfit: 7.93e+01
# itreação: 116   r: 501.06   z: 599.35   misfit: 7.93e+01
# itreação: 117   r: 501.04   z: 599.44   misfit: 7.93e+01
# itreação: 118   r: 501.02   z: 599.53   misfit: 7.93e+01
# itreação: 119   r: 500.99   z: 599.62   misfit: 7.93e+01
# itreação: 120   r: 500.97   z: 599.70   misfit: 7.93e+01
# itreação: 121   r: 500.95   z: 599.78   misfit: 7.93e+01
# itreação: 122   r: 500.93   z: 599.86   misfit: 7.93e+01
# itreação: 123   r: 500.91   z: 599.94   misfit: 7.93e+01
# itreação: 124   r: 500.90   z: 600.01   misfit: 7.93e+01
# itreação: 125   r: 500.88   z: 600.08   misfit: 7.93e+01
# itreação: 126   r: 500.86   z: 600.15   misfit: 7.93e+01
# itreação: 127   r: 500.84   z: 600.22   misfit: 7.93e+01
# itreação: 128   r: 500.83   z: 600.29   misfit: 7.93e+01
# itreação: 129   r: 500.81   z: 600.35   misfit: 7.93e+01
# itreação: 130   r: 500.79   z: 600.42   misfit: 7.93e+01
# itreação: 131   r: 500.78   z: 600.48   misfit: 7.93e+01
# itreação: 132   r: 500.76   z: 600.54   misfit: 7.93e+01
# itreação: 133   r: 500.75   z: 600.59   misfit: 7.93e+01
# itreação: 134   r: 500.74   z: 600.65   misfit: 7.93e+01
# itreação: 135   r: 500.72   z: 600.71   misfit: 7.93e+01
# itreação: 136   r: 500.71   z: 600.76   misfit: 7.93e+01
# itreação: 137   r: 500.70   z: 600.81   misfit: 7.93e+01
# itreação: 138   r: 500.68   z: 600.86   misfit: 7.93e+01
# itreação: 139   r: 500.67   z: 600.91   misfit: 7.93e+01
# itreação: 140   r: 500.66   z: 600.96   misfit: 7.93e+01
# itreação: 141   r: 500.65   z: 601.00   misfit: 7.93e+01
# itreação: 142   r: 500.64   z: 601.05   misfit: 7.93e+01
# itreação: 143   r: 500.63   z: 601.09   misfit: 7.93e+01
# itreação: 144   r: 500.62   z: 601.14   misfit: 7.93e+01
# itreação: 145   r: 500.61   z: 601.18   misfit: 7.93e+01
# itreação: 146   r: 500.60   z: 601.22   misfit: 7.93e+01
# itreação: 147   r: 500.59   z: 601.26   misfit: 7.93e+01
# itreação: 148   r: 500.58   z: 601.30   misfit: 7.93e+01
# itreação: 149   r: 500.57   z: 601.33   misfit: 7.93e+01
# itreação: 150   r: 500.56   z: 601.37   misfit: 7.93e+01
# itreação: 151   r: 500.55   z: 601.40   misfit: 7.93e+01
# itreação: 152   r: 500.54   z: 601.44   misfit: 7.93e+01
# itreação: 153   r: 500.53   z: 601.47   misfit: 7.93e+01
# itreação: 154   r: 500.52   z: 601.50   misfit: 7.93e+01
# itreação: 155   r: 500.52   z: 601.54   misfit: 7.93e+01
# itreação: 156   r: 500.51   z: 601.57   misfit: 7.93e+01
# itreação: 157   r: 500.50   z: 601.60   misfit: 7.93e+01
# itreação: 158   r: 500.49   z: 601.63   misfit: 7.93e+01
# itreação: 159   r: 500.49   z: 601.65   misfit: 7.93e+01
# itreação: 160   r: 500.48   z: 601.68   misfit: 7.93e+01
# itreação: 161   r: 500.47   z: 601.71   misfit: 7.93e+01
# itreação: 162   r: 500.47   z: 601.73   misfit: 7.93e+01
# itreação: 163   r: 500.46   z: 601.76   misfit: 7.93e+01
# itreação: 164   r: 500.45   z: 601.78   misfit: 7.93e+01
# itreação: 165   r: 500.45   z: 601.81   misfit: 7.93e+01
# itreação: 166   r: 500.44   z: 601.83   misfit: 7.93e+01
# itreação: 167   r: 500.44   z: 601.85   misfit: 7.93e+01
# itreação: 168   r: 500.43   z: 601.88   misfit: 7.93e+01
# itreação: 169   r: 500.43   z: 601.90   misfit: 7.93e+01
# itreação: 170   r: 500.42   z: 601.92   misfit: 7.93e+01
# itreação: 171   r: 500.42   z: 601.94   misfit: 7.93e+01
# itreação: 172   r: 500.41   z: 601.96   misfit: 7.93e+01
# itreação: 173   r: 500.41   z: 601.98   misfit: 7.93e+01
# itreação: 174   r: 500.40   z: 602.00   misfit: 7.93e+01
# itreação: 175   r: 500.40   z: 602.02   misfit: 7.93e+01
# itreação: 176   r: 500.39   z: 602.03   misfit: 7.93e+01
# itreação: 177   r: 500.39   z: 602.05   misfit: 7.93e+01
# itreação: 178   r: 500.38   z: 602.07   misfit: 7.93e+01
# itreação: 179   r: 500.38   z: 602.08   misfit: 7.93e+01
# itreação: 180   r: 500.38   z: 602.10   misfit: 7.93e+01
# itreação: 181   r: 500.37   z: 602.12   misfit: 7.93e+01
# itreação: 182   r: 500.37   z: 602.13   misfit: 7.93e+01
# itreação: 183   r: 500.36   z: 602.14   misfit: 7.93e+01
# itreação: 184   r: 500.36   z: 602.16   misfit: 7.93e+01
# itreação: 185   r: 500.36   z: 602.17   misfit: 7.93e+01
# itreação: 186   r: 500.35   z: 602.19   misfit: 7.93e+01
# itreação: 187   r: 500.35   z: 602.20   misfit: 7.93e+01
# itreação: 188   r: 500.35   z: 602.21   misfit: 7.93e+01
# itreação: 189   r: 500.34   z: 602.23   misfit: 7.93e+01
# itreação: 190   r: 500.34   z: 602.24   misfit: 7.93e+01
# itreação: 191   r: 500.34   z: 602.25   misfit: 7.93e+01
# itreação: 192   r: 500.34   z: 602.26   misfit: 7.93e+01
# itreação: 193   r: 500.33   z: 602.27   misfit: 7.93e+01
# itreação: 194   r: 500.33   z: 602.28   misfit: 7.93e+01
# itreação: 195   r: 500.33   z: 602.29   misfit: 7.93e+01
# itreação: 196   r: 500.33   z: 602.30   misfit: 7.93e+01
# itreação: 197   r: 500.32   z: 602.31   misfit: 7.93e+01
# itreação: 198   r: 500.32   z: 602.32   misfit: 7.93e+01
# itreação: 199   r: 500.32   z: 602.33   misfit: 7.93e+01
# itreação: 200   r: 500.32   z: 602.34   misfit: 7.93e+01
# itreação: 201   r: 500.31   z: 602.35   misfit: 7.93e+01
# itreação: 202   r: 500.31   z: 602.36   misfit: 7.93e+01
# itreação: 203   r: 500.31   z: 602.37   misfit: 7.93e+01
# itreação: 204   r: 500.31   z: 602.38   misfit: 7.93e+01
# itreação: 205   r: 500.31   z: 602.39   misfit: 7.93e+01
# itreação: 206   r: 500.30   z: 602.39   misfit: 7.93e+01
# itreação: 207   r: 500.30   z: 602.40   misfit: 7.93e+01
# itreação: 208   r: 500.30   z: 602.41   misfit: 7.93e+01
# itreação: 209   r: 500.30   z: 602.42   misfit: 7.93e+01
# itreação: 210   r: 500.30   z: 602.42   misfit: 7.93e+01
# itreação: 211   r: 500.29   z: 602.43   misfit: 7.93e+01
# itreação: 212   r: 500.29   z: 602.44   misfit: 7.93e+01
# itreação: 213   r: 500.29   z: 602.44   misfit: 7.93e+01
# itreação: 214   r: 500.29   z: 602.45   misfit: 7.93e+01
# itreação: 215   r: 500.29   z: 602.45   misfit: 7.93e+01
# itreação: 216   r: 500.29   z: 602.46   misfit: 7.93e+01
# itreação: 217   r: 500.29   z: 602.47   misfit: 7.93e+01
# itreação: 218   r: 500.28   z: 602.47   misfit: 7.93e+01
# itreação: 219   r: 500.28   z: 602.48   misfit: 7.93e+01
# itreação: 220   r: 500.28   z: 602.48   misfit: 7.93e+01
# itreação: 221   r: 500.28   z: 602.49   misfit: 7.93e+01
# itreação: 222   r: 500.28   z: 602.49   misfit: 7.93e+01
# itreação: 223   r: 500.28   z: 602.50   misfit: 7.93e+01
# itreação: 224   r: 500.28   z: 602.50   misfit: 7.93e+01
# itreação: 225   r: 500.27   z: 602.51   misfit: 7.93e+01
# itreação: 226   r: 500.27   z: 602.51   misfit: 7.93e+01
# itreação: 227   r: 500.27   z: 602.52   misfit: 7.93e+01
# itreação: 228   r: 500.27   z: 602.52   misfit: 7.93e+01
# itreação: 229   r: 500.27   z: 602.53   misfit: 7.93e+01
# itreação: 230   r: 500.27   z: 602.53   misfit: 7.93e+01
# itreação: 231   r: 500.27   z: 602.53   misfit: 7.93e+01
# itreação: 232   r: 500.27   z: 602.54   misfit: 7.93e+01
# itreação: 233   r: 500.27   z: 602.54   misfit: 7.93e+01
# itreação: 234   r: 500.27   z: 602.55   misfit: 7.93e+01
# itreação: 235   r: 500.26   z: 602.55   misfit: 7.93e+01
# itreação: 236   r: 500.26   z: 602.55   misfit: 7.93e+01
# itreação: 237   r: 500.26   z: 602.56   misfit: 7.93e+01
# itreação: 238   r: 500.26   z: 602.56   misfit: 7.93e+01
# itreação: 239   r: 500.26   z: 602.56   misfit: 7.93e+01
# itreação: 240   r: 500.26   z: 602.57   misfit: 7.93e+01
# itreação: 241   r: 500.26   z: 602.57   misfit: 7.93e+01
# itreação: 242   r: 500.26   z: 602.57   misfit: 7.93e+01
# itreação: 243   r: 500.26   z: 602.57   misfit: 7.93e+01
# itreação: 244   r: 500.26   z: 602.58   misfit: 7.93e+01
# itreação: 245   r: 500.26   z: 602.58   misfit: 7.93e+01
# itreação: 246   r: 500.26   z: 602.58   misfit: 7.93e+01
# itreação: 247   r: 500.26   z: 602.59   misfit: 7.93e+01
# itreação: 248   r: 500.26   z: 602.59   misfit: 7.93e+01
# itreação: 249   r: 500.25   z: 602.59   misfit: 7.93e+01
# itreação: 250   r: 500.25   z: 602.59   misfit: 7.93e+01
# itreação: 251   r: 500.25   z: 602.59   misfit: 7.93e+01
# itreação: 252   r: 500.25   z: 602.60   misfit: 7.93e+01
# itreação: 253   r: 500.25   z: 602.60   misfit: 7.93e+01
# itreação: 254   r: 500.25   z: 602.60   misfit: 7.93e+01
# itreação: 255   r: 500.25   z: 602.60   misfit: 7.93e+01
# itreação: 256   r: 500.25   z: 602.61   misfit: 7.93e+01
# itreação: 257   r: 500.25   z: 602.61   misfit: 7.93e+01
# itreação: 258   r: 500.25   z: 602.61   misfit: 7.93e+01
# itreação: 259   r: 500.25   z: 602.61   misfit: 7.93e+01
# itreação: 260   r: 500.25   z: 602.61   misfit: 7.93e+01
# itreação: 261   r: 500.25   z: 602.62   misfit: 7.93e+01
# itreação: 262   r: 500.25   z: 602.62   misfit: 7.93e+01
# itreação: 263   r: 500.25   z: 602.62   misfit: 7.93e+01
# itreação: 264   r: 500.25   z: 602.62   misfit: 7.93e+01
# itreação: 265   r: 500.25   z: 602.62   misfit: 7.93e+01
# itreação: 266   r: 500.25   z: 602.62   misfit: 7.93e+01
# itreação: 267   r: 500.25   z: 602.62   misfit: 7.93e+01
# itreação: 268   r: 500.25   z: 602.63   misfit: 7.93e+01
# itreação: 269   r: 500.25   z: 602.63   misfit: 7.93e+01
# itreação: 270   r: 500.24   z: 602.63   misfit: 7.93e+01
# itreação: 271   r: 500.24   z: 602.63   misfit: 7.93e+01
# itreação: 272   r: 500.24   z: 602.63   misfit: 7.93e+01
# itreação: 273   r: 500.24   z: 602.63   misfit: 7.93e+01
# itreação: 274   r: 500.24   z: 602.63   misfit: 7.93e+01
# itreação: 275   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 276   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 277   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 278   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 279   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 280   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 281   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 282   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 283   r: 500.24   z: 602.64   misfit: 7.93e+01
# itreação: 284   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 285   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 286   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 287   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 288   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 289   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 290   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 291   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 292   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 293   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 294   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 295   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 296   r: 500.24   z: 602.65   misfit: 7.93e+01
# itreação: 297   r: 500.24   z: 602.66   misfit: 7.93e+01

# %%
#plot
plt.figure(figsize=(5,5))
plt.plot(cylinder_model['r'], cylinder_model['z0'] + cylinder_model['dz'], 'og')
plt.plot(p1_list, p2_list, '.w-', markersize=5)
plt.title('SD - geofisica', fontsize=18)
plt.contourf(cylinder_bottom_data['p1'], cylinder_bottom_data['p2'], cylinder_bottom_data['phi_eq'], 40, cmap='jet')
plt.xlabel('$p_1$', fontsize=18)
plt.ylabel('$p_2$', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.savefig('plot_SD_geofisica-base.png', pad_inches=0.0)
plt.show()

# %%
plt.title('Convergence', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('Phi value')
plt.plot(phi_list, 'o')
plt.savefig('convergence_SD_geofisica-base.png', dpi=300)
plt.show()

# %%
res = res.reshape(regular_grid['shape'])
xp = regular_grid['xp'].reshape(regular_grid['shape'])
yp = regular_grid['yp'].reshape(regular_grid['shape'])
dpred = cylinder_bottom_data['data'].reshape(regular_grid['shape'])
dobs = cylinder_bottom_data['data_noise'].reshape(regular_grid['shape'])

# %%
# plot
plt.figure(figsize=(30,10))
plt.subplot(1, 3, 1)
plt.title('Dado observado', fontsize=18)
plt.contourf(yp, xp, dobs, 40, cmap='jet')
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)

plt.subplot(1, 3, 2)
plt.title('SD - ajuste', fontsize=18)
plt.contourf(yp, xp, res, 40, cmap='jet')
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.show()

plt.subplot(1, 3, 3)
plt.axis('auto')
plt.title('Histograma', fontsize = 18)
plt.xlabel('$\mu$ = %.7f  $\sigma$ = %.7f' % (np.mean(res), np.std(res)), fontsize=15)
nbins = int((np.max(res) - np.min(res)))
plt.hist(res,bins=nbins, normed=True)
plt.ylim(0.,0.5)
plt.xlim(-10., 10.)
plt.savefig('plot_SD_ajuste_base.png', pad_inches=0.0)
plt.show()
