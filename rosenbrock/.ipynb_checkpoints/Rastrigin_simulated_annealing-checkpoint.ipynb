# %% [markdown]
# # Steepest descent aplicado à função Rosenbrock

# %% [markdown]
# Este algoritmo aplica o método de otimização Steepest descent à função matemática de Rosenbrock, a qual é definida pela equação geral:

# %% [markdown]
# \begin{equation}
# f(x,y) = (a - x)^2 + b(y - x^2)^2 ,
# \end{equation}

# %% [markdown]
# onde $a$ e $b$ são constantes e o mínimo dessa função é $(x,y)=(a,a^2)$, onde $f(a,a^2)=0$. Normalmente $a$ e $b$ são iguais a 1 e a 100, respectivamente, nesse caso, o mínimo dessa função é $(x,y)=(1,1)$.

# %% [markdown]
# Então a função a ser minimizada através do método steepest descente é:

# %% [markdown]
# \begin{equation}
# f(p_1,p_2) = 100(p_2 - p_1^2)^2 + (p_1 - 1)^2 ,
# \end{equation}

# %% [markdown]
# A proposta do código é encontrar o mínimo da função através de muitas iterações.

# %% [markdown]
# O método steepest descent é um método de convergência global, o qual se aproxima do mínimo com a direção de $-\nabla \boldsymbol{\phi}(\mathbf{p})$, que é menos o gradiente da função objetivo e $\mathbf{p}$ é o vetor de parâmentros. O método possui o seguinte algoritmo:

# %% [markdown]
# 1) estabelece um chute inicial $\mathbf{p}_i$
#
# 2) determina a direção $\mathbf{a}_i$ que diminua $\boldsymbol{\phi}$ em torno de $\mathbf{p}_i$
#
# 3) calcula $\mathbf{p}_{i+1} = \mathbf{p}_i + \rho _i \mathbf{a}_i$, onde $\rho_i$ é um escalar que modula o passo em direção ao mínimo e $\mathbf{a}_i = -\nabla \boldsymbol{\phi}(\mathbf{p})$
#
# 4) testa a convergência, se for satisfeita o algoritmo para, caso contrário retorna para 1)

# %% [markdown]
# # Importando pacotes

# %%
import numpy as np
import matplotlib.pyplot as plt
from visual import histeq

# %% [markdown]
# # Funções

# %%
# calculando a phi
def rastrigin(p0):
    '''
    Calcula a função de Rosenbrock
    
    entrada
    p0: array 1D - contém duas componentes que podem ser arrays 1D
    
    output
    phi: array 1D - valor da função calculada em cada ponto (p1, p2)
    '''
    phi = 10.*2 + p0[0]*p0[0] + p0[1]*p0[1] - 10.*np.cos(2.*np.pi*p0[0]) - 10.*np.cos(2.*np.pi*p0[1])
    #phi *= 100.
    
    return phi

# %% [markdown]
# ## Plotando a função

# %%
# numero de parametros de p1 e p2
np1 = 50
np2 = 50

#definindo os parâmetros
p1 = np.linspace(-5., 5., np1)
p2 = np.linspace(-5., 5., np2)

#criando um grid
p1, p2 = np.meshgrid(p1, p2)

# calculando a phi
phi = rastrigin([p1,p2])

# equalizando as cores
phi_eq = histeq(phi)
phi_eq = np.reshape(phi_eq,(np1,np2))

#plot
plt.figure(figsize=(5,5))
plt.plot(0., 0., 'oy')
plt.title('Funcao Rosenbrock', fontsize=18)
plt.contourf(p1, p2, phi_eq, 100, cmap='jet')
plt.xlabel('$p_1$', fontsize=18)
plt.ylabel('$p_2$', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.savefig('plot_rosenbrock.png', pad_inches=0.0)
plt.show()

# %%
# chute inicial
p01 = 3.5
p02 = -3.5

# chute inicial e temperatura inicial
p0 = np.array([p01,p02])
T = 500.

phi0 = rastrigin(p0)

p1_list = [p01]
p2_list = [p02]
phi_list = [phi0]

itmax = 100

kb = 1.38064852*1e-23

# %%
pm = p0.copy()
phim = phi0
p = pm.copy()
phi = phi0

for it in range(itmax):
  
    
    for j in range(15):
        # perturbando a solução
        rand = float(2*np.random.random(1) - 1.)
        #print rand
        p_vizinho = p + T*rand
        #print p_vizinho
        # calculando a função e a variação
        phi_vizinho = rastrigin(p_vizinho)
        delta_phi = phi_vizinho - phi
        #print delta_phi
        # avaliando a função do vizinho
        if delta_phi < 0.:
            p = p_vizinho.copy()
            phi = rastrigin(p)
            #print p, phi
            if phi < phim:
                pm = p.copy()
                phim = rastrigin(pm)
                # armazenando os resultados em listas para o plot
                phi_list.append(phim)
                p1_list.append(pm[0])
                p2_list.append(pm[1])
                print 'break'
                break
            else:
                P = np.exp(-delta_phi/T)
                if abs(rand) <= P:
                    p = p_vizinho.copy()
                else:
                    break
        #print pm, phim, p, phi, p_vizinho, phi_vizinho
                    
    print 'iteração: %3d   p1: %.2f   p2: %.2f   f: %.5e    T: %.2f' % (it, pm[0], pm[1], phim, T)
    
    #alfa = 0.01
    #T -= alfa
    T = T/(1 + np.sqrt(T))
    print T
    

        

        # armazenando os resultados em listas para o plot
        #phi_list.append(phi0)
        #p1_list.append(p0[0])
        #p2_list.append(p0[1])
    
    # printa os valores
    #print 'vetor de parametros', p0
    #print 'valor da funcao', phi0
    #print 'vetor gradiente', grad
# Out:
# iteração:   0   p1: 3.50   p2: -3.50   f: 6.45000e+01    T: 500.00
# 21.4034867485
# iteração:   1   p1: 3.50   p2: -3.50   f: 6.45000e+01    T: 21.40
# 3.8041241002
# break
# iteração:   2   p1: 1.99   p2: -5.01   f: 2.91321e+01    T: 3.80
# 1.28935160175
# break
# iteração:   3   p1: 3.10   p2: -3.90   f: 2.89480e+01    T: 1.29
# 0.603771435725
# break
# iteração:   4   p1: 3.06   p2: -3.94   f: 2.64106e+01    T: 0.60
# 0.339764860882
# break
# iteração:   5   p1: 2.95   p2: -4.05   f: 2.59966e+01    T: 0.34
# 0.214647956813
# break
# iteração:   6   p1: 3.01   p2: -3.99   f: 2.50033e+01    T: 0.21
# 0.146687478937
# iteração:   7   p1: 3.01   p2: -3.99   f: 2.50033e+01    T: 0.15
# 0.106064851448
# break
# iteração:   8   p1: 3.00   p2: -4.00   f: 2.49980e+01    T: 0.11
# 0.0800081257618
# iteração:   9   p1: 3.00   p2: -4.00   f: 2.49980e+01    T: 0.08
# 0.0623671391174
# iteração:  10   p1: 3.00   p2: -4.00   f: 2.49980e+01    T: 0.06
# 0.0499043254701
# iteração:  11   p1: 3.00   p2: -4.00   f: 2.49980e+01    T: 0.05
# 0.0407917449563
# iteração:  12   p1: 3.00   p2: -4.00   f: 2.49980e+01    T: 0.04
# 0.0339374163896
# iteração:  13   p1: 3.00   p2: -4.00   f: 2.49980e+01    T: 0.03
# 0.0286580066672
# break
# iteração:  14   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.03
# 0.0245089636518
# iteração:  15   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.02
# 0.0211913811173
# iteração:  16   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.02
# 0.0184985056077
# iteração:  17   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.02
# 0.0162837637413
# iteração:  18   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.02
# 0.0144409811629
# iteração:  19   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.0128917691025
# iteração:  20   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.0115772642181
# iteração:  21   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.0104525896526
# iteração:  22   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00948306131106
# iteração:  23   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00864153946138
# iteração:  24   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00790654772623
# iteração:  25   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00726091600336
# iteração:  26   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00669078727101
# iteração:  27   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00618488111174
# iteração:  28   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00573394097138
# iteração:  29   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00533031467127
# iteração:  30   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.01
# 0.00496763275163
# break
# iteração:  31   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00464055945936
# iteração:  32   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00434459824969
# iteração:  33   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00407593859972
# iteração:  34   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.0038313344179
# iteração:  35   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00360800682697
# iteração:  36   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00340356590102
# iteração:  37   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00321594725428
# iteração:  38   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00304336035078
# iteração:  39   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00288424612604
# iteração:  40   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00273724205472
# iteração:  41   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00260115320766
# iteração:  42   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.0024749281544
# iteração:  43   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.0023576388071
# iteração:  44   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00224846348671
# iteração:  45   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00214667263689
# iteração:  46   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.0020516167232
# iteração:  47   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00196271594436
# iteração:  48   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00187945145226
# iteração:  49   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.0018013578334
# iteração:  50   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00172801664908
# iteração:  51   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00165905086737
# iteração:  52   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00159412004926
# iteração:  53   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00153291617439
# iteração:  54   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00147516001126
# iteração:  55   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00142059795239
# iteração:  56   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00136899924745
# iteração:  57   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00132015357847
# iteração:  58   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00127386892957
# iteração:  59   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00122996971104
# iteração:  60   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00118829510375
# iteração:  61   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00114869759481
# iteração:  62   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00111104167961
# iteração:  63   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00107520270912
# iteração:  64   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00104106586402
# iteração:  65   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00100852524016
# iteração:  66   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000977483031566
# iteração:  67   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000947848799475
# iteração:  68   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00091953881708
# iteração:  69   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00089247548122
# iteração:  70   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000866586783303
# iteração:  71   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000841805832748
# iteração:  72   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000818070427085
# iteração:  73   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000795322663554
# iteração:  74   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000773508587705
# iteração:  75   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000752577875018
# iteração:  76   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000732483542053
# iteração:  77   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000713181684037
# iteração:  78   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000694631236171
# iteração:  79   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000676793756226
# iteração:  80   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000659633226297
# iteração:  81   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000643115871807
# iteração:  82   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000627209996072
# iteração:  83   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00061188582891
# iteração:  84   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000597115387954
# iteração:  85   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000582872351471
# iteração:  86   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000569131941596
# iteração:  87   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.00055587081703
# iteração:  88   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000543066974333
# iteração:  89   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000530699657033
# iteração:  90   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000518749271851
# iteração:  91   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000507197311415
# iteração:  92   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.0004960262829
# iteração:  93   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000485219642066
# iteração:  94   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000474761732251
# iteração:  95   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000464637727883
# iteração:  96   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000454833582146
# iteração:  97   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000445335978441
# iteração:  98   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000436132285339
# iteração:  99   p1: 3.00   p2: -4.00   f: 2.49975e+01    T: 0.00
# 0.000427210514749

# %%
print phi_list
# Out:
# [64.5, 29.132129817453517, 28.947983762828713, 26.41063780560355, 25.996598941643178, 25.003297498875181, 24.997965780102078, 24.997480010937718, 24.997479685844237]

# %%
#plot
plt.figure(figsize=(5,5))
plt.plot(0., 0., 'oy')
plt.plot(p1_list, p2_list, '.w', markersize=5)
plt.title('SD - Rosenbrock', fontsize=18)
plt.contourf(p1, p2, phi_eq, 40, cmap='jet')
plt.xlabel('$p_1$', fontsize=18)
plt.ylabel('$p_2$', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.savefig('plot_rosenbrock.png', pad_inches=0.0)
plt.show()

# %%
plt.title('Convergence', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('Phi value')
plt.plot(phi_list, 'o')
plt.savefig('convergence.png', dpi=300)
plt.show()
