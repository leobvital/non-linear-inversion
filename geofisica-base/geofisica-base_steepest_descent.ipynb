# %% [markdown]
# # Steepest descent aplicado à função geofísica

# %% [markdown]
# Algoritmo de Steepest Descent aplicado a um problema geofísico para estimar o raio e a coordenada z da base de um prisma de base poligonal próximo de um cilindro.

# %% [markdown]
# # Importando pacotes

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
from visual import histeq
from fatiando import utils
from fatiando.mesher import PolygonalPrism
from IPython.display import Image as img
from fatiando.gravmag import polyprism
from copy import deepcopy
from fatiando.vis import myv
from fatiando.gridder import regular
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# # Funções para o prisma de base polygonal do fatiando

# %%
def pol2cart(l, M, L):
    '''
    This function transforms polar coordinates of the prisms
    into Cartesian coordinates and returns a list of polygonal
    prisms of the Fatiando a Terra.

    input

    l: list - each element is a list of [r, x0, y0, z1, z2, 'magnetization'],
              whrere r is an array with the radial distances of the vertices,
              x0 and y0 are the origin cartesian coordinates of each prism,
              z1 and z2 are the top and bottom of each prism and
              magnetization is physical property
    M: int - number of vertices per prism
    L: int - number of prisms

    output

    mk: list - list of objects of the class
    fatiando.mesher.PolygonalPrism
    '''

    lk = []
    r = np.zeros(M)  # it contains radial distances of the vertices in polar coordinates
    verts = [] # it contains radial distances of the vertices in Cartesian coordinates

    assert len(l) == L, 'The size of m and the number of prisms must be equal'

    for lv in l:
        assert len(lv[0]) == M, 'All prisms must have M vertices'

    ang = 2*np.pi/M # angle between two vertices

    for lv in l:
        r = lv[0]
        verts=[]
        for i in range(M):
            verts.append([r[i]*np.cos(i*ang) + lv[1], r[i]*np.sin(i*ang) + lv[2]])
        lk.append(PolygonalPrism(verts, lv[3], lv[4], lv[5]))

    return lk

def param2polyprism(m, M, L, z0, dz, props):
    '''
    Returns a lis of objects of the class
    fatiando.mesher.PolygonalPrism

    input

    m: 1D array - parameter vector
    M: int - number of vertices
    L: int - number of prisms
    z0: float - top of the model
    dz: float - thickness of each prism
    props: dictionary - physical property

    output

    mv: list - list of fatiando.mesher.PolygonalPrism
    '''
    P = L*(M + 2)
    assert m.size == P, 'The size of m must be equal to L*(M + 2)'
    for i in range(P):
        assert m[i:i+M].all >= 0., 'The radial distances must be positives'

    r = np.zeros(M) # vector for radial distances
    mv = [] # list of prisms

    k = 0.
    for i in range(0, P, M + 2):
        r = m[i:M+i]
        mv.append([r, m[i+M], m[i+M+1], z0 + dz*k, z0 + dz*(k + 1.), props])
        k = k + 1.

    mv = pol2cart(mv, M, L)

    return mv

# %% [markdown]
# # Modelagem direta

# %%
M = 10 # number of vertices per prism
L = 1 # number of prisms
P = L*(M+2) # number of parameters

z0 = 100.    # depth of the top the shallowest prism
dz_true = 500.    # thickness of each prism

inc = -60.  # inclination
dec = 50.   # declination
intensity = 0.035 # intensity

props={'magnetization': utils.ang2vec(intensity, inc, dec)} # physical property: magnetization

r_true = 500.

r = np.zeros(M) + r_true # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

l = [[r, x0, y0, z0, z0 + dz_true, props]]   # list of parameters of the prisms

# criando os prismas do fatiando
prisms = pol2cart(l, M, L)

# %%
img(filename='bolacha.png')

# %% [markdown]
# # Pontos de observação

# %%
area = [-2000, 2000, -2000, 2000] #x minimum, x maximum, y minimum and y maximum
shape = (50,50) #number of data along the y and x directions
N = shape[0]*shape[1] #total number of data

#coordinates x and y of the data
xp, yp = regular(area, shape)

zp = np.zeros(N) - 100.

# %% [markdown]
# # Dados observados

# %%
data = polyprism.tf(xp, yp, zp, prisms, inc, dec) # predict data
amp_noise = 0.01*np.max(data)
data_noise = data + np.random.normal(loc=0., scale=amp_noise, size=shape[0]*shape[1]) # noise corrupted data

# %% [markdown]
# # Plot função desajuste

# %%
r_plot = np.linspace(100., 1000., 20)
dz_plot = np.linspace(10., 1000., 20)
r_plot,dz_plot = np.meshgrid(r_plot, dz_plot)
r_plot = r_plot.ravel()
dz_plot = dz_plot.ravel()
phi_plot = np.zeros_like(r_plot)

for i, (r, dz) in enumerate(zip(r_plot,dz_plot)):
    m = np.zeros(M) + r
    m = np.hstack((m,np.zeros(2)))
    l = param2polyprism(m, M, L, z0, z0 + dz, props)
    d_pred = polyprism.tf(xp, yp, zp, l, inc, dec)
    phi_plot[i] = np.sum((data - d_pred)**2)

r_plot = r_plot.reshape((20,20))
dz_plot = dz_plot.reshape((20,20))
phi_plot = phi_plot.reshape((20,20))

# equalizando as cores
phi_eq = histeq(phi_plot)
phi_eq = np.reshape(phi_eq,(20,20))
phi_eq = phi_eq

# %%
plt.figure(figsize=(5,5))
plt.plot(r_true, dz_true, 'og')
plt.title('Funcao objetivo', fontsize=18)
plt.contourf(r_plot, dz_plot, phi_eq, 50, cmap='jet')
plt.xlabel('$r$ (m)', fontsize=18)
plt.ylabel('$dz$ (m)', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.show()

# %% [markdown]
# # Funções

# %%
def derivative_tf_z(xp, yp, zp, prism, M, deltaz, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of one fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    delta: float - increment in x coordinate in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - deltaa
    prism_plus[0].z2 += deltaz
    prism_minus[0].z2 -= deltaz

    df = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df -= polyprism.tf(xp, yp, zp, prism_minus, inc, dec)
    df /= (2.*deltaz)

    return df

def derivative_tf_radiall(xp, yp, zp, prism, M, deltar, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of a fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in radial distance in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'
    
    ang = 2.*np.pi/M # angle between two vertices
    
    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - delta

    for i in range(M):
        deltax = deltar*np.cos(i*ang)
        deltay = deltar*np.sin(i*ang)
        prism_plus[0].x[i] += deltax
        prism_plus[0].y[i] += deltay
        prism_minus[0].x[i] -= deltax
        prism_minus[0].y[i] -= deltay

    df = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df -= polyprism.tf(xp, yp, zp, prism_minus, inc, dec)
    df /= (2.*deltar)

    return df

# calculando jacobiana de phi
def jacobi_geo(xp, yp, zp, prism, M, deltar, deltaz, inc, dec):
    '''
    Returns the sensitivity matrix for polygonal prisms using finite
    differences.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in meters for radial distance
    deltaz: float - increment in meters for depth
    inc: float - inclination of the local-geomagnetic field
    dec: declination of the local-geomagnetic field

    output

    G: 2D array - sensitivity matrix
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    G = np.zeros((xp.size, 2))

    G[:, 0] = derivative_tf_radiall(xp, yp, zp, prism[0], M, deltar, inc, dec)
    G[:, 1] = derivative_tf_z(xp, yp, zp, prism[0], M, deltaz, inc, dec)

    return G

# %% [markdown]
# # Modelo interpretativo

# %%
# chute inicial
p01 = 100.
p02 = 400.

# incremento para as derivadas
deltar = 0.01*p01
deltaz = 0.01*p02

r = np.zeros(M) + p01 # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

l = [[r, x0, y0, z0, z0 + p02, props]]

prism0 = pol2cart(l, M, L)

d0 = polyprism.tf(xp, yp, zp, prism0, inc, dec)

# vetor do chute inicial
p0 = np.array([p01,p02]) 

# parâmetro de regulazrização
mi = 0.000000

# tamanho do passo
lamb = 1.

# critério de parada
epsilon = 0.00000001

# calculando o valor da função e do resíduo em p0
res0 = data_noise - d0
phi0 = np.sum(res0*res0)

# listas para armazenar as estimativas
p1_list = [p01]
p2_list = [p02]
phi_list = [phi0]

# iterações do algoritmo
itmax = 1000

# %% [markdown]
# # Algoritmo Steepest Descent

# %%
for i in range(itmax):
    # calculando a Jacobiana e o gradiente
    G = jacobi_geo(xp, yp, zp, prism0, M, deltar, deltaz, inc, dec)
    grad = -2.*np.dot(G.T, res0) + mi*p0
    #print grad
    # calculando p e atualizando para a próxima iteração
    p = p0 - lamb*grad
    #print p, p0
    l = [[np.zeros(M) + p[0], x0, y0, z0, z0 + p[1], props]]
    prism = pol2cart(l, M, L)
    d = polyprism.tf(xp, yp, zp, prism, inc, dec)
    res = data_noise - d
    phi = np.sum(res*res) + mi*np.dot(p0, p0)
    
    # printa os valores
    print 'itreação: %3d   r: %.2f   dz: %.2f   misfit: %.2e' % (i, p[0], p[1], phi)
    
    # armazenando os resultados em listas para o plot
    phi_list.append(phi)
    p1_list.append(p[0])
    p2_list.append(p[1])
    
    if (abs(phi-phi0)/phi0 <= epsilon):
        break
    else:
        # atualizando parâmetros
        p0 = p.copy()
        d0 = d.copy()
        res0 = res.copy()
        phi0 = phi
        prism0 = prism
# Out:
# itreação:   0   r: 109.46   z0: 400.61   misfit: 4.54e+03
# itreação:   1   r: 119.59   z0: 401.32   misfit: 4.44e+03
# itreação:   2   r: 130.38   z0: 402.16   misfit: 4.32e+03
# itreação:   3   r: 141.83   z0: 403.13   misfit: 4.18e+03
# itreação:   4   r: 153.89   z0: 404.25   misfit: 4.03e+03
# itreação:   5   r: 166.53   z0: 405.53   misfit: 3.87e+03
# itreação:   6   r: 179.69   z0: 406.98   misfit: 3.69e+03
# itreação:   7   r: 193.32   z0: 408.60   misfit: 3.50e+03
# itreação:   8   r: 207.34   z0: 410.39   misfit: 3.29e+03
# itreação:   9   r: 221.67   z0: 412.36   misfit: 3.08e+03
# itreação:  10   r: 236.23   z0: 414.50   misfit: 2.86e+03
# itreação:  11   r: 250.92   z0: 416.79   misfit: 2.64e+03
# itreação:  12   r: 265.66   z0: 419.21   misfit: 2.42e+03
# itreação:  13   r: 280.35   z0: 421.76   misfit: 2.20e+03
# itreação:  14   r: 294.89   z0: 424.40   misfit: 1.98e+03
# itreação:  15   r: 309.19   z0: 427.11   misfit: 1.77e+03
# itreação:  16   r: 323.16   z0: 429.86   misfit: 1.57e+03
# itreação:  17   r: 336.73   z0: 432.63   misfit: 1.38e+03
# itreação:  18   r: 349.81   z0: 435.38   misfit: 1.21e+03
# itreação:  19   r: 362.35   z0: 438.10   misfit: 1.05e+03
# itreação:  20   r: 374.29   z0: 440.75   misfit: 9.02e+02
# itreação:  21   r: 385.59   z0: 443.33   misfit: 7.71e+02
# itreação:  22   r: 396.23   z0: 445.80   misfit: 6.55e+02
# itreação:  23   r: 406.19   z0: 448.17   misfit: 5.54e+02
# itreação:  24   r: 415.47   z0: 450.41   misfit: 4.66e+02
# itreação:  25   r: 424.06   z0: 452.53   misfit: 3.91e+02
# itreação:  26   r: 432.00   z0: 454.52   misfit: 3.27e+02
# itreação:  27   r: 439.29   z0: 456.37   misfit: 2.72e+02
# itreação:  28   r: 445.97   z0: 458.10   misfit: 2.27e+02
# itreação:  29   r: 452.06   z0: 459.70   misfit: 1.89e+02
# itreação:  30   r: 457.61   z0: 461.17   misfit: 1.58e+02
# itreação:  31   r: 462.64   z0: 462.53   misfit: 1.32e+02
# itreação:  32   r: 467.20   z0: 463.77   misfit: 1.10e+02
# itreação:  33   r: 471.32   z0: 464.92   misfit: 9.30e+01
# itreação:  34   r: 475.03   z0: 465.96   misfit: 7.88e+01
# itreação:  35   r: 478.37   z0: 466.91   misfit: 6.73e+01
# itreação:  36   r: 481.38   z0: 467.78   misfit: 5.81e+01
# itreação:  37   r: 484.07   z0: 468.58   misfit: 5.06e+01
# itreação:  38   r: 486.49   z0: 469.30   misfit: 4.45e+01
# itreação:  39   r: 488.65   z0: 469.96   misfit: 3.97e+01
# itreação:  40   r: 490.59   z0: 470.56   misfit: 3.58e+01
# itreação:  41   r: 492.32   z0: 471.11   misfit: 3.27e+01
# itreação:  42   r: 493.86   z0: 471.61   misfit: 3.02e+01
# itreação:  43   r: 495.24   z0: 472.07   misfit: 2.82e+01
# itreação:  44   r: 496.46   z0: 472.48   misfit: 2.66e+01
# itreação:  45   r: 497.56   z0: 472.86   misfit: 2.53e+01
# itreação:  46   r: 498.53   z0: 473.22   misfit: 2.43e+01
# itreação:  47   r: 499.40   z0: 473.54   misfit: 2.35e+01
# itreação:  48   r: 500.17   z0: 473.83   misfit: 2.29e+01
# itreação:  49   r: 500.85   z0: 474.11   misfit: 2.23e+01
# itreação:  50   r: 501.45   z0: 474.36   misfit: 2.19e+01
# itreação:  51   r: 501.99   z0: 474.59   misfit: 2.16e+01
# itreação:  52   r: 502.47   z0: 474.81   misfit: 2.14e+01
# itreação:  53   r: 502.89   z0: 475.02   misfit: 2.11e+01
# itreação:  54   r: 503.26   z0: 475.21   misfit: 2.10e+01
# itreação:  55   r: 503.59   z0: 475.38   misfit: 2.08e+01
# itreação:  56   r: 503.88   z0: 475.55   misfit: 2.07e+01
# itreação:  57   r: 504.14   z0: 475.71   misfit: 2.07e+01
# itreação:  58   r: 504.37   z0: 475.86   misfit: 2.06e+01
# itreação:  59   r: 504.57   z0: 476.00   misfit: 2.05e+01
# itreação:  60   r: 504.74   z0: 476.14   misfit: 2.05e+01
# itreação:  61   r: 504.89   z0: 476.26   misfit: 2.04e+01
# itreação:  62   r: 505.03   z0: 476.39   misfit: 2.04e+01
# itreação:  63   r: 505.14   z0: 476.51   misfit: 2.04e+01
# itreação:  64   r: 505.25   z0: 476.62   misfit: 2.04e+01
# itreação:  65   r: 505.33   z0: 476.73   misfit: 2.03e+01
# itreação:  66   r: 505.41   z0: 476.84   misfit: 2.03e+01
# itreação:  67   r: 505.47   z0: 476.94   misfit: 2.03e+01
# itreação:  68   r: 505.53   z0: 477.04   misfit: 2.03e+01
# itreação:  69   r: 505.58   z0: 477.14   misfit: 2.03e+01
# itreação:  70   r: 505.62   z0: 477.24   misfit: 2.03e+01
# itreação:  71   r: 505.65   z0: 477.33   misfit: 2.03e+01
# itreação:  72   r: 505.68   z0: 477.42   misfit: 2.03e+01
# itreação:  73   r: 505.70   z0: 477.51   misfit: 2.02e+01
# itreação:  74   r: 505.72   z0: 477.60   misfit: 2.02e+01
# itreação:  75   r: 505.73   z0: 477.69   misfit: 2.02e+01
# itreação:  76   r: 505.74   z0: 477.78   misfit: 2.02e+01
# itreação:  77   r: 505.74   z0: 477.86   misfit: 2.02e+01
# itreação:  78   r: 505.75   z0: 477.94   misfit: 2.02e+01
# itreação:  79   r: 505.75   z0: 478.03   misfit: 2.02e+01
# itreação:  80   r: 505.75   z0: 478.11   misfit: 2.02e+01
# itreação:  81   r: 505.74   z0: 478.19   misfit: 2.02e+01
# itreação:  82   r: 505.74   z0: 478.27   misfit: 2.02e+01
# itreação:  83   r: 505.73   z0: 478.35   misfit: 2.02e+01
# itreação:  84   r: 505.72   z0: 478.43   misfit: 2.02e+01
# itreação:  85   r: 505.71   z0: 478.51   misfit: 2.02e+01
# itreação:  86   r: 505.70   z0: 478.59   misfit: 2.02e+01
# itreação:  87   r: 505.69   z0: 478.66   misfit: 2.02e+01
# itreação:  88   r: 505.68   z0: 478.74   misfit: 2.01e+01
# itreação:  89   r: 505.66   z0: 478.82   misfit: 2.01e+01
# itreação:  90   r: 505.65   z0: 478.89   misfit: 2.01e+01
# itreação:  91   r: 505.63   z0: 478.97   misfit: 2.01e+01
# itreação:  92   r: 505.62   z0: 479.04   misfit: 2.01e+01
# itreação:  93   r: 505.60   z0: 479.12   misfit: 2.01e+01
# itreação:  94   r: 505.59   z0: 479.19   misfit: 2.01e+01
# itreação:  95   r: 505.57   z0: 479.27   misfit: 2.01e+01
# itreação:  96   r: 505.56   z0: 479.34   misfit: 2.01e+01
# itreação:  97   r: 505.54   z0: 479.41   misfit: 2.01e+01
# itreação:  98   r: 505.52   z0: 479.49   misfit: 2.01e+01
# itreação:  99   r: 505.51   z0: 479.56   misfit: 2.01e+01
# itreação: 100   r: 505.49   z0: 479.63   misfit: 2.01e+01
# itreação: 101   r: 505.47   z0: 479.70   misfit: 2.01e+01
# itreação: 102   r: 505.45   z0: 479.77   misfit: 2.01e+01
# itreação: 103   r: 505.44   z0: 479.84   misfit: 2.01e+01
# itreação: 104   r: 505.42   z0: 479.92   misfit: 2.01e+01
# itreação: 105   r: 505.40   z0: 479.99   misfit: 2.01e+01
# itreação: 106   r: 505.38   z0: 480.06   misfit: 2.00e+01
# itreação: 107   r: 505.37   z0: 480.13   misfit: 2.00e+01
# itreação: 108   r: 505.35   z0: 480.20   misfit: 2.00e+01
# itreação: 109   r: 505.33   z0: 480.27   misfit: 2.00e+01
# itreação: 110   r: 505.31   z0: 480.34   misfit: 2.00e+01
# itreação: 111   r: 505.29   z0: 480.40   misfit: 2.00e+01
# itreação: 112   r: 505.28   z0: 480.47   misfit: 2.00e+01
# itreação: 113   r: 505.26   z0: 480.54   misfit: 2.00e+01
# itreação: 114   r: 505.24   z0: 480.61   misfit: 2.00e+01
# itreação: 115   r: 505.22   z0: 480.68   misfit: 2.00e+01
# itreação: 116   r: 505.21   z0: 480.75   misfit: 2.00e+01
# itreação: 117   r: 505.19   z0: 480.81   misfit: 2.00e+01
# itreação: 118   r: 505.17   z0: 480.88   misfit: 2.00e+01
# itreação: 119   r: 505.15   z0: 480.95   misfit: 2.00e+01
# itreação: 120   r: 505.14   z0: 481.02   misfit: 2.00e+01
# itreação: 121   r: 505.12   z0: 481.08   misfit: 2.00e+01
# itreação: 122   r: 505.10   z0: 481.15   misfit: 2.00e+01
# itreação: 123   r: 505.08   z0: 481.21   misfit: 2.00e+01
# itreação: 124   r: 505.07   z0: 481.28   misfit: 2.00e+01
# itreação: 125   r: 505.05   z0: 481.35   misfit: 2.00e+01
# itreação: 126   r: 505.03   z0: 481.41   misfit: 1.99e+01
# itreação: 127   r: 505.01   z0: 481.48   misfit: 1.99e+01
# itreação: 128   r: 505.00   z0: 481.54   misfit: 1.99e+01
# itreação: 129   r: 504.98   z0: 481.61   misfit: 1.99e+01
# itreação: 130   r: 504.96   z0: 481.67   misfit: 1.99e+01
# itreação: 131   r: 504.95   z0: 481.74   misfit: 1.99e+01
# itreação: 132   r: 504.93   z0: 481.80   misfit: 1.99e+01
# itreação: 133   r: 504.91   z0: 481.86   misfit: 1.99e+01
# itreação: 134   r: 504.90   z0: 481.93   misfit: 1.99e+01
# itreação: 135   r: 504.88   z0: 481.99   misfit: 1.99e+01
# itreação: 136   r: 504.86   z0: 482.05   misfit: 1.99e+01
# itreação: 137   r: 504.85   z0: 482.12   misfit: 1.99e+01
# itreação: 138   r: 504.83   z0: 482.18   misfit: 1.99e+01
# itreação: 139   r: 504.81   z0: 482.24   misfit: 1.99e+01
# itreação: 140   r: 504.80   z0: 482.30   misfit: 1.99e+01
# itreação: 141   r: 504.78   z0: 482.37   misfit: 1.99e+01
# itreação: 142   r: 504.77   z0: 482.43   misfit: 1.99e+01
# itreação: 143   r: 504.75   z0: 482.49   misfit: 1.99e+01
# itreação: 144   r: 504.73   z0: 482.55   misfit: 1.99e+01
# itreação: 145   r: 504.72   z0: 482.61   misfit: 1.99e+01
# itreação: 146   r: 504.70   z0: 482.67   misfit: 1.99e+01
# itreação: 147   r: 504.68   z0: 482.74   misfit: 1.99e+01
# itreação: 148   r: 504.67   z0: 482.80   misfit: 1.99e+01
# itreação: 149   r: 504.65   z0: 482.86   misfit: 1.99e+01
# itreação: 150   r: 504.64   z0: 482.92   misfit: 1.98e+01
# itreação: 151   r: 504.62   z0: 482.98   misfit: 1.98e+01
# itreação: 152   r: 504.61   z0: 483.04   misfit: 1.98e+01
# itreação: 153   r: 504.59   z0: 483.10   misfit: 1.98e+01
# itreação: 154   r: 504.57   z0: 483.16   misfit: 1.98e+01
# itreação: 155   r: 504.56   z0: 483.22   misfit: 1.98e+01
# itreação: 156   r: 504.54   z0: 483.27   misfit: 1.98e+01
# itreação: 157   r: 504.53   z0: 483.33   misfit: 1.98e+01
# itreação: 158   r: 504.51   z0: 483.39   misfit: 1.98e+01
# itreação: 159   r: 504.50   z0: 483.45   misfit: 1.98e+01
# itreação: 160   r: 504.48   z0: 483.51   misfit: 1.98e+01
# itreação: 161   r: 504.47   z0: 483.57   misfit: 1.98e+01
# itreação: 162   r: 504.45   z0: 483.62   misfit: 1.98e+01
# itreação: 163   r: 504.44   z0: 483.68   misfit: 1.98e+01
# itreação: 164   r: 504.42   z0: 483.74   misfit: 1.98e+01
# itreação: 165   r: 504.41   z0: 483.80   misfit: 1.98e+01
# itreação: 166   r: 504.39   z0: 483.85   misfit: 1.98e+01
# itreação: 167   r: 504.38   z0: 483.91   misfit: 1.98e+01
# itreação: 168   r: 504.36   z0: 483.97   misfit: 1.98e+01
# itreação: 169   r: 504.35   z0: 484.02   misfit: 1.98e+01
# itreação: 170   r: 504.33   z0: 484.08   misfit: 1.98e+01
# itreação: 171   r: 504.32   z0: 484.14   misfit: 1.98e+01
# itreação: 172   r: 504.30   z0: 484.19   misfit: 1.98e+01
# itreação: 173   r: 504.29   z0: 484.25   misfit: 1.98e+01
# itreação: 174   r: 504.27   z0: 484.30   misfit: 1.98e+01
# itreação: 175   r: 504.26   z0: 484.36   misfit: 1.98e+01
# itreação: 176   r: 504.25   z0: 484.42   misfit: 1.98e+01
# itreação: 177   r: 504.23   z0: 484.47   misfit: 1.98e+01
# itreação: 178   r: 504.22   z0: 484.52   misfit: 1.97e+01
# itreação: 179   r: 504.20   z0: 484.58   misfit: 1.97e+01
# itreação: 180   r: 504.19   z0: 484.63   misfit: 1.97e+01
# itreação: 181   r: 504.17   z0: 484.69   misfit: 1.97e+01
# itreação: 182   r: 504.16   z0: 484.74   misfit: 1.97e+01
# itreação: 183   r: 504.15   z0: 484.80   misfit: 1.97e+01
# itreação: 184   r: 504.13   z0: 484.85   misfit: 1.97e+01
# itreação: 185   r: 504.12   z0: 484.90   misfit: 1.97e+01
# itreação: 186   r: 504.10   z0: 484.96   misfit: 1.97e+01
# itreação: 187   r: 504.09   z0: 485.01   misfit: 1.97e+01
# itreação: 188   r: 504.08   z0: 485.06   misfit: 1.97e+01
# itreação: 189   r: 504.06   z0: 485.12   misfit: 1.97e+01
# itreação: 190   r: 504.05   z0: 485.17   misfit: 1.97e+01
# itreação: 191   r: 504.04   z0: 485.22   misfit: 1.97e+01
# itreação: 192   r: 504.02   z0: 485.27   misfit: 1.97e+01
# itreação: 193   r: 504.01   z0: 485.33   misfit: 1.97e+01
# itreação: 194   r: 503.99   z0: 485.38   misfit: 1.97e+01
# itreação: 195   r: 503.98   z0: 485.43   misfit: 1.97e+01
# itreação: 196   r: 503.97   z0: 485.48   misfit: 1.97e+01
# itreação: 197   r: 503.95   z0: 485.53   misfit: 1.97e+01
# itreação: 198   r: 503.94   z0: 485.58   misfit: 1.97e+01
# itreação: 199   r: 503.93   z0: 485.64   misfit: 1.97e+01
# itreação: 200   r: 503.91   z0: 485.69   misfit: 1.97e+01
# itreação: 201   r: 503.90   z0: 485.74   misfit: 1.97e+01
# itreação: 202   r: 503.89   z0: 485.79   misfit: 1.97e+01
# itreação: 203   r: 503.87   z0: 485.84   misfit: 1.97e+01
# itreação: 204   r: 503.86   z0: 485.89   misfit: 1.97e+01
# itreação: 205   r: 503.85   z0: 485.94   misfit: 1.97e+01
# itreação: 206   r: 503.84   z0: 485.99   misfit: 1.97e+01
# itreação: 207   r: 503.82   z0: 486.04   misfit: 1.97e+01
# itreação: 208   r: 503.81   z0: 486.09   misfit: 1.97e+01
# itreação: 209   r: 503.80   z0: 486.14   misfit: 1.97e+01
# itreação: 210   r: 503.78   z0: 486.19   misfit: 1.97e+01
# itreação: 211   r: 503.77   z0: 486.24   misfit: 1.97e+01
# itreação: 212   r: 503.76   z0: 486.29   misfit: 1.97e+01
# itreação: 213   r: 503.75   z0: 486.33   misfit: 1.96e+01
# itreação: 214   r: 503.73   z0: 486.38   misfit: 1.96e+01
# itreação: 215   r: 503.72   z0: 486.43   misfit: 1.96e+01
# itreação: 216   r: 503.71   z0: 486.48   misfit: 1.96e+01
# itreação: 217   r: 503.70   z0: 486.53   misfit: 1.96e+01
# itreação: 218   r: 503.68   z0: 486.58   misfit: 1.96e+01
# itreação: 219   r: 503.67   z0: 486.62   misfit: 1.96e+01
# itreação: 220   r: 503.66   z0: 486.67   misfit: 1.96e+01
# itreação: 221   r: 503.65   z0: 486.72   misfit: 1.96e+01
# itreação: 222   r: 503.63   z0: 486.77   misfit: 1.96e+01
# itreação: 223   r: 503.62   z0: 486.81   misfit: 1.96e+01
# itreação: 224   r: 503.61   z0: 486.86   misfit: 1.96e+01
# itreação: 225   r: 503.60   z0: 486.91   misfit: 1.96e+01
# itreação: 226   r: 503.58   z0: 486.96   misfit: 1.96e+01
# itreação: 227   r: 503.57   z0: 487.00   misfit: 1.96e+01
# itreação: 228   r: 503.56   z0: 487.05   misfit: 1.96e+01
# itreação: 229   r: 503.55   z0: 487.10   misfit: 1.96e+01
# itreação: 230   r: 503.54   z0: 487.14   misfit: 1.96e+01
# itreação: 231   r: 503.52   z0: 487.19   misfit: 1.96e+01
# itreação: 232   r: 503.51   z0: 487.23   misfit: 1.96e+01
# itreação: 233   r: 503.50   z0: 487.28   misfit: 1.96e+01
# itreação: 234   r: 503.49   z0: 487.33   misfit: 1.96e+01
# itreação: 235   r: 503.48   z0: 487.37   misfit: 1.96e+01
# itreação: 236   r: 503.47   z0: 487.42   misfit: 1.96e+01
# itreação: 237   r: 503.45   z0: 487.46   misfit: 1.96e+01
# itreação: 238   r: 503.44   z0: 487.51   misfit: 1.96e+01
# itreação: 239   r: 503.43   z0: 487.55   misfit: 1.96e+01
# itreação: 240   r: 503.42   z0: 487.60   misfit: 1.96e+01
# itreação: 241   r: 503.41   z0: 487.64   misfit: 1.96e+01
# itreação: 242   r: 503.40   z0: 487.69   misfit: 1.96e+01
# itreação: 243   r: 503.38   z0: 487.73   misfit: 1.96e+01
# itreação: 244   r: 503.37   z0: 487.77   misfit: 1.96e+01
# itreação: 245   r: 503.36   z0: 487.82   misfit: 1.96e+01
# itreação: 246   r: 503.35   z0: 487.86   misfit: 1.96e+01
# itreação: 247   r: 503.34   z0: 487.91   misfit: 1.96e+01
# itreação: 248   r: 503.33   z0: 487.95   misfit: 1.96e+01
# itreação: 249   r: 503.32   z0: 487.99   misfit: 1.96e+01
# itreação: 250   r: 503.31   z0: 488.04   misfit: 1.96e+01
# itreação: 251   r: 503.29   z0: 488.08   misfit: 1.96e+01
# itreação: 252   r: 503.28   z0: 488.12   misfit: 1.96e+01
# itreação: 253   r: 503.27   z0: 488.17   misfit: 1.96e+01
# itreação: 254   r: 503.26   z0: 488.21   misfit: 1.96e+01
# itreação: 255   r: 503.25   z0: 488.25   misfit: 1.96e+01
# itreação: 256   r: 503.24   z0: 488.29   misfit: 1.96e+01
# itreação: 257   r: 503.23   z0: 488.34   misfit: 1.96e+01
# itreação: 258   r: 503.22   z0: 488.38   misfit: 1.95e+01
# itreação: 259   r: 503.21   z0: 488.42   misfit: 1.95e+01
# itreação: 260   r: 503.20   z0: 488.46   misfit: 1.95e+01
# itreação: 261   r: 503.18   z0: 488.50   misfit: 1.95e+01
# itreação: 262   r: 503.17   z0: 488.55   misfit: 1.95e+01
# itreação: 263   r: 503.16   z0: 488.59   misfit: 1.95e+01
# itreação: 264   r: 503.15   z0: 488.63   misfit: 1.95e+01
# itreação: 265   r: 503.14   z0: 488.67   misfit: 1.95e+01
# itreação: 266   r: 503.13   z0: 488.71   misfit: 1.95e+01
# itreação: 267   r: 503.12   z0: 488.75   misfit: 1.95e+01
# itreação: 268   r: 503.11   z0: 488.79   misfit: 1.95e+01
# itreação: 269   r: 503.10   z0: 488.83   misfit: 1.95e+01
# itreação: 270   r: 503.09   z0: 488.88   misfit: 1.95e+01
# itreação: 271   r: 503.08   z0: 488.92   misfit: 1.95e+01
# itreação: 272   r: 503.07   z0: 488.96   misfit: 1.95e+01
# itreação: 273   r: 503.06   z0: 489.00   misfit: 1.95e+01
# itreação: 274   r: 503.05   z0: 489.04   misfit: 1.95e+01
# itreação: 275   r: 503.04   z0: 489.08   misfit: 1.95e+01
# itreação: 276   r: 503.03   z0: 489.12   misfit: 1.95e+01
# itreação: 277   r: 503.02   z0: 489.16   misfit: 1.95e+01
# itreação: 278   r: 503.01   z0: 489.20   misfit: 1.95e+01
# itreação: 279   r: 503.00   z0: 489.24   misfit: 1.95e+01
# itreação: 280   r: 502.99   z0: 489.28   misfit: 1.95e+01
# itreação: 281   r: 502.98   z0: 489.31   misfit: 1.95e+01
# itreação: 282   r: 502.97   z0: 489.35   misfit: 1.95e+01
# itreação: 283   r: 502.96   z0: 489.39   misfit: 1.95e+01
# itreação: 284   r: 502.95   z0: 489.43   misfit: 1.95e+01
# itreação: 285   r: 502.94   z0: 489.47   misfit: 1.95e+01
# itreação: 286   r: 502.93   z0: 489.51   misfit: 1.95e+01
# itreação: 287   r: 502.92   z0: 489.55   misfit: 1.95e+01
# itreação: 288   r: 502.91   z0: 489.59   misfit: 1.95e+01
# itreação: 289   r: 502.90   z0: 489.62   misfit: 1.95e+01
# itreação: 290   r: 502.89   z0: 489.66   misfit: 1.95e+01
# itreação: 291   r: 502.88   z0: 489.70   misfit: 1.95e+01
# itreação: 292   r: 502.87   z0: 489.74   misfit: 1.95e+01
# itreação: 293   r: 502.86   z0: 489.78   misfit: 1.95e+01
# itreação: 294   r: 502.85   z0: 489.81   misfit: 1.95e+01
# itreação: 295   r: 502.84   z0: 489.85   misfit: 1.95e+01
# itreação: 296   r: 502.83   z0: 489.89   misfit: 1.95e+01
# itreação: 297   r: 502.82   z0: 489.93   misfit: 1.95e+01
# itreação: 298   r: 502.81   z0: 489.96   misfit: 1.95e+01
# itreação: 299   r: 502.80   z0: 490.00   misfit: 1.95e+01
# itreação: 300   r: 502.79   z0: 490.04   misfit: 1.95e+01
# itreação: 301   r: 502.78   z0: 490.08   misfit: 1.95e+01
# itreação: 302   r: 502.77   z0: 490.11   misfit: 1.95e+01
# itreação: 303   r: 502.76   z0: 490.15   misfit: 1.95e+01
# itreação: 304   r: 502.75   z0: 490.19   misfit: 1.95e+01
# itreação: 305   r: 502.74   z0: 490.22   misfit: 1.95e+01
# itreação: 306   r: 502.73   z0: 490.26   misfit: 1.95e+01
# itreação: 307   r: 502.72   z0: 490.29   misfit: 1.95e+01
# itreação: 308   r: 502.72   z0: 490.33   misfit: 1.95e+01
# itreação: 309   r: 502.71   z0: 490.37   misfit: 1.95e+01
# itreação: 310   r: 502.70   z0: 490.40   misfit: 1.95e+01
# itreação: 311   r: 502.69   z0: 490.44   misfit: 1.95e+01
# itreação: 312   r: 502.68   z0: 490.47   misfit: 1.95e+01
# itreação: 313   r: 502.67   z0: 490.51   misfit: 1.95e+01
# itreação: 314   r: 502.66   z0: 490.55   misfit: 1.95e+01
# itreação: 315   r: 502.65   z0: 490.58   misfit: 1.95e+01
# itreação: 316   r: 502.64   z0: 490.62   misfit: 1.95e+01
# itreação: 317   r: 502.63   z0: 490.65   misfit: 1.95e+01
# itreação: 318   r: 502.62   z0: 490.69   misfit: 1.95e+01
# itreação: 319   r: 502.62   z0: 490.72   misfit: 1.95e+01
# itreação: 320   r: 502.61   z0: 490.76   misfit: 1.95e+01
# itreação: 321   r: 502.60   z0: 490.79   misfit: 1.95e+01
# itreação: 322   r: 502.59   z0: 490.83   misfit: 1.94e+01
# itreação: 323   r: 502.58   z0: 490.86   misfit: 1.94e+01
# itreação: 324   r: 502.57   z0: 490.89   misfit: 1.94e+01
# itreação: 325   r: 502.56   z0: 490.93   misfit: 1.94e+01
# itreação: 326   r: 502.55   z0: 490.96   misfit: 1.94e+01
# itreação: 327   r: 502.54   z0: 491.00   misfit: 1.94e+01
# itreação: 328   r: 502.54   z0: 491.03   misfit: 1.94e+01
# itreação: 329   r: 502.53   z0: 491.06   misfit: 1.94e+01
# itreação: 330   r: 502.52   z0: 491.10   misfit: 1.94e+01
# itreação: 331   r: 502.51   z0: 491.13   misfit: 1.94e+01
# itreação: 332   r: 502.50   z0: 491.17   misfit: 1.94e+01
# itreação: 333   r: 502.49   z0: 491.20   misfit: 1.94e+01
# itreação: 334   r: 502.48   z0: 491.23   misfit: 1.94e+01
# itreação: 335   r: 502.48   z0: 491.27   misfit: 1.94e+01
# itreação: 336   r: 502.47   z0: 491.30   misfit: 1.94e+01
# itreação: 337   r: 502.46   z0: 491.33   misfit: 1.94e+01
# itreação: 338   r: 502.45   z0: 491.36   misfit: 1.94e+01
# itreação: 339   r: 502.44   z0: 491.40   misfit: 1.94e+01
# itreação: 340   r: 502.43   z0: 491.43   misfit: 1.94e+01
# itreação: 341   r: 502.43   z0: 491.46   misfit: 1.94e+01
# itreação: 342   r: 502.42   z0: 491.50   misfit: 1.94e+01
# itreação: 343   r: 502.41   z0: 491.53   misfit: 1.94e+01
# itreação: 344   r: 502.40   z0: 491.56   misfit: 1.94e+01
# itreação: 345   r: 502.39   z0: 491.59   misfit: 1.94e+01
# itreação: 346   r: 502.38   z0: 491.62   misfit: 1.94e+01
# itreação: 347   r: 502.38   z0: 491.66   misfit: 1.94e+01
# itreação: 348   r: 502.37   z0: 491.69   misfit: 1.94e+01
# itreação: 349   r: 502.36   z0: 491.72   misfit: 1.94e+01
# itreação: 350   r: 502.35   z0: 491.75   misfit: 1.94e+01
# itreação: 351   r: 502.34   z0: 491.78   misfit: 1.94e+01
# itreação: 352   r: 502.34   z0: 491.82   misfit: 1.94e+01
# itreação: 353   r: 502.33   z0: 491.85   misfit: 1.94e+01
# itreação: 354   r: 502.32   z0: 491.88   misfit: 1.94e+01
# itreação: 355   r: 502.31   z0: 491.91   misfit: 1.94e+01
# itreação: 356   r: 502.30   z0: 491.94   misfit: 1.94e+01
# itreação: 357   r: 502.30   z0: 491.97   misfit: 1.94e+01
# itreação: 358   r: 502.29   z0: 492.00   misfit: 1.94e+01
# itreação: 359   r: 502.28   z0: 492.03   misfit: 1.94e+01
# itreação: 360   r: 502.27   z0: 492.06   misfit: 1.94e+01
# itreação: 361   r: 502.26   z0: 492.10   misfit: 1.94e+01
# itreação: 362   r: 502.26   z0: 492.13   misfit: 1.94e+01
# itreação: 363   r: 502.25   z0: 492.16   misfit: 1.94e+01
# itreação: 364   r: 502.24   z0: 492.19   misfit: 1.94e+01
# itreação: 365   r: 502.23   z0: 492.22   misfit: 1.94e+01
# itreação: 366   r: 502.23   z0: 492.25   misfit: 1.94e+01
# itreação: 367   r: 502.22   z0: 492.28   misfit: 1.94e+01
# itreação: 368   r: 502.21   z0: 492.31   misfit: 1.94e+01
# itreação: 369   r: 502.20   z0: 492.34   misfit: 1.94e+01
# itreação: 370   r: 502.19   z0: 492.37   misfit: 1.94e+01
# itreação: 371   r: 502.19   z0: 492.40   misfit: 1.94e+01
# itreação: 372   r: 502.18   z0: 492.43   misfit: 1.94e+01
# itreação: 373   r: 502.17   z0: 492.46   misfit: 1.94e+01
# itreação: 374   r: 502.16   z0: 492.49   misfit: 1.94e+01
# itreação: 375   r: 502.16   z0: 492.52   misfit: 1.94e+01
# itreação: 376   r: 502.15   z0: 492.54   misfit: 1.94e+01
# itreação: 377   r: 502.14   z0: 492.57   misfit: 1.94e+01
# itreação: 378   r: 502.13   z0: 492.60   misfit: 1.94e+01
# itreação: 379   r: 502.13   z0: 492.63   misfit: 1.94e+01
# itreação: 380   r: 502.12   z0: 492.66   misfit: 1.94e+01
# itreação: 381   r: 502.11   z0: 492.69   misfit: 1.94e+01
# itreação: 382   r: 502.11   z0: 492.72   misfit: 1.94e+01
# itreação: 383   r: 502.10   z0: 492.75   misfit: 1.94e+01
# itreação: 384   r: 502.09   z0: 492.78   misfit: 1.94e+01
# itreação: 385   r: 502.08   z0: 492.80   misfit: 1.94e+01
# itreação: 386   r: 502.08   z0: 492.83   misfit: 1.94e+01
# itreação: 387   r: 502.07   z0: 492.86   misfit: 1.94e+01
# itreação: 388   r: 502.06   z0: 492.89   misfit: 1.94e+01
# itreação: 389   r: 502.05   z0: 492.92   misfit: 1.94e+01
# itreação: 390   r: 502.05   z0: 492.95   misfit: 1.94e+01
# itreação: 391   r: 502.04   z0: 492.97   misfit: 1.94e+01
# itreação: 392   r: 502.03   z0: 493.00   misfit: 1.94e+01
# itreação: 393   r: 502.03   z0: 493.03   misfit: 1.94e+01
# itreação: 394   r: 502.02   z0: 493.06   misfit: 1.94e+01
# itreação: 395   r: 502.01   z0: 493.09   misfit: 1.94e+01
# itreação: 396   r: 502.00   z0: 493.11   misfit: 1.94e+01
# itreação: 397   r: 502.00   z0: 493.14   misfit: 1.94e+01
# itreação: 398   r: 501.99   z0: 493.17   misfit: 1.94e+01
# itreação: 399   r: 501.98   z0: 493.20   misfit: 1.94e+01
# itreação: 400   r: 501.98   z0: 493.22   misfit: 1.94e+01
# itreação: 401   r: 501.97   z0: 493.25   misfit: 1.94e+01
# itreação: 402   r: 501.96   z0: 493.28   misfit: 1.94e+01
# itreação: 403   r: 501.96   z0: 493.30   misfit: 1.94e+01
# itreação: 404   r: 501.95   z0: 493.33   misfit: 1.94e+01
# itreação: 405   r: 501.94   z0: 493.36   misfit: 1.94e+01
# itreação: 406   r: 501.94   z0: 493.39   misfit: 1.94e+01
# itreação: 407   r: 501.93   z0: 493.41   misfit: 1.94e+01
# itreação: 408   r: 501.92   z0: 493.44   misfit: 1.94e+01
# itreação: 409   r: 501.92   z0: 493.47   misfit: 1.94e+01
# itreação: 410   r: 501.91   z0: 493.49   misfit: 1.94e+01
# itreação: 411   r: 501.90   z0: 493.52   misfit: 1.94e+01
# itreação: 412   r: 501.90   z0: 493.54   misfit: 1.94e+01
# itreação: 413   r: 501.89   z0: 493.57   misfit: 1.94e+01
# itreação: 414   r: 501.88   z0: 493.60   misfit: 1.94e+01
# itreação: 415   r: 501.88   z0: 493.62   misfit: 1.94e+01
# itreação: 416   r: 501.87   z0: 493.65   misfit: 1.94e+01
# itreação: 417   r: 501.86   z0: 493.67   misfit: 1.94e+01
# itreação: 418   r: 501.86   z0: 493.70   misfit: 1.94e+01
# itreação: 419   r: 501.85   z0: 493.73   misfit: 1.94e+01
# itreação: 420   r: 501.84   z0: 493.75   misfit: 1.94e+01
# itreação: 421   r: 501.84   z0: 493.78   misfit: 1.94e+01
# itreação: 422   r: 501.83   z0: 493.80   misfit: 1.94e+01
# itreação: 423   r: 501.82   z0: 493.83   misfit: 1.94e+01
# itreação: 424   r: 501.82   z0: 493.85   misfit: 1.94e+01
# itreação: 425   r: 501.81   z0: 493.88   misfit: 1.94e+01
# itreação: 426   r: 501.80   z0: 493.91   misfit: 1.94e+01
# itreação: 427   r: 501.80   z0: 493.93   misfit: 1.94e+01
# itreação: 428   r: 501.79   z0: 493.96   misfit: 1.94e+01
# itreação: 429   r: 501.78   z0: 493.98   misfit: 1.93e+01
# itreação: 430   r: 501.78   z0: 494.01   misfit: 1.93e+01
# itreação: 431   r: 501.77   z0: 494.03   misfit: 1.93e+01
# itreação: 432   r: 501.77   z0: 494.06   misfit: 1.93e+01
# itreação: 433   r: 501.76   z0: 494.08   misfit: 1.93e+01
# itreação: 434   r: 501.75   z0: 494.10   misfit: 1.93e+01
# itreação: 435   r: 501.75   z0: 494.13   misfit: 1.93e+01
# itreação: 436   r: 501.74   z0: 494.15   misfit: 1.93e+01
# itreação: 437   r: 501.73   z0: 494.18   misfit: 1.93e+01
# itreação: 438   r: 501.73   z0: 494.20   misfit: 1.93e+01
# itreação: 439   r: 501.72   z0: 494.23   misfit: 1.93e+01
# itreação: 440   r: 501.72   z0: 494.25   misfit: 1.93e+01
# itreação: 441   r: 501.71   z0: 494.28   misfit: 1.93e+01
# itreação: 442   r: 501.70   z0: 494.30   misfit: 1.93e+01
# itreação: 443   r: 501.70   z0: 494.32   misfit: 1.93e+01
# itreação: 444   r: 501.69   z0: 494.35   misfit: 1.93e+01
# itreação: 445   r: 501.69   z0: 494.37   misfit: 1.93e+01
# itreação: 446   r: 501.68   z0: 494.39   misfit: 1.93e+01
# itreação: 447   r: 501.67   z0: 494.42   misfit: 1.93e+01
# itreação: 448   r: 501.67   z0: 494.44   misfit: 1.93e+01
# itreação: 449   r: 501.66   z0: 494.47   misfit: 1.93e+01
# itreação: 450   r: 501.66   z0: 494.49   misfit: 1.93e+01
# itreação: 451   r: 501.65   z0: 494.51   misfit: 1.93e+01
# itreação: 452   r: 501.64   z0: 494.54   misfit: 1.93e+01
# itreação: 453   r: 501.64   z0: 494.56   misfit: 1.93e+01
# itreação: 454   r: 501.63   z0: 494.58   misfit: 1.93e+01
# itreação: 455   r: 501.63   z0: 494.61   misfit: 1.93e+01
# itreação: 456   r: 501.62   z0: 494.63   misfit: 1.93e+01
# itreação: 457   r: 501.61   z0: 494.65   misfit: 1.93e+01
# itreação: 458   r: 501.61   z0: 494.68   misfit: 1.93e+01
# itreação: 459   r: 501.60   z0: 494.70   misfit: 1.93e+01
# itreação: 460   r: 501.60   z0: 494.72   misfit: 1.93e+01
# itreação: 461   r: 501.59   z0: 494.74   misfit: 1.93e+01
# itreação: 462   r: 501.59   z0: 494.77   misfit: 1.93e+01
# itreação: 463   r: 501.58   z0: 494.79   misfit: 1.93e+01
# itreação: 464   r: 501.57   z0: 494.81   misfit: 1.93e+01
# itreação: 465   r: 501.57   z0: 494.83   misfit: 1.93e+01
# itreação: 466   r: 501.56   z0: 494.86   misfit: 1.93e+01
# itreação: 467   r: 501.56   z0: 494.88   misfit: 1.93e+01
# itreação: 468   r: 501.55   z0: 494.90   misfit: 1.93e+01
# itreação: 469   r: 501.55   z0: 494.92   misfit: 1.93e+01
# itreação: 470   r: 501.54   z0: 494.95   misfit: 1.93e+01
# itreação: 471   r: 501.53   z0: 494.97   misfit: 1.93e+01
# itreação: 472   r: 501.53   z0: 494.99   misfit: 1.93e+01
# itreação: 473   r: 501.52   z0: 495.01   misfit: 1.93e+01
# itreação: 474   r: 501.52   z0: 495.03   misfit: 1.93e+01
# itreação: 475   r: 501.51   z0: 495.06   misfit: 1.93e+01
# itreação: 476   r: 501.51   z0: 495.08   misfit: 1.93e+01
# itreação: 477   r: 501.50   z0: 495.10   misfit: 1.93e+01
# itreação: 478   r: 501.50   z0: 495.12   misfit: 1.93e+01
# itreação: 479   r: 501.49   z0: 495.14   misfit: 1.93e+01
# itreação: 480   r: 501.48   z0: 495.16   misfit: 1.93e+01
# itreação: 481   r: 501.48   z0: 495.19   misfit: 1.93e+01
# itreação: 482   r: 501.47   z0: 495.21   misfit: 1.93e+01
# itreação: 483   r: 501.47   z0: 495.23   misfit: 1.93e+01
# itreação: 484   r: 501.46   z0: 495.25   misfit: 1.93e+01
# itreação: 485   r: 501.46   z0: 495.27   misfit: 1.93e+01
# itreação: 486   r: 501.45   z0: 495.29   misfit: 1.93e+01
# itreação: 487   r: 501.45   z0: 495.31   misfit: 1.93e+01
# itreação: 488   r: 501.44   z0: 495.33   misfit: 1.93e+01
# itreação: 489   r: 501.44   z0: 495.36   misfit: 1.93e+01
# itreação: 490   r: 501.43   z0: 495.38   misfit: 1.93e+01
# itreação: 491   r: 501.43   z0: 495.40   misfit: 1.93e+01
# itreação: 492   r: 501.42   z0: 495.42   misfit: 1.93e+01
# itreação: 493   r: 501.42   z0: 495.44   misfit: 1.93e+01
# itreação: 494   r: 501.41   z0: 495.46   misfit: 1.93e+01
# itreação: 495   r: 501.41   z0: 495.48   misfit: 1.93e+01
# itreação: 496   r: 501.40   z0: 495.50   misfit: 1.93e+01
# itreação: 497   r: 501.39   z0: 495.52   misfit: 1.93e+01
# itreação: 498   r: 501.39   z0: 495.54   misfit: 1.93e+01
# itreação: 499   r: 501.38   z0: 495.56   misfit: 1.93e+01
# itreação: 500   r: 501.38   z0: 495.58   misfit: 1.93e+01
# itreação: 501   r: 501.37   z0: 495.60   misfit: 1.93e+01
# itreação: 502   r: 501.37   z0: 495.62   misfit: 1.93e+01
# itreação: 503   r: 501.36   z0: 495.64   misfit: 1.93e+01
# itreação: 504   r: 501.36   z0: 495.66   misfit: 1.93e+01
# itreação: 505   r: 501.35   z0: 495.68   misfit: 1.93e+01
# itreação: 506   r: 501.35   z0: 495.70   misfit: 1.93e+01
# itreação: 507   r: 501.34   z0: 495.72   misfit: 1.93e+01
# itreação: 508   r: 501.34   z0: 495.74   misfit: 1.93e+01
# itreação: 509   r: 501.33   z0: 495.76   misfit: 1.93e+01
# itreação: 510   r: 501.33   z0: 495.78   misfit: 1.93e+01
# itreação: 511   r: 501.32   z0: 495.80   misfit: 1.93e+01
# itreação: 512   r: 501.32   z0: 495.82   misfit: 1.93e+01
# itreação: 513   r: 501.31   z0: 495.84   misfit: 1.93e+01
# itreação: 514   r: 501.31   z0: 495.86   misfit: 1.93e+01
# itreação: 515   r: 501.30   z0: 495.88   misfit: 1.93e+01
# itreação: 516   r: 501.30   z0: 495.90   misfit: 1.93e+01
# itreação: 517   r: 501.29   z0: 495.92   misfit: 1.93e+01
# itreação: 518   r: 501.29   z0: 495.94   misfit: 1.93e+01
# itreação: 519   r: 501.28   z0: 495.96   misfit: 1.93e+01
# itreação: 520   r: 501.28   z0: 495.98   misfit: 1.93e+01
# itreação: 521   r: 501.28   z0: 496.00   misfit: 1.93e+01
# itreação: 522   r: 501.27   z0: 496.01   misfit: 1.93e+01
# itreação: 523   r: 501.27   z0: 496.03   misfit: 1.93e+01
# itreação: 524   r: 501.26   z0: 496.05   misfit: 1.93e+01
# itreação: 525   r: 501.26   z0: 496.07   misfit: 1.93e+01
# itreação: 526   r: 501.25   z0: 496.09   misfit: 1.93e+01
# itreação: 527   r: 501.25   z0: 496.11   misfit: 1.93e+01
# itreação: 528   r: 501.24   z0: 496.13   misfit: 1.93e+01
# itreação: 529   r: 501.24   z0: 496.15   misfit: 1.93e+01
# itreação: 530   r: 501.23   z0: 496.17   misfit: 1.93e+01
# itreação: 531   r: 501.23   z0: 496.18   misfit: 1.93e+01
# itreação: 532   r: 501.22   z0: 496.20   misfit: 1.93e+01
# itreação: 533   r: 501.22   z0: 496.22   misfit: 1.93e+01
# itreação: 534   r: 501.21   z0: 496.24   misfit: 1.93e+01
# itreação: 535   r: 501.21   z0: 496.26   misfit: 1.93e+01
# itreação: 536   r: 501.20   z0: 496.28   misfit: 1.93e+01
# itreação: 537   r: 501.20   z0: 496.29   misfit: 1.93e+01
# itreação: 538   r: 501.20   z0: 496.31   misfit: 1.93e+01
# itreação: 539   r: 501.19   z0: 496.33   misfit: 1.93e+01
# itreação: 540   r: 501.19   z0: 496.35   misfit: 1.93e+01
# itreação: 541   r: 501.18   z0: 496.37   misfit: 1.93e+01
# itreação: 542   r: 501.18   z0: 496.38   misfit: 1.93e+01
# itreação: 543   r: 501.17   z0: 496.40   misfit: 1.93e+01
# itreação: 544   r: 501.17   z0: 496.42   misfit: 1.93e+01
# itreação: 545   r: 501.16   z0: 496.44   misfit: 1.93e+01
# itreação: 546   r: 501.16   z0: 496.46   misfit: 1.93e+01
# itreação: 547   r: 501.15   z0: 496.47   misfit: 1.93e+01
# itreação: 548   r: 501.15   z0: 496.49   misfit: 1.93e+01
# itreação: 549   r: 501.15   z0: 496.51   misfit: 1.93e+01
# itreação: 550   r: 501.14   z0: 496.53   misfit: 1.93e+01
# itreação: 551   r: 501.14   z0: 496.54   misfit: 1.93e+01
# itreação: 552   r: 501.13   z0: 496.56   misfit: 1.93e+01
# itreação: 553   r: 501.13   z0: 496.58   misfit: 1.93e+01
# itreação: 554   r: 501.12   z0: 496.60   misfit: 1.93e+01
# itreação: 555   r: 501.12   z0: 496.61   misfit: 1.93e+01
# itreação: 556   r: 501.11   z0: 496.63   misfit: 1.93e+01
# itreação: 557   r: 501.11   z0: 496.65   misfit: 1.93e+01
# itreação: 558   r: 501.11   z0: 496.67   misfit: 1.93e+01
# itreação: 559   r: 501.10   z0: 496.68   misfit: 1.93e+01
# itreação: 560   r: 501.10   z0: 496.70   misfit: 1.93e+01
# itreação: 561   r: 501.09   z0: 496.72   misfit: 1.93e+01
# itreação: 562   r: 501.09   z0: 496.73   misfit: 1.93e+01
# itreação: 563   r: 501.08   z0: 496.75   misfit: 1.93e+01
# itreação: 564   r: 501.08   z0: 496.77   misfit: 1.93e+01
# itreação: 565   r: 501.08   z0: 496.78   misfit: 1.93e+01
# itreação: 566   r: 501.07   z0: 496.80   misfit: 1.93e+01
# itreação: 567   r: 501.07   z0: 496.82   misfit: 1.93e+01
# itreação: 568   r: 501.06   z0: 496.83   misfit: 1.93e+01
# itreação: 569   r: 501.06   z0: 496.85   misfit: 1.93e+01
# itreação: 570   r: 501.06   z0: 496.87   misfit: 1.93e+01
# itreação: 571   r: 501.05   z0: 496.88   misfit: 1.93e+01
# itreação: 572   r: 501.05   z0: 496.90   misfit: 1.93e+01
# itreação: 573   r: 501.04   z0: 496.92   misfit: 1.93e+01
# itreação: 574   r: 501.04   z0: 496.93   misfit: 1.93e+01
# itreação: 575   r: 501.03   z0: 496.95   misfit: 1.93e+01
# itreação: 576   r: 501.03   z0: 496.97   misfit: 1.93e+01
# itreação: 577   r: 501.03   z0: 496.98   misfit: 1.93e+01
# itreação: 578   r: 501.02   z0: 497.00   misfit: 1.93e+01
# itreação: 579   r: 501.02   z0: 497.02   misfit: 1.93e+01
# itreação: 580   r: 501.01   z0: 497.03   misfit: 1.93e+01
# itreação: 581   r: 501.01   z0: 497.05   misfit: 1.93e+01
# itreação: 582   r: 501.01   z0: 497.06   misfit: 1.93e+01
# itreação: 583   r: 501.00   z0: 497.08   misfit: 1.93e+01
# itreação: 584   r: 501.00   z0: 497.10   misfit: 1.93e+01
# itreação: 585   r: 500.99   z0: 497.11   misfit: 1.93e+01
# itreação: 586   r: 500.99   z0: 497.13   misfit: 1.93e+01
# itreação: 587   r: 500.99   z0: 497.14   misfit: 1.93e+01
# itreação: 588   r: 500.98   z0: 497.16   misfit: 1.93e+01
# itreação: 589   r: 500.98   z0: 497.17   misfit: 1.93e+01
# itreação: 590   r: 500.97   z0: 497.19   misfit: 1.93e+01
# itreação: 591   r: 500.97   z0: 497.21   misfit: 1.93e+01
# itreação: 592   r: 500.97   z0: 497.22   misfit: 1.93e+01
# itreação: 593   r: 500.96   z0: 497.24   misfit: 1.93e+01
# itreação: 594   r: 500.96   z0: 497.25   misfit: 1.93e+01
# itreação: 595   r: 500.95   z0: 497.27   misfit: 1.93e+01
# itreação: 596   r: 500.95   z0: 497.28   misfit: 1.93e+01
# itreação: 597   r: 500.95   z0: 497.30   misfit: 1.93e+01
# itreação: 598   r: 500.94   z0: 497.31   misfit: 1.93e+01
# itreação: 599   r: 500.94   z0: 497.33   misfit: 1.93e+01
# itreação: 600   r: 500.94   z0: 497.34   misfit: 1.93e+01
# itreação: 601   r: 500.93   z0: 497.36   misfit: 1.93e+01
# itreação: 602   r: 500.93   z0: 497.38   misfit: 1.93e+01
# itreação: 603   r: 500.92   z0: 497.39   misfit: 1.93e+01
# itreação: 604   r: 500.92   z0: 497.41   misfit: 1.93e+01
# itreação: 605   r: 500.92   z0: 497.42   misfit: 1.93e+01
# itreação: 606   r: 500.91   z0: 497.44   misfit: 1.93e+01
# itreação: 607   r: 500.91   z0: 497.45   misfit: 1.93e+01
# itreação: 608   r: 500.91   z0: 497.47   misfit: 1.93e+01
# itreação: 609   r: 500.90   z0: 497.48   misfit: 1.93e+01
# itreação: 610   r: 500.90   z0: 497.49   misfit: 1.93e+01
# itreação: 611   r: 500.89   z0: 497.51   misfit: 1.93e+01
# itreação: 612   r: 500.89   z0: 497.52   misfit: 1.93e+01
# itreação: 613   r: 500.89   z0: 497.54   misfit: 1.93e+01
# itreação: 614   r: 500.88   z0: 497.55   misfit: 1.93e+01
# itreação: 615   r: 500.88   z0: 497.57   misfit: 1.93e+01
# itreação: 616   r: 500.88   z0: 497.58   misfit: 1.93e+01
# itreação: 617   r: 500.87   z0: 497.60   misfit: 1.93e+01
# itreação: 618   r: 500.87   z0: 497.61   misfit: 1.93e+01
# itreação: 619   r: 500.86   z0: 497.63   misfit: 1.93e+01
# itreação: 620   r: 500.86   z0: 497.64   misfit: 1.93e+01
# itreação: 621   r: 500.86   z0: 497.66   misfit: 1.93e+01
# itreação: 622   r: 500.85   z0: 497.67   misfit: 1.93e+01
# itreação: 623   r: 500.85   z0: 497.68   misfit: 1.93e+01
# itreação: 624   r: 500.85   z0: 497.70   misfit: 1.93e+01
# itreação: 625   r: 500.84   z0: 497.71   misfit: 1.93e+01
# itreação: 626   r: 500.84   z0: 497.73   misfit: 1.93e+01
# itreação: 627   r: 500.84   z0: 497.74   misfit: 1.93e+01
# itreação: 628   r: 500.83   z0: 497.75   misfit: 1.93e+01
# itreação: 629   r: 500.83   z0: 497.77   misfit: 1.93e+01
# itreação: 630   r: 500.83   z0: 497.78   misfit: 1.93e+01
# itreação: 631   r: 500.82   z0: 497.80   misfit: 1.93e+01
# itreação: 632   r: 500.82   z0: 497.81   misfit: 1.93e+01
# itreação: 633   r: 500.82   z0: 497.82   misfit: 1.93e+01
# itreação: 634   r: 500.81   z0: 497.84   misfit: 1.93e+01
# itreação: 635   r: 500.81   z0: 497.85   misfit: 1.93e+01
# itreação: 636   r: 500.80   z0: 497.87   misfit: 1.93e+01
# itreação: 637   r: 500.80   z0: 497.88   misfit: 1.93e+01
# itreação: 638   r: 500.80   z0: 497.89   misfit: 1.93e+01
# itreação: 639   r: 500.79   z0: 497.91   misfit: 1.93e+01
# itreação: 640   r: 500.79   z0: 497.92   misfit: 1.93e+01
# itreação: 641   r: 500.79   z0: 497.93   misfit: 1.93e+01
# itreação: 642   r: 500.78   z0: 497.95   misfit: 1.93e+01
# itreação: 643   r: 500.78   z0: 497.96   misfit: 1.93e+01
# itreação: 644   r: 500.78   z0: 497.97   misfit: 1.93e+01
# itreação: 645   r: 500.77   z0: 497.99   misfit: 1.93e+01
# itreação: 646   r: 500.77   z0: 498.00   misfit: 1.93e+01
# itreação: 647   r: 500.77   z0: 498.01   misfit: 1.93e+01
# itreação: 648   r: 500.76   z0: 498.03   misfit: 1.93e+01
# itreação: 649   r: 500.76   z0: 498.04   misfit: 1.93e+01
# itreação: 650   r: 500.76   z0: 498.05   misfit: 1.93e+01
# itreação: 651   r: 500.75   z0: 498.07   misfit: 1.93e+01
# itreação: 652   r: 500.75   z0: 498.08   misfit: 1.93e+01
# itreação: 653   r: 500.75   z0: 498.09   misfit: 1.93e+01
# itreação: 654   r: 500.74   z0: 498.11   misfit: 1.93e+01
# itreação: 655   r: 500.74   z0: 498.12   misfit: 1.93e+01
# itreação: 656   r: 500.74   z0: 498.13   misfit: 1.93e+01
# itreação: 657   r: 500.73   z0: 498.15   misfit: 1.93e+01
# itreação: 658   r: 500.73   z0: 498.16   misfit: 1.93e+01
# itreação: 659   r: 500.73   z0: 498.17   misfit: 1.93e+01
# itreação: 660   r: 500.72   z0: 498.18   misfit: 1.93e+01
# itreação: 661   r: 500.72   z0: 498.20   misfit: 1.93e+01
# itreação: 662   r: 500.72   z0: 498.21   misfit: 1.93e+01
# itreação: 663   r: 500.72   z0: 498.22   misfit: 1.93e+01
# itreação: 664   r: 500.71   z0: 498.24   misfit: 1.93e+01
# itreação: 665   r: 500.71   z0: 498.25   misfit: 1.93e+01
# itreação: 666   r: 500.71   z0: 498.26   misfit: 1.93e+01
# itreação: 667   r: 500.70   z0: 498.27   misfit: 1.93e+01
# itreação: 668   r: 500.70   z0: 498.29   misfit: 1.93e+01
# itreação: 669   r: 500.70   z0: 498.30   misfit: 1.93e+01
# itreação: 670   r: 500.69   z0: 498.31   misfit: 1.93e+01
# itreação: 671   r: 500.69   z0: 498.32   misfit: 1.93e+01
# itreação: 672   r: 500.69   z0: 498.34   misfit: 1.93e+01
# itreação: 673   r: 500.68   z0: 498.35   misfit: 1.93e+01
# itreação: 674   r: 500.68   z0: 498.36   misfit: 1.93e+01
# itreação: 675   r: 500.68   z0: 498.37   misfit: 1.93e+01
# itreação: 676   r: 500.67   z0: 498.39   misfit: 1.93e+01
# itreação: 677   r: 500.67   z0: 498.40   misfit: 1.93e+01
# itreação: 678   r: 500.67   z0: 498.41   misfit: 1.93e+01
# itreação: 679   r: 500.67   z0: 498.42   misfit: 1.93e+01
# itreação: 680   r: 500.66   z0: 498.43   misfit: 1.93e+01
# itreação: 681   r: 500.66   z0: 498.45   misfit: 1.93e+01
# itreação: 682   r: 500.66   z0: 498.46   misfit: 1.93e+01
# itreação: 683   r: 500.65   z0: 498.47   misfit: 1.93e+01
# itreação: 684   r: 500.65   z0: 498.48   misfit: 1.93e+01
# itreação: 685   r: 500.65   z0: 498.49   misfit: 1.93e+01
# itreação: 686   r: 500.64   z0: 498.51   misfit: 1.93e+01
# itreação: 687   r: 500.64   z0: 498.52   misfit: 1.93e+01
# itreação: 688   r: 500.64   z0: 498.53   misfit: 1.93e+01
# itreação: 689   r: 500.64   z0: 498.54   misfit: 1.93e+01
# itreação: 690   r: 500.63   z0: 498.55   misfit: 1.93e+01
# itreação: 691   r: 500.63   z0: 498.57   misfit: 1.93e+01
# itreação: 692   r: 500.63   z0: 498.58   misfit: 1.93e+01
# itreação: 693   r: 500.62   z0: 498.59   misfit: 1.93e+01
# itreação: 694   r: 500.62   z0: 498.60   misfit: 1.93e+01
# itreação: 695   r: 500.62   z0: 498.61   misfit: 1.93e+01
# itreação: 696   r: 500.61   z0: 498.62   misfit: 1.93e+01
# itreação: 697   r: 500.61   z0: 498.64   misfit: 1.93e+01
# itreação: 698   r: 500.61   z0: 498.65   misfit: 1.93e+01
# itreação: 699   r: 500.61   z0: 498.66   misfit: 1.93e+01
# itreação: 700   r: 500.60   z0: 498.67   misfit: 1.93e+01
# itreação: 701   r: 500.60   z0: 498.68   misfit: 1.93e+01
# itreação: 702   r: 500.60   z0: 498.69   misfit: 1.93e+01
# itreação: 703   r: 500.59   z0: 498.70   misfit: 1.93e+01
# itreação: 704   r: 500.59   z0: 498.72   misfit: 1.93e+01
# itreação: 705   r: 500.59   z0: 498.73   misfit: 1.93e+01
# itreação: 706   r: 500.59   z0: 498.74   misfit: 1.93e+01
# itreação: 707   r: 500.58   z0: 498.75   misfit: 1.93e+01
# itreação: 708   r: 500.58   z0: 498.76   misfit: 1.93e+01
# itreação: 709   r: 500.58   z0: 498.77   misfit: 1.93e+01
# itreação: 710   r: 500.57   z0: 498.78   misfit: 1.93e+01
# itreação: 711   r: 500.57   z0: 498.79   misfit: 1.93e+01
# itreação: 712   r: 500.57   z0: 498.81   misfit: 1.93e+01
# itreação: 713   r: 500.57   z0: 498.82   misfit: 1.93e+01
# itreação: 714   r: 500.56   z0: 498.83   misfit: 1.93e+01
# itreação: 715   r: 500.56   z0: 498.84   misfit: 1.93e+01
# itreação: 716   r: 500.56   z0: 498.85   misfit: 1.93e+01
# itreação: 717   r: 500.56   z0: 498.86   misfit: 1.93e+01
# itreação: 718   r: 500.55   z0: 498.87   misfit: 1.93e+01
# itreação: 719   r: 500.55   z0: 498.88   misfit: 1.93e+01
# itreação: 720   r: 500.55   z0: 498.89   misfit: 1.93e+01
# itreação: 721   r: 500.54   z0: 498.90   misfit: 1.93e+01
# itreação: 722   r: 500.54   z0: 498.92   misfit: 1.93e+01
# itreação: 723   r: 500.54   z0: 498.93   misfit: 1.93e+01
# itreação: 724   r: 500.54   z0: 498.94   misfit: 1.93e+01
# itreação: 725   r: 500.53   z0: 498.95   misfit: 1.93e+01
# itreação: 726   r: 500.53   z0: 498.96   misfit: 1.93e+01
# itreação: 727   r: 500.53   z0: 498.97   misfit: 1.93e+01
# itreação: 728   r: 500.53   z0: 498.98   misfit: 1.93e+01
# itreação: 729   r: 500.52   z0: 498.99   misfit: 1.93e+01
# itreação: 730   r: 500.52   z0: 499.00   misfit: 1.93e+01
# itreação: 731   r: 500.52   z0: 499.01   misfit: 1.93e+01
# itreação: 732   r: 500.52   z0: 499.02   misfit: 1.93e+01
# itreação: 733   r: 500.51   z0: 499.03   misfit: 1.93e+01
# itreação: 734   r: 500.51   z0: 499.04   misfit: 1.93e+01
# itreação: 735   r: 500.51   z0: 499.05   misfit: 1.93e+01
# itreação: 736   r: 500.50   z0: 499.06   misfit: 1.93e+01
# itreação: 737   r: 500.50   z0: 499.07   misfit: 1.93e+01
# itreação: 738   r: 500.50   z0: 499.08   misfit: 1.93e+01
# itreação: 739   r: 500.50   z0: 499.09   misfit: 1.93e+01
# itreação: 740   r: 500.49   z0: 499.11   misfit: 1.93e+01
# itreação: 741   r: 500.49   z0: 499.12   misfit: 1.93e+01
# itreação: 742   r: 500.49   z0: 499.13   misfit: 1.93e+01
# itreação: 743   r: 500.49   z0: 499.14   misfit: 1.93e+01
# itreação: 744   r: 500.48   z0: 499.15   misfit: 1.93e+01
# itreação: 745   r: 500.48   z0: 499.16   misfit: 1.93e+01
# itreação: 746   r: 500.48   z0: 499.17   misfit: 1.93e+01
# itreação: 747   r: 500.48   z0: 499.18   misfit: 1.93e+01
# itreação: 748   r: 500.47   z0: 499.19   misfit: 1.93e+01
# itreação: 749   r: 500.47   z0: 499.20   misfit: 1.93e+01
# itreação: 750   r: 500.47   z0: 499.21   misfit: 1.93e+01
# itreação: 751   r: 500.47   z0: 499.22   misfit: 1.93e+01
# itreação: 752   r: 500.46   z0: 499.23   misfit: 1.93e+01
# itreação: 753   r: 500.46   z0: 499.24   misfit: 1.93e+01
# itreação: 754   r: 500.46   z0: 499.25   misfit: 1.93e+01
# itreação: 755   r: 500.46   z0: 499.26   misfit: 1.93e+01
# itreação: 756   r: 500.45   z0: 499.27   misfit: 1.93e+01
# itreação: 757   r: 500.45   z0: 499.28   misfit: 1.93e+01
# itreação: 758   r: 500.45   z0: 499.29   misfit: 1.93e+01
# itreação: 759   r: 500.45   z0: 499.30   misfit: 1.93e+01
# itreação: 760   r: 500.44   z0: 499.30   misfit: 1.93e+01
# itreação: 761   r: 500.44   z0: 499.31   misfit: 1.93e+01
# itreação: 762   r: 500.44   z0: 499.32   misfit: 1.93e+01
# itreação: 763   r: 500.44   z0: 499.33   misfit: 1.93e+01
# itreação: 764   r: 500.44   z0: 499.34   misfit: 1.93e+01
# itreação: 765   r: 500.43   z0: 499.35   misfit: 1.93e+01
# itreação: 766   r: 500.43   z0: 499.36   misfit: 1.93e+01
# itreação: 767   r: 500.43   z0: 499.37   misfit: 1.93e+01
# itreação: 768   r: 500.43   z0: 499.38   misfit: 1.93e+01
# itreação: 769   r: 500.42   z0: 499.39   misfit: 1.93e+01
# itreação: 770   r: 500.42   z0: 499.40   misfit: 1.93e+01
# itreação: 771   r: 500.42   z0: 499.41   misfit: 1.93e+01
# itreação: 772   r: 500.42   z0: 499.42   misfit: 1.93e+01
# itreação: 773   r: 500.41   z0: 499.43   misfit: 1.93e+01
# itreação: 774   r: 500.41   z0: 499.44   misfit: 1.93e+01
# itreação: 775   r: 500.41   z0: 499.45   misfit: 1.93e+01
# itreação: 776   r: 500.41   z0: 499.46   misfit: 1.93e+01
# itreação: 777   r: 500.40   z0: 499.47   misfit: 1.93e+01
# itreação: 778   r: 500.40   z0: 499.48   misfit: 1.93e+01
# itreação: 779   r: 500.40   z0: 499.48   misfit: 1.93e+01
# itreação: 780   r: 500.40   z0: 499.49   misfit: 1.93e+01
# itreação: 781   r: 500.40   z0: 499.50   misfit: 1.93e+01
# itreação: 782   r: 500.39   z0: 499.51   misfit: 1.93e+01
# itreação: 783   r: 500.39   z0: 499.52   misfit: 1.93e+01
# itreação: 784   r: 500.39   z0: 499.53   misfit: 1.92e+01
# itreação: 785   r: 500.39   z0: 499.54   misfit: 1.92e+01
# itreação: 786   r: 500.38   z0: 499.55   misfit: 1.92e+01
# itreação: 787   r: 500.38   z0: 499.56   misfit: 1.92e+01
# itreação: 788   r: 500.38   z0: 499.57   misfit: 1.92e+01
# itreação: 789   r: 500.38   z0: 499.58   misfit: 1.92e+01
# itreação: 790   r: 500.37   z0: 499.58   misfit: 1.92e+01
# itreação: 791   r: 500.37   z0: 499.59   misfit: 1.92e+01
# itreação: 792   r: 500.37   z0: 499.60   misfit: 1.92e+01
# itreação: 793   r: 500.37   z0: 499.61   misfit: 1.92e+01
# itreação: 794   r: 500.37   z0: 499.62   misfit: 1.92e+01
# itreação: 795   r: 500.36   z0: 499.63   misfit: 1.92e+01
# itreação: 796   r: 500.36   z0: 499.64   misfit: 1.92e+01
# itreação: 797   r: 500.36   z0: 499.65   misfit: 1.92e+01
# itreação: 798   r: 500.36   z0: 499.66   misfit: 1.92e+01
# itreação: 799   r: 500.36   z0: 499.66   misfit: 1.92e+01
# itreação: 800   r: 500.35   z0: 499.67   misfit: 1.92e+01
# itreação: 801   r: 500.35   z0: 499.68   misfit: 1.92e+01
# itreação: 802   r: 500.35   z0: 499.69   misfit: 1.92e+01
# itreação: 803   r: 500.35   z0: 499.70   misfit: 1.92e+01
# itreação: 804   r: 500.34   z0: 499.71   misfit: 1.92e+01
# itreação: 805   r: 500.34   z0: 499.72   misfit: 1.92e+01
# itreação: 806   r: 500.34   z0: 499.72   misfit: 1.92e+01
# itreação: 807   r: 500.34   z0: 499.73   misfit: 1.92e+01
# itreação: 808   r: 500.34   z0: 499.74   misfit: 1.92e+01
# itreação: 809   r: 500.33   z0: 499.75   misfit: 1.92e+01
# itreação: 810   r: 500.33   z0: 499.76   misfit: 1.92e+01
# itreação: 811   r: 500.33   z0: 499.77   misfit: 1.92e+01
# itreação: 812   r: 500.33   z0: 499.78   misfit: 1.92e+01
# itreação: 813   r: 500.33   z0: 499.78   misfit: 1.92e+01
# itreação: 814   r: 500.32   z0: 499.79   misfit: 1.92e+01
# itreação: 815   r: 500.32   z0: 499.80   misfit: 1.92e+01
# itreação: 816   r: 500.32   z0: 499.81   misfit: 1.92e+01
# itreação: 817   r: 500.32   z0: 499.82   misfit: 1.92e+01
# itreação: 818   r: 500.31   z0: 499.83   misfit: 1.92e+01
# itreação: 819   r: 500.31   z0: 499.83   misfit: 1.92e+01
# itreação: 820   r: 500.31   z0: 499.84   misfit: 1.92e+01
# itreação: 821   r: 500.31   z0: 499.85   misfit: 1.92e+01
# itreação: 822   r: 500.31   z0: 499.86   misfit: 1.92e+01
# itreação: 823   r: 500.30   z0: 499.87   misfit: 1.92e+01
# itreação: 824   r: 500.30   z0: 499.87   misfit: 1.92e+01
# itreação: 825   r: 500.30   z0: 499.88   misfit: 1.92e+01
# itreação: 826   r: 500.30   z0: 499.89   misfit: 1.92e+01
# itreação: 827   r: 500.30   z0: 499.90   misfit: 1.92e+01
# itreação: 828   r: 500.29   z0: 499.91   misfit: 1.92e+01
# itreação: 829   r: 500.29   z0: 499.91   misfit: 1.92e+01
# itreação: 830   r: 500.29   z0: 499.92   misfit: 1.92e+01
# itreação: 831   r: 500.29   z0: 499.93   misfit: 1.92e+01
# itreação: 832   r: 500.29   z0: 499.94   misfit: 1.92e+01
# itreação: 833   r: 500.28   z0: 499.95   misfit: 1.92e+01
# itreação: 834   r: 500.28   z0: 499.95   misfit: 1.92e+01
# itreação: 835   r: 500.28   z0: 499.96   misfit: 1.92e+01
# itreação: 836   r: 500.28   z0: 499.97   misfit: 1.92e+01
# itreação: 837   r: 500.28   z0: 499.98   misfit: 1.92e+01
# itreação: 838   r: 500.27   z0: 499.99   misfit: 1.92e+01
# itreação: 839   r: 500.27   z0: 499.99   misfit: 1.92e+01
# itreação: 840   r: 500.27   z0: 500.00   misfit: 1.92e+01
# itreação: 841   r: 500.27   z0: 500.01   misfit: 1.92e+01
# itreação: 842   r: 500.27   z0: 500.02   misfit: 1.92e+01
# itreação: 843   r: 500.27   z0: 500.03   misfit: 1.92e+01
# itreação: 844   r: 500.26   z0: 500.03   misfit: 1.92e+01
# itreação: 845   r: 500.26   z0: 500.04   misfit: 1.92e+01
# itreação: 846   r: 500.26   z0: 500.05   misfit: 1.92e+01
# itreação: 847   r: 500.26   z0: 500.06   misfit: 1.92e+01
# itreação: 848   r: 500.26   z0: 500.06   misfit: 1.92e+01
# itreação: 849   r: 500.25   z0: 500.07   misfit: 1.92e+01
# itreação: 850   r: 500.25   z0: 500.08   misfit: 1.92e+01
# itreação: 851   r: 500.25   z0: 500.09   misfit: 1.92e+01
# itreação: 852   r: 500.25   z0: 500.09   misfit: 1.92e+01
# itreação: 853   r: 500.25   z0: 500.10   misfit: 1.92e+01
# itreação: 854   r: 500.24   z0: 500.11   misfit: 1.92e+01
# itreação: 855   r: 500.24   z0: 500.12   misfit: 1.92e+01
# itreação: 856   r: 500.24   z0: 500.12   misfit: 1.92e+01
# itreação: 857   r: 500.24   z0: 500.13   misfit: 1.92e+01
# itreação: 858   r: 500.24   z0: 500.14   misfit: 1.92e+01
# itreação: 859   r: 500.24   z0: 500.15   misfit: 1.92e+01
# itreação: 860   r: 500.23   z0: 500.15   misfit: 1.92e+01
# itreação: 861   r: 500.23   z0: 500.16   misfit: 1.92e+01
# itreação: 862   r: 500.23   z0: 500.17   misfit: 1.92e+01
# itreação: 863   r: 500.23   z0: 500.18   misfit: 1.92e+01
# itreação: 864   r: 500.23   z0: 500.18   misfit: 1.92e+01
# itreação: 865   r: 500.22   z0: 500.19   misfit: 1.92e+01
# itreação: 866   r: 500.22   z0: 500.20   misfit: 1.92e+01
# itreação: 867   r: 500.22   z0: 500.20   misfit: 1.92e+01
# itreação: 868   r: 500.22   z0: 500.21   misfit: 1.92e+01
# itreação: 869   r: 500.22   z0: 500.22   misfit: 1.92e+01
# itreação: 870   r: 500.22   z0: 500.23   misfit: 1.92e+01
# itreação: 871   r: 500.21   z0: 500.23   misfit: 1.92e+01
# itreação: 872   r: 500.21   z0: 500.24   misfit: 1.92e+01
# itreação: 873   r: 500.21   z0: 500.25   misfit: 1.92e+01
# itreação: 874   r: 500.21   z0: 500.25   misfit: 1.92e+01
# itreação: 875   r: 500.21   z0: 500.26   misfit: 1.92e+01
# itreação: 876   r: 500.20   z0: 500.27   misfit: 1.92e+01
# itreação: 877   r: 500.20   z0: 500.28   misfit: 1.92e+01
# itreação: 878   r: 500.20   z0: 500.28   misfit: 1.92e+01
# itreação: 879   r: 500.20   z0: 500.29   misfit: 1.92e+01
# itreação: 880   r: 500.20   z0: 500.30   misfit: 1.92e+01
# itreação: 881   r: 500.20   z0: 500.30   misfit: 1.92e+01
# itreação: 882   r: 500.19   z0: 500.31   misfit: 1.92e+01
# itreação: 883   r: 500.19   z0: 500.32   misfit: 1.92e+01
# itreação: 884   r: 500.19   z0: 500.32   misfit: 1.92e+01
# itreação: 885   r: 500.19   z0: 500.33   misfit: 1.92e+01
# itreação: 886   r: 500.19   z0: 500.34   misfit: 1.92e+01
# itreação: 887   r: 500.19   z0: 500.35   misfit: 1.92e+01
# itreação: 888   r: 500.18   z0: 500.35   misfit: 1.92e+01
# itreação: 889   r: 500.18   z0: 500.36   misfit: 1.92e+01
# itreação: 890   r: 500.18   z0: 500.37   misfit: 1.92e+01
# itreação: 891   r: 500.18   z0: 500.37   misfit: 1.92e+01
# itreação: 892   r: 500.18   z0: 500.38   misfit: 1.92e+01
# itreação: 893   r: 500.18   z0: 500.39   misfit: 1.92e+01
# itreação: 894   r: 500.17   z0: 500.39   misfit: 1.92e+01
# itreação: 895   r: 500.17   z0: 500.40   misfit: 1.92e+01
# itreação: 896   r: 500.17   z0: 500.41   misfit: 1.92e+01
# itreação: 897   r: 500.17   z0: 500.41   misfit: 1.92e+01
# itreação: 898   r: 500.17   z0: 500.42   misfit: 1.92e+01
# itreação: 899   r: 500.17   z0: 500.43   misfit: 1.92e+01
# itreação: 900   r: 500.16   z0: 500.43   misfit: 1.92e+01
# itreação: 901   r: 500.16   z0: 500.44   misfit: 1.92e+01
# itreação: 902   r: 500.16   z0: 500.45   misfit: 1.92e+01
# itreação: 903   r: 500.16   z0: 500.45   misfit: 1.92e+01
# itreação: 904   r: 500.16   z0: 500.46   misfit: 1.92e+01
# itreação: 905   r: 500.16   z0: 500.47   misfit: 1.92e+01
# itreação: 906   r: 500.15   z0: 500.47   misfit: 1.92e+01
# itreação: 907   r: 500.15   z0: 500.48   misfit: 1.92e+01
# itreação: 908   r: 500.15   z0: 500.48   misfit: 1.92e+01
# itreação: 909   r: 500.15   z0: 500.49   misfit: 1.92e+01
# itreação: 910   r: 500.15   z0: 500.50   misfit: 1.92e+01
# itreação: 911   r: 500.15   z0: 500.50   misfit: 1.92e+01
# itreação: 912   r: 500.14   z0: 500.51   misfit: 1.92e+01
# itreação: 913   r: 500.14   z0: 500.52   misfit: 1.92e+01
# itreação: 914   r: 500.14   z0: 500.52   misfit: 1.92e+01
# itreação: 915   r: 500.14   z0: 500.53   misfit: 1.92e+01
# itreação: 916   r: 500.14   z0: 500.54   misfit: 1.92e+01
# itreação: 917   r: 500.14   z0: 500.54   misfit: 1.92e+01
# itreação: 918   r: 500.13   z0: 500.55   misfit: 1.92e+01
# itreação: 919   r: 500.13   z0: 500.55   misfit: 1.92e+01
# itreação: 920   r: 500.13   z0: 500.56   misfit: 1.92e+01
# itreação: 921   r: 500.13   z0: 500.57   misfit: 1.92e+01
# itreação: 922   r: 500.13   z0: 500.57   misfit: 1.92e+01
# itreação: 923   r: 500.13   z0: 500.58   misfit: 1.92e+01
# itreação: 924   r: 500.13   z0: 500.59   misfit: 1.92e+01
# itreação: 925   r: 500.12   z0: 500.59   misfit: 1.92e+01
# itreação: 926   r: 500.12   z0: 500.60   misfit: 1.92e+01
# itreação: 927   r: 500.12   z0: 500.60   misfit: 1.92e+01
# itreação: 928   r: 500.12   z0: 500.61   misfit: 1.92e+01
# itreação: 929   r: 500.12   z0: 500.62   misfit: 1.92e+01
# itreação: 930   r: 500.12   z0: 500.62   misfit: 1.92e+01
# itreação: 931   r: 500.11   z0: 500.63   misfit: 1.92e+01
# itreação: 932   r: 500.11   z0: 500.63   misfit: 1.92e+01
# itreação: 933   r: 500.11   z0: 500.64   misfit: 1.92e+01
# itreação: 934   r: 500.11   z0: 500.65   misfit: 1.92e+01
# itreação: 935   r: 500.11   z0: 500.65   misfit: 1.92e+01
# itreação: 936   r: 500.11   z0: 500.66   misfit: 1.92e+01
# itreação: 937   r: 500.11   z0: 500.66   misfit: 1.92e+01
# itreação: 938   r: 500.10   z0: 500.67   misfit: 1.92e+01
# itreação: 939   r: 500.10   z0: 500.68   misfit: 1.92e+01
# itreação: 940   r: 500.10   z0: 500.68   misfit: 1.92e+01
# itreação: 941   r: 500.10   z0: 500.69   misfit: 1.92e+01
# itreação: 942   r: 500.10   z0: 500.69   misfit: 1.92e+01
# itreação: 943   r: 500.10   z0: 500.70   misfit: 1.92e+01
# itreação: 944   r: 500.10   z0: 500.71   misfit: 1.92e+01
# itreação: 945   r: 500.09   z0: 500.71   misfit: 1.92e+01
# itreação: 946   r: 500.09   z0: 500.72   misfit: 1.92e+01
# itreação: 947   r: 500.09   z0: 500.72   misfit: 1.92e+01
# itreação: 948   r: 500.09   z0: 500.73   misfit: 1.92e+01
# itreação: 949   r: 500.09   z0: 500.74   misfit: 1.92e+01
# itreação: 950   r: 500.09   z0: 500.74   misfit: 1.92e+01
# itreação: 951   r: 500.09   z0: 500.75   misfit: 1.92e+01
# itreação: 952   r: 500.08   z0: 500.75   misfit: 1.92e+01
# itreação: 953   r: 500.08   z0: 500.76   misfit: 1.92e+01
# itreação: 954   r: 500.08   z0: 500.76   misfit: 1.92e+01
# itreação: 955   r: 500.08   z0: 500.77   misfit: 1.92e+01
# itreação: 956   r: 500.08   z0: 500.78   misfit: 1.92e+01
# itreação: 957   r: 500.08   z0: 500.78   misfit: 1.92e+01
# itreação: 958   r: 500.08   z0: 500.79   misfit: 1.92e+01
# itreação: 959   r: 500.07   z0: 500.79   misfit: 1.92e+01
# itreação: 960   r: 500.07   z0: 500.80   misfit: 1.92e+01
# itreação: 961   r: 500.07   z0: 500.80   misfit: 1.92e+01
# itreação: 962   r: 500.07   z0: 500.81   misfit: 1.92e+01
# itreação: 963   r: 500.07   z0: 500.81   misfit: 1.92e+01
# itreação: 964   r: 500.07   z0: 500.82   misfit: 1.92e+01
# itreação: 965   r: 500.07   z0: 500.83   misfit: 1.92e+01
# itreação: 966   r: 500.06   z0: 500.83   misfit: 1.92e+01
# itreação: 967   r: 500.06   z0: 500.84   misfit: 1.92e+01
# itreação: 968   r: 500.06   z0: 500.84   misfit: 1.92e+01
# itreação: 969   r: 500.06   z0: 500.85   misfit: 1.92e+01
# itreação: 970   r: 500.06   z0: 500.85   misfit: 1.92e+01
# itreação: 971   r: 500.06   z0: 500.86   misfit: 1.92e+01
# itreação: 972   r: 500.06   z0: 500.86   misfit: 1.92e+01
# itreação: 973   r: 500.06   z0: 500.87   misfit: 1.92e+01
# itreação: 974   r: 500.05   z0: 500.87   misfit: 1.92e+01
# itreação: 975   r: 500.05   z0: 500.88   misfit: 1.92e+01
# itreação: 976   r: 500.05   z0: 500.89   misfit: 1.92e+01
# itreação: 977   r: 500.05   z0: 500.89   misfit: 1.92e+01
# itreação: 978   r: 500.05   z0: 500.90   misfit: 1.92e+01
# itreação: 979   r: 500.05   z0: 500.90   misfit: 1.92e+01
# itreação: 980   r: 500.05   z0: 500.91   misfit: 1.92e+01
# itreação: 981   r: 500.04   z0: 500.91   misfit: 1.92e+01
# itreação: 982   r: 500.04   z0: 500.92   misfit: 1.92e+01
# itreação: 983   r: 500.04   z0: 500.92   misfit: 1.92e+01
# itreação: 984   r: 500.04   z0: 500.93   misfit: 1.92e+01
# itreação: 985   r: 500.04   z0: 500.93   misfit: 1.92e+01
# itreação: 986   r: 500.04   z0: 500.94   misfit: 1.92e+01
# itreação: 987   r: 500.04   z0: 500.94   misfit: 1.92e+01
# itreação: 988   r: 500.04   z0: 500.95   misfit: 1.92e+01
# itreação: 989   r: 500.03   z0: 500.95   misfit: 1.92e+01
# itreação: 990   r: 500.03   z0: 500.96   misfit: 1.92e+01
# itreação: 991   r: 500.03   z0: 500.96   misfit: 1.92e+01
# itreação: 992   r: 500.03   z0: 500.97   misfit: 1.92e+01
# itreação: 993   r: 500.03   z0: 500.97   misfit: 1.92e+01
# itreação: 994   r: 500.03   z0: 500.98   misfit: 1.92e+01
# itreação: 995   r: 500.03   z0: 500.98   misfit: 1.92e+01
# itreação: 996   r: 500.03   z0: 500.99   misfit: 1.92e+01
# itreação: 997   r: 500.02   z0: 501.00   misfit: 1.92e+01
# itreação: 998   r: 500.02   z0: 501.00   misfit: 1.92e+01
# itreação: 999   r: 500.02   z0: 501.01   misfit: 1.92e+01

# %% [markdown]
# # Plots de resultados

# %%
res_norm = (res - np.mean(res))/np.std(res)
res_plot = res.reshape(shape)
xp = xp.reshape(shape)
yp = yp.reshape(shape)
dpred = data.reshape(shape)
dobs = data_noise.reshape(shape)

# %%
#plot
plt.figure(figsize=(5,5))
plt.plot(r_true, dz_true, 'oy')
plt.plot(p1_list, p2_list, '.w-', markersize=5)
plt.title('SD - geofisica', fontsize=18)
plt.contourf(r_plot, dz_plot, phi_eq, 40, cmap='jet')
plt.xlabel('$r$', fontsize=18)
plt.ylabel('$dz$', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Convergencia', fontsize = 18)
plt.xlabel('Iteration number')
plt.plot(phi_list, 'o')

plt.subplot(1, 3, 2)
plt.title('Estimativas de  r', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('r')
plt.plot(p1_list, 'o')
plt.plot(np.zeros(len(p1_list)) + r_true, '-')

plt.subplot(1, 3, 3)
plt.title('Estimativas de  dz', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('z0')
plt.plot(p2_list, 'o')
plt.plot(np.zeros(len(p1_list)) + dz_true, '-')
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Dado predito', fontsize=20)
plt.contourf(yp, xp, dpred, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 2)
plt.title('Dado observado', fontsize=20)
plt.contourf(yp, xp, dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 3)
plt.title('SD - ajuste', fontsize=20)
plt.contourf(yp, xp, res_plot, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)
plt.show()

# %%
plt.plot(figsize=(20,5))
plt.title('Histogram', fontsize = 20)
plt.xlabel('$\mu$ = %.7f  $\sigma$ = %.7f' % (np.mean(res_norm), np.std(res_norm)), fontsize=20)
nbins = int((np.max(res_norm) - np.min(res_norm)))
plt.hist(res_norm,bins=nbins, normed=True)
plt.ylim(0.,0.5)
plt.xlim(-10., 10.)
plt.show()
