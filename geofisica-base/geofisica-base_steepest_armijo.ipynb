# %% [markdown]
# # Steepest Descent com critério de Armijo aplicado à função geofísica

# %% [markdown]
# Algoritmo de Steepest Descent com critério de Armijo aplicado a um problema geofísico para estimar o raio e a espessura um prisma de base poligonal próximo de um cilindro.

# %% [markdown]
# # Importando pacotes

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
from visual import histeq
from fatiando import utils
from fatiando.mesher import PolygonalPrism
from IPython.display import Image as img
from fatiando.gravmag import polyprism
from copy import deepcopy
from fatiando.vis import myv
from fatiando.gridder import regular
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# # Funções para o prisma de base polygonal do fatiando

# %%
def pol2cart(l, M, L):
    '''
    This function transforms polar coordinates of the prisms
    into Cartesian coordinates and returns a list of polygonal
    prisms of the Fatiando a Terra.

    input

    l: list - each element is a list of [r, x0, y0, z1, z2, 'magnetization'],
              whrere r is an array with the radial distances of the vertices,
              x0 and y0 are the origin cartesian coordinates of each prism,
              z1 and z2 are the top and bottom of each prism and
              magnetization is physical property
    M: int - number of vertices per prism
    L: int - number of prisms

    output

    mk: list - list of objects of the class
    fatiando.mesher.PolygonalPrism
    '''

    lk = []
    r = np.zeros(M)  # it contains radial distances of the vertices in polar coordinates
    verts = [] # it contains radial distances of the vertices in Cartesian coordinates

    assert len(l) == L, 'The size of m and the number of prisms must be equal'

    for lv in l:
        assert len(lv[0]) == M, 'All prisms must have M vertices'

    ang = 2*np.pi/M # angle between two vertices

    for lv in l:
        r = lv[0]
        verts=[]
        for i in range(M):
            verts.append([r[i]*np.cos(i*ang) + lv[1], r[i]*np.sin(i*ang) + lv[2]])
        lk.append(PolygonalPrism(verts, lv[3], lv[4], lv[5]))

    return lk

def param2polyprism(m, M, L, z0, dz, props):
    '''
    Returns a lis of objects of the class
    fatiando.mesher.PolygonalPrism

    input

    m: 1D array - parameter vector
    M: int - number of vertices
    L: int - number of prisms
    z0: float - top of the model
    dz: float - thickness of each prism
    props: dictionary - physical property

    output

    mv: list - list of fatiando.mesher.PolygonalPrism
    '''
    P = L*(M + 2)
    assert m.size == P, 'The size of m must be equal to L*(M + 2)'
    for i in range(P):
        assert m[i:i+M].all >= 0., 'The radial distances must be positives'

    r = np.zeros(M) # vector for radial distances
    mv = [] # list of prisms

    k = 0.
    for i in range(0, P, M + 2):
        r = m[i:M+i]
        mv.append([r, m[i+M], m[i+M+1], z0 + dz*k, z0 + dz*(k + 1.), props])
        k = k + 1.

    mv = pol2cart(mv, M, L)

    return mv

# %% [markdown]
# # Modelagem direta

# %%
M = 10 # number of vertices per prism
L = 1 # number of prisms
P = L*(M+2) # number of parameters

z0 = 100.    # depth of the top the shallowest prism
dz_true = 500.    # thickness of each prism

inc = -60.  # inclination
dec = 50.   # declination
intensity = 0.035 # intensity

props={'magnetization': utils.ang2vec(intensity, inc, dec)} # physical property: magnetization

r_true = 500.

r = np.zeros(M) + r_true # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

l = [[r, x0, y0, z0, z0 + dz_true, props]]   # list of parameters of the prisms

# criando os prismas do fatiando
prisms = pol2cart(l, M, L)

# %%
img(filename='bolacha.png')

# %% [markdown]
# # Pontos de observação

# %%
area = [-2000, 2000, -2000, 2000] #x minimum, x maximum, y minimum and y maximum
shape = (50,50) #number of data along the y and x directions
N = shape[0]*shape[1] #total number of data

#coordinates x and y of the data
xp, yp = regular(area, shape)

zp = np.zeros(N) - 100.

# %% [markdown]
# # Dados observados

# %%
data = polyprism.tf(xp, yp, zp, prisms, inc, dec) # predict data
amp_noise = 0.01*np.max(data)
data_noise = data + np.random.normal(loc=0., scale=amp_noise, size=shape[0]*shape[1]) # noise corrupted data

# %% [markdown]
# # Plot função desajuste

# %%
r_plot = np.linspace(100., 1000., 20)
dz_plot = np.linspace(10., 1000., 20)
r_plot,dz_plot = np.meshgrid(r_plot, dz_plot)
r_plot = r_plot.ravel()
dz_plot = dz_plot.ravel()
phi_plot = np.zeros_like(r_plot)

for i, (r, dz) in enumerate(zip(r_plot,dz_plot)):
    m = np.zeros(M) + r
    m = np.hstack((m,np.zeros(2)))
    l = param2polyprism(m, M, L, z0, z0 + dz, props)
    d_pred = polyprism.tf(xp, yp, zp, l, inc, dec)
    phi_plot[i] = np.sum((data - d_pred)**2)

r_plot = r_plot.reshape((20,20))
dz_plot = dz_plot.reshape((20,20))
phi_plot = phi_plot.reshape((20,20))

# equalizando as cores
phi_eq = histeq(phi_plot)
phi_eq = np.reshape(phi_eq,(20,20))
phi_eq = phi_eq

# %%
plt.figure(figsize=(5,5))
plt.plot(r_true, dz_true, 'og')
plt.title('Funcao objetivo', fontsize=18)
plt.contourf(r_plot, dz_plot, phi_eq, 50, cmap='jet')
plt.xlabel('$r$ (m)', fontsize=18)
plt.ylabel('$dz$ (m)', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.show()

# %% [markdown]
# # Funções

# %%
def derivative_tf_dz(xp, yp, zp, prism, M, deltaz, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of one fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    delta: float - increment in x coordinate in meters
    inc: float - inclination
    dec: declination

    output

    df1: 1D array - derivative plus
    df2: 1D array - derivative minus
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - deltaa
    prism_plus[0].z2 += deltaz
    prism_minus[0].z2 -= deltaz

    df1 = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df2 = polyprism.tf(xp, yp, zp, prism_minus, inc, dec)

    return df1, df2

def derivative_tf_radiall(xp, yp, zp, prism, M, deltar, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of a fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in radial distance in meters
    inc: float - inclination
    dec: declination

    output

    df1: 1D array - derivative plus
    df2: 1D array - derivative minus
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'
    
    ang = 2.*np.pi/M # angle between two vertices
    
    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - delta

    for i in range(M):
        deltax = deltar*np.cos(i*ang)
        deltay = deltar*np.sin(i*ang)
        prism_plus[0].x[i] += deltax
        prism_plus[0].y[i] += deltay
        prism_minus[0].x[i] -= deltax
        prism_minus[0].y[i] -= deltay

    df1 = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df2 = polyprism.tf(xp, yp, zp, prism_minus, inc, dec)

    return df1, df2

def grad_geo(xp, yp, zp, prism, M, deltar, deltaz, inc, dec, dobs):
    '''
    Returns the gradient vector for polygonal prisms using finite
    differences.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in meters for radial distance
    deltaz: float - increment in meters for depth
    inc: float - inclination of the local-geomagnetic field
    dec: float - declination of the local-geomagnetic field
    dobs: 1D array - data vector

    output

    grad: 1D array - gradient
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'
    
    drp, drm = derivative_tf_radiall(xp, yp, zp, prism[0], M, deltar, inc, dec)
    dzp, dzm = derivative_tf_dz(xp, yp, zp, prism[0], M, deltaz, inc, dec)
    grad = np.zeros(2)
    grad[0] = (np.sum((dobs - drp)*(dobs - drp)) - np.sum((dobs - drm)*(dobs - drm)))/(2.*deltar)
    grad[1] = (np.sum((dobs - dzp)*(dobs - dzp)) - np.sum((dobs - dzm)*(dobs - dzm)))/(2.*deltaz)
    
    return grad

# %% [markdown]
# # Modelo interpretativo

# %%
# chute inicial
p01 = 900.
p02 = 300.

# incremento para as derivadas
deltar = 0.01*p01
deltaz = 0.01*p02

r = np.zeros(M) + p01 # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

l = [[r, x0, y0, z0, z0 + p02, props]]

prism0 = pol2cart(l, M, L)

d0 = polyprism.tf(xp, yp, zp, prism0, inc, dec)

# vetor do chute inicial
p0 = np.array([p01,p02]) 

# parâmetro de regularização
mi = 0.0000000

# parâmetros para o critério de Armijo
alfa = 0.0001
beta = 0.4

# critério de parada
epsilon = 0.00000001

# calculando o valor da função e do resíduo em p0
res0 = data_noise - d0
phi0 = np.sum(res0*res0)

# listas para armazenar as estimativas
p1_list = [p01]
p2_list = [p02]
phi_list = [phi0]

# iterações do algoritmo
itmax = 1000

# %% [markdown]
# # Algoritmo Steepest Descent com Armijo

# %%
for i in range(itmax):
    m = 0.
    lamb = 1.
    # calculando a Jacobiana e o gradiente
    grad = grad_geo(xp, yp, zp, prism0, M, deltar, deltaz, inc, dec, data_noise)
    #print grad
    # calculando p e atualizando para a próxima iteração
    p = p0 - lamb*grad
    #print p, p0
    l = [[np.zeros(M) + p[0], x0, y0, z0, z0 + p[1], props]]
    prism = pol2cart(l, M, L)
    d = polyprism.tf(xp, yp, zp, prism, inc, dec)
    res = data_noise - d
    phi = np.sum(res*res) + mi*np.dot(p0, p0)
    
    # condição de Armijo
    while (phi - phi0) > alfa*lamb*np.sum(grad*grad):
        m += 1.
        print m
        lamb = beta**m
        #print lamb
        p = p0 - lamb*grad
        l = [[np.zeros(M) + p[0], x0, y0, z0, z0 + p[1], props]]
        prism = pol2cart(l, M, L)
        d = polyprism.tf(xp, yp, zp, prism, inc, dec)
        res = data_noise - d
        phi = np.sum(res*res) + mi*np.dot(p0, p0)
    
    # printa os valores
    print 'itreação: %3d   r: %.2f   dz: %.2f   misfit: %.2e' % (i, p[0], p[1], phi)
    
    # armazenando os resultados em listas para o plot
    phi_list.append(phi)
    p1_list.append(p[0])
    p2_list.append(p[1])
    
    if abs(phi-phi0)/phi0 <= epsilon:
        break
    else:
        # atualizando parâmetros
        p0 = p.copy()
        d0 = d.copy()
        res0 = res.copy()
        phi0 = phi
        prism0 = prism
# Out:
# itreação:   0   r: 879.21   z0: 282.98   misfit: 3.59e+03
# itreação:   1   r: 860.38   z0: 268.65   misfit: 3.07e+03
# itreação:   2   r: 843.22   z0: 256.73   misfit: 2.65e+03
# itreação:   3   r: 827.51   z0: 246.96   misfit: 2.33e+03
# itreação:   4   r: 813.06   z0: 239.07   misfit: 2.07e+03
# itreação:   5   r: 799.68   z0: 232.83   misfit: 1.87e+03
# itreação:   6   r: 787.23   z0: 228.03   misfit: 1.70e+03
# itreação:   7   r: 775.60   z0: 224.45   misfit: 1.56e+03
# itreação:   8   r: 764.69   z0: 221.91   misfit: 1.43e+03
# itreação:   9   r: 754.41   z0: 220.27   misfit: 1.33e+03
# itreação:  10   r: 744.70   z0: 219.38   misfit: 1.24e+03
# itreação:  11   r: 735.50   z0: 219.12   misfit: 1.15e+03
# itreação:  12   r: 726.77   z0: 219.39   misfit: 1.08e+03
# itreação:  13   r: 718.47   z0: 220.09   misfit: 1.01e+03
# itreação:  14   r: 710.57   z0: 221.17   misfit: 9.50e+02
# itreação:  15   r: 703.05   z0: 222.54   misfit: 8.93e+02
# itreação:  16   r: 695.88   z0: 224.17   misfit: 8.39e+02
# itreação:  17   r: 689.04   z0: 226.00   misfit: 7.90e+02
# itreação:  18   r: 682.52   z0: 227.99   misfit: 7.45e+02
# itreação:  19   r: 676.30   z0: 230.12   misfit: 7.02e+02
# itreação:  20   r: 670.36   z0: 232.35   misfit: 6.63e+02
# itreação:  21   r: 664.71   z0: 234.67   misfit: 6.26e+02
# itreação:  22   r: 659.31   z0: 237.04   misfit: 5.92e+02
# itreação:  23   r: 654.17   z0: 239.47   misfit: 5.60e+02
# itreação:  24   r: 649.26   z0: 241.93   misfit: 5.30e+02
# itreação:  25   r: 644.59   z0: 244.41   misfit: 5.03e+02
# itreação:  26   r: 640.14   z0: 246.91   misfit: 4.77e+02
# itreação:  27   r: 635.89   z0: 249.41   misfit: 4.54e+02
# itreação:  28   r: 631.85   z0: 251.91   misfit: 4.31e+02
# itreação:  29   r: 628.00   z0: 254.39   misfit: 4.11e+02
# itreação:  30   r: 624.33   z0: 256.87   misfit: 3.91e+02
# itreação:  31   r: 620.84   z0: 259.33   misfit: 3.74e+02
# itreação:  32   r: 617.51   z0: 261.76   misfit: 3.57e+02
# itreação:  33   r: 614.34   z0: 264.17   misfit: 3.41e+02
# itreação:  34   r: 611.32   z0: 266.56   misfit: 3.27e+02
# itreação:  35   r: 608.44   z0: 268.92   misfit: 3.13e+02
# itreação:  36   r: 605.70   z0: 271.25   misfit: 3.00e+02
# itreação:  37   r: 603.08   z0: 273.55   misfit: 2.88e+02
# itreação:  38   r: 600.59   z0: 275.82   misfit: 2.77e+02
# itreação:  39   r: 598.20   z0: 278.05   misfit: 2.67e+02
# itreação:  40   r: 595.93   z0: 280.25   misfit: 2.57e+02
# itreação:  41   r: 593.76   z0: 282.42   misfit: 2.47e+02
# itreação:  42   r: 591.69   z0: 284.56   misfit: 2.39e+02
# itreação:  43   r: 589.71   z0: 286.66   misfit: 2.31e+02
# itreação:  44   r: 587.82   z0: 288.73   misfit: 2.23e+02
# itreação:  45   r: 586.00   z0: 290.77   misfit: 2.15e+02
# itreação:  46   r: 584.27   z0: 292.77   misfit: 2.09e+02
# itreação:  47   r: 582.61   z0: 294.75   misfit: 2.02e+02
# itreação:  48   r: 581.02   z0: 296.68   misfit: 1.96e+02
# itreação:  49   r: 579.50   z0: 298.59   misfit: 1.90e+02
# itreação:  50   r: 578.03   z0: 300.47   misfit: 1.84e+02
# itreação:  51   r: 576.63   z0: 302.31   misfit: 1.79e+02
# itreação:  52   r: 575.28   z0: 304.12   misfit: 1.74e+02
# itreação:  53   r: 573.98   z0: 305.91   misfit: 1.69e+02
# itreação:  54   r: 572.74   z0: 307.66   misfit: 1.65e+02
# itreação:  55   r: 571.54   z0: 309.39   misfit: 1.60e+02
# itreação:  56   r: 570.39   z0: 311.08   misfit: 1.56e+02
# itreação:  57   r: 569.27   z0: 312.75   misfit: 1.52e+02
# itreação:  58   r: 568.20   z0: 314.39   misfit: 1.48e+02
# itreação:  59   r: 567.17   z0: 316.00   misfit: 1.45e+02
# itreação:  60   r: 566.17   z0: 317.59   misfit: 1.41e+02
# itreação:  61   r: 565.21   z0: 319.15   misfit: 1.38e+02
# itreação:  62   r: 564.27   z0: 320.69   misfit: 1.35e+02
# itreação:  63   r: 563.37   z0: 322.20   misfit: 1.32e+02
# itreação:  64   r: 562.50   z0: 323.68   misfit: 1.29e+02
# itreação:  65   r: 561.66   z0: 325.14   misfit: 1.26e+02
# itreação:  66   r: 560.84   z0: 326.58   misfit: 1.23e+02
# itreação:  67   r: 560.05   z0: 328.00   misfit: 1.21e+02
# itreação:  68   r: 559.28   z0: 329.39   misfit: 1.18e+02
# itreação:  69   r: 558.53   z0: 330.77   misfit: 1.16e+02
# itreação:  70   r: 557.81   z0: 332.12   misfit: 1.13e+02
# itreação:  71   r: 557.10   z0: 333.45   misfit: 1.11e+02
# itreação:  72   r: 556.42   z0: 334.76   misfit: 1.09e+02
# itreação:  73   r: 555.75   z0: 336.05   misfit: 1.07e+02
# itreação:  74   r: 555.10   z0: 337.32   misfit: 1.05e+02
# itreação:  75   r: 554.47   z0: 338.57   misfit: 1.03e+02
# itreação:  76   r: 553.86   z0: 339.80   misfit: 1.01e+02
# itreação:  77   r: 553.26   z0: 341.01   misfit: 9.91e+01
# itreação:  78   r: 552.68   z0: 342.21   misfit: 9.74e+01
# itreação:  79   r: 552.11   z0: 343.39   misfit: 9.57e+01
# itreação:  80   r: 551.55   z0: 344.55   misfit: 9.40e+01
# itreação:  81   r: 551.01   z0: 345.70   misfit: 9.25e+01
# itreação:  82   r: 550.48   z0: 346.82   misfit: 9.09e+01
# itreação:  83   r: 549.96   z0: 347.94   misfit: 8.94e+01
# itreação:  84   r: 549.46   z0: 349.03   misfit: 8.80e+01
# itreação:  85   r: 548.96   z0: 350.12   misfit: 8.66e+01
# itreação:  86   r: 548.48   z0: 351.18   misfit: 8.52e+01
# itreação:  87   r: 548.01   z0: 352.24   misfit: 8.39e+01
# itreação:  88   r: 547.54   z0: 353.27   misfit: 8.26e+01
# itreação:  89   r: 547.09   z0: 354.30   misfit: 8.14e+01
# itreação:  90   r: 546.65   z0: 355.31   misfit: 8.02e+01
# itreação:  91   r: 546.21   z0: 356.31   misfit: 7.90e+01
# itreação:  92   r: 545.78   z0: 357.29   misfit: 7.78e+01
# itreação:  93   r: 545.37   z0: 358.26   misfit: 7.67e+01
# itreação:  94   r: 544.96   z0: 359.22   misfit: 7.56e+01
# itreação:  95   r: 544.55   z0: 360.17   misfit: 7.46e+01
# itreação:  96   r: 544.16   z0: 361.10   misfit: 7.36e+01
# itreação:  97   r: 543.77   z0: 362.02   misfit: 7.26e+01
# itreação:  98   r: 543.39   z0: 362.93   misfit: 7.16e+01
# itreação:  99   r: 543.02   z0: 363.83   misfit: 7.07e+01
# itreação: 100   r: 542.65   z0: 364.72   misfit: 6.98e+01
# itreação: 101   r: 542.29   z0: 365.60   misfit: 6.89e+01
# itreação: 102   r: 541.93   z0: 366.47   misfit: 6.80e+01
# itreação: 103   r: 541.59   z0: 367.32   misfit: 6.71e+01
# itreação: 104   r: 541.24   z0: 368.17   misfit: 6.63e+01
# itreação: 105   r: 540.91   z0: 369.00   misfit: 6.55e+01
# itreação: 106   r: 540.58   z0: 369.83   misfit: 6.47e+01
# itreação: 107   r: 540.25   z0: 370.65   misfit: 6.40e+01
# itreação: 108   r: 539.93   z0: 371.45   misfit: 6.32e+01
# itreação: 109   r: 539.61   z0: 372.25   misfit: 6.25e+01
# itreação: 110   r: 539.30   z0: 373.04   misfit: 6.18e+01
# itreação: 111   r: 539.00   z0: 373.82   misfit: 6.11e+01
# itreação: 112   r: 538.70   z0: 374.59   misfit: 6.04e+01
# itreação: 113   r: 538.40   z0: 375.35   misfit: 5.97e+01
# itreação: 114   r: 538.11   z0: 376.11   misfit: 5.91e+01
# itreação: 115   r: 537.82   z0: 376.85   misfit: 5.84e+01
# itreação: 116   r: 537.54   z0: 377.59   misfit: 5.78e+01
# itreação: 117   r: 537.26   z0: 378.32   misfit: 5.72e+01
# itreação: 118   r: 536.98   z0: 379.04   misfit: 5.66e+01
# itreação: 119   r: 536.71   z0: 379.75   misfit: 5.60e+01
# itreação: 120   r: 536.44   z0: 380.46   misfit: 5.55e+01
# itreação: 121   r: 536.18   z0: 381.16   misfit: 5.49e+01
# itreação: 122   r: 535.92   z0: 381.85   misfit: 5.44e+01
# itreação: 123   r: 535.66   z0: 382.53   misfit: 5.39e+01
# itreação: 124   r: 535.41   z0: 383.21   misfit: 5.33e+01
# itreação: 125   r: 535.16   z0: 383.88   misfit: 5.28e+01
# itreação: 126   r: 534.91   z0: 384.54   misfit: 5.23e+01
# itreação: 127   r: 534.67   z0: 385.20   misfit: 5.18e+01
# itreação: 128   r: 534.43   z0: 385.85   misfit: 5.14e+01
# itreação: 129   r: 534.19   z0: 386.49   misfit: 5.09e+01
# itreação: 130   r: 533.96   z0: 387.13   misfit: 5.04e+01
# itreação: 131   r: 533.73   z0: 387.76   misfit: 5.00e+01
# itreação: 132   r: 533.50   z0: 388.38   misfit: 4.96e+01
# itreação: 133   r: 533.27   z0: 389.00   misfit: 4.91e+01
# itreação: 134   r: 533.05   z0: 389.61   misfit: 4.87e+01
# itreação: 135   r: 532.83   z0: 390.22   misfit: 4.83e+01
# itreação: 136   r: 532.61   z0: 390.82   misfit: 4.79e+01
# itreação: 137   r: 532.40   z0: 391.42   misfit: 4.75e+01
# itreação: 138   r: 532.19   z0: 392.01   misfit: 4.71e+01
# itreação: 139   r: 531.98   z0: 392.59   misfit: 4.67e+01
# itreação: 140   r: 531.77   z0: 393.17   misfit: 4.63e+01
# itreação: 141   r: 531.57   z0: 393.74   misfit: 4.60e+01
# itreação: 142   r: 531.37   z0: 394.31   misfit: 4.56e+01
# itreação: 143   r: 531.17   z0: 394.87   misfit: 4.53e+01
# itreação: 144   r: 530.97   z0: 395.43   misfit: 4.49e+01
# itreação: 145   r: 530.77   z0: 395.98   misfit: 4.46e+01
# itreação: 146   r: 530.58   z0: 396.53   misfit: 4.42e+01
# itreação: 147   r: 530.39   z0: 397.07   misfit: 4.39e+01
# itreação: 148   r: 530.20   z0: 397.61   misfit: 4.36e+01
# itreação: 149   r: 530.01   z0: 398.14   misfit: 4.33e+01
# itreação: 150   r: 529.83   z0: 398.67   misfit: 4.30e+01
# itreação: 151   r: 529.65   z0: 399.19   misfit: 4.27e+01
# itreação: 152   r: 529.47   z0: 399.71   misfit: 4.24e+01
# itreação: 153   r: 529.29   z0: 400.22   misfit: 4.21e+01
# itreação: 154   r: 529.11   z0: 400.73   misfit: 4.18e+01
# itreação: 155   r: 528.94   z0: 401.24   misfit: 4.15e+01
# itreação: 156   r: 528.76   z0: 401.74   misfit: 4.12e+01
# itreação: 157   r: 528.59   z0: 402.24   misfit: 4.09e+01
# itreação: 158   r: 528.42   z0: 402.73   misfit: 4.07e+01
# itreação: 159   r: 528.26   z0: 403.22   misfit: 4.04e+01
# itreação: 160   r: 528.09   z0: 403.70   misfit: 4.01e+01
# itreação: 161   r: 527.93   z0: 404.18   misfit: 3.99e+01
# itreação: 162   r: 527.76   z0: 404.66   misfit: 3.96e+01
# itreação: 163   r: 527.60   z0: 405.13   misfit: 3.94e+01
# itreação: 164   r: 527.44   z0: 405.60   misfit: 3.91e+01
# itreação: 165   r: 527.29   z0: 406.06   misfit: 3.89e+01
# itreação: 166   r: 527.13   z0: 406.52   misfit: 3.87e+01
# itreação: 167   r: 526.98   z0: 406.98   misfit: 3.84e+01
# itreação: 168   r: 526.82   z0: 407.43   misfit: 3.82e+01
# itreação: 169   r: 526.67   z0: 407.88   misfit: 3.80e+01
# itreação: 170   r: 526.52   z0: 408.33   misfit: 3.78e+01
# itreação: 171   r: 526.37   z0: 408.77   misfit: 3.75e+01
# itreação: 172   r: 526.22   z0: 409.21   misfit: 3.73e+01
# itreação: 173   r: 526.08   z0: 409.65   misfit: 3.71e+01
# itreação: 174   r: 525.93   z0: 410.08   misfit: 3.69e+01
# itreação: 175   r: 525.79   z0: 410.51   misfit: 3.67e+01
# itreação: 176   r: 525.65   z0: 410.94   misfit: 3.65e+01
# itreação: 177   r: 525.51   z0: 411.36   misfit: 3.63e+01
# itreação: 178   r: 525.37   z0: 411.78   misfit: 3.61e+01
# itreação: 179   r: 525.23   z0: 412.20   misfit: 3.59e+01
# itreação: 180   r: 525.09   z0: 412.61   misfit: 3.57e+01
# itreação: 181   r: 524.96   z0: 413.02   misfit: 3.56e+01
# itreação: 182   r: 524.82   z0: 413.42   misfit: 3.54e+01
# itreação: 183   r: 524.69   z0: 413.83   misfit: 3.52e+01
# itreação: 184   r: 524.56   z0: 414.23   misfit: 3.50e+01
# itreação: 185   r: 524.43   z0: 414.63   misfit: 3.48e+01
# itreação: 186   r: 524.30   z0: 415.02   misfit: 3.47e+01
# itreação: 187   r: 524.17   z0: 415.41   misfit: 3.45e+01
# itreação: 188   r: 524.04   z0: 415.80   misfit: 3.43e+01
# itreação: 189   r: 523.92   z0: 416.19   misfit: 3.42e+01
# itreação: 190   r: 523.79   z0: 416.57   misfit: 3.40e+01
# itreação: 191   r: 523.67   z0: 416.95   misfit: 3.38e+01
# itreação: 192   r: 523.55   z0: 417.33   misfit: 3.37e+01
# itreação: 193   r: 523.42   z0: 417.71   misfit: 3.35e+01
# itreação: 194   r: 523.30   z0: 418.08   misfit: 3.34e+01
# itreação: 195   r: 523.18   z0: 418.45   misfit: 3.32e+01
# itreação: 196   r: 523.06   z0: 418.82   misfit: 3.31e+01
# itreação: 197   r: 522.95   z0: 419.18   misfit: 3.29e+01
# itreação: 198   r: 522.83   z0: 419.54   misfit: 3.28e+01
# itreação: 199   r: 522.71   z0: 419.90   misfit: 3.27e+01
# itreação: 200   r: 522.60   z0: 420.26   misfit: 3.25e+01
# itreação: 201   r: 522.49   z0: 420.61   misfit: 3.24e+01
# itreação: 202   r: 522.37   z0: 420.97   misfit: 3.22e+01
# itreação: 203   r: 522.26   z0: 421.32   misfit: 3.21e+01
# itreação: 204   r: 522.15   z0: 421.66   misfit: 3.20e+01
# itreação: 205   r: 522.04   z0: 422.01   misfit: 3.18e+01
# itreação: 206   r: 521.93   z0: 422.35   misfit: 3.17e+01
# itreação: 207   r: 521.82   z0: 422.69   misfit: 3.16e+01
# itreação: 208   r: 521.71   z0: 423.03   misfit: 3.15e+01
# itreação: 209   r: 521.61   z0: 423.36   misfit: 3.13e+01
# itreação: 210   r: 521.50   z0: 423.70   misfit: 3.12e+01
# itreação: 211   r: 521.39   z0: 424.03   misfit: 3.11e+01
# itreação: 212   r: 521.29   z0: 424.36   misfit: 3.10e+01
# itreação: 213   r: 521.19   z0: 424.69   misfit: 3.09e+01
# itreação: 214   r: 521.08   z0: 425.01   misfit: 3.07e+01
# itreação: 215   r: 520.98   z0: 425.33   misfit: 3.06e+01
# itreação: 216   r: 520.88   z0: 425.65   misfit: 3.05e+01
# itreação: 217   r: 520.78   z0: 425.97   misfit: 3.04e+01
# itreação: 218   r: 520.68   z0: 426.29   misfit: 3.03e+01
# itreação: 219   r: 520.58   z0: 426.60   misfit: 3.02e+01
# itreação: 220   r: 520.48   z0: 426.91   misfit: 3.01e+01
# itreação: 221   r: 520.39   z0: 427.22   misfit: 3.00e+01
# itreação: 222   r: 520.29   z0: 427.53   misfit: 2.99e+01
# itreação: 223   r: 520.19   z0: 427.84   misfit: 2.98e+01
# itreação: 224   r: 520.10   z0: 428.14   misfit: 2.97e+01
# itreação: 225   r: 520.00   z0: 428.45   misfit: 2.96e+01
# itreação: 226   r: 519.91   z0: 428.75   misfit: 2.95e+01
# itreação: 227   r: 519.82   z0: 429.04   misfit: 2.94e+01
# itreação: 228   r: 519.73   z0: 429.34   misfit: 2.93e+01
# itreação: 229   r: 519.63   z0: 429.64   misfit: 2.92e+01
# itreação: 230   r: 519.54   z0: 429.93   misfit: 2.91e+01
# itreação: 231   r: 519.45   z0: 430.22   misfit: 2.90e+01
# itreação: 232   r: 519.36   z0: 430.51   misfit: 2.89e+01
# itreação: 233   r: 519.27   z0: 430.80   misfit: 2.88e+01
# itreação: 234   r: 519.18   z0: 431.08   misfit: 2.87e+01
# itreação: 235   r: 519.10   z0: 431.37   misfit: 2.86e+01
# itreação: 236   r: 519.01   z0: 431.65   misfit: 2.86e+01
# itreação: 237   r: 518.92   z0: 431.93   misfit: 2.85e+01
# itreação: 238   r: 518.84   z0: 432.21   misfit: 2.84e+01
# itreação: 239   r: 518.75   z0: 432.49   misfit: 2.83e+01
# itreação: 240   r: 518.67   z0: 432.76   misfit: 2.82e+01
# itreação: 241   r: 518.58   z0: 433.03   misfit: 2.81e+01
# itreação: 242   r: 518.50   z0: 433.31   misfit: 2.81e+01
# itreação: 243   r: 518.41   z0: 433.58   misfit: 2.80e+01
# itreação: 244   r: 518.33   z0: 433.85   misfit: 2.79e+01
# itreação: 245   r: 518.25   z0: 434.11   misfit: 2.78e+01
# itreação: 246   r: 518.17   z0: 434.38   misfit: 2.77e+01
# itreação: 247   r: 518.09   z0: 434.64   misfit: 2.77e+01
# itreação: 248   r: 518.01   z0: 434.91   misfit: 2.76e+01
# itreação: 249   r: 517.93   z0: 435.17   misfit: 2.75e+01
# itreação: 250   r: 517.85   z0: 435.43   misfit: 2.74e+01
# itreação: 251   r: 517.77   z0: 435.69   misfit: 2.74e+01
# itreação: 252   r: 517.69   z0: 435.94   misfit: 2.73e+01
# itreação: 253   r: 517.61   z0: 436.20   misfit: 2.72e+01
# itreação: 254   r: 517.54   z0: 436.45   misfit: 2.72e+01
# itreação: 255   r: 517.46   z0: 436.70   misfit: 2.71e+01
# itreação: 256   r: 517.38   z0: 436.95   misfit: 2.70e+01
# itreação: 257   r: 517.31   z0: 437.20   misfit: 2.70e+01
# itreação: 258   r: 517.23   z0: 437.45   misfit: 2.69e+01
# itreação: 259   r: 517.16   z0: 437.70   misfit: 2.68e+01
# itreação: 260   r: 517.08   z0: 437.94   misfit: 2.68e+01
# itreação: 261   r: 517.01   z0: 438.19   misfit: 2.67e+01
# itreação: 262   r: 516.94   z0: 438.43   misfit: 2.66e+01
# itreação: 263   r: 516.87   z0: 438.67   misfit: 2.66e+01
# itreação: 264   r: 516.79   z0: 438.91   misfit: 2.65e+01
# itreação: 265   r: 516.72   z0: 439.15   misfit: 2.64e+01
# itreação: 266   r: 516.65   z0: 439.38   misfit: 2.64e+01
# itreação: 267   r: 516.58   z0: 439.62   misfit: 2.63e+01
# itreação: 268   r: 516.51   z0: 439.85   misfit: 2.63e+01
# itreação: 269   r: 516.44   z0: 440.09   misfit: 2.62e+01
# itreação: 270   r: 516.37   z0: 440.32   misfit: 2.61e+01
# itreação: 271   r: 516.30   z0: 440.55   misfit: 2.61e+01
# itreação: 272   r: 516.23   z0: 440.78   misfit: 2.60e+01
# itreação: 273   r: 516.16   z0: 441.00   misfit: 2.60e+01
# itreação: 274   r: 516.10   z0: 441.23   misfit: 2.59e+01
# itreação: 275   r: 516.03   z0: 441.46   misfit: 2.59e+01
# itreação: 276   r: 515.96   z0: 441.68   misfit: 2.58e+01
# itreação: 277   r: 515.89   z0: 441.90   misfit: 2.58e+01
# itreação: 278   r: 515.83   z0: 442.12   misfit: 2.57e+01
# itreação: 279   r: 515.76   z0: 442.34   misfit: 2.57e+01
# itreação: 280   r: 515.70   z0: 442.56   misfit: 2.56e+01
# itreação: 281   r: 515.63   z0: 442.78   misfit: 2.55e+01
# itreação: 282   r: 515.57   z0: 443.00   misfit: 2.55e+01
# itreação: 283   r: 515.50   z0: 443.21   misfit: 2.54e+01
# itreação: 284   r: 515.44   z0: 443.43   misfit: 2.54e+01
# itreação: 285   r: 515.38   z0: 443.64   misfit: 2.53e+01
# itreação: 286   r: 515.31   z0: 443.85   misfit: 2.53e+01
# itreação: 287   r: 515.25   z0: 444.07   misfit: 2.53e+01
# itreação: 288   r: 515.19   z0: 444.28   misfit: 2.52e+01
# itreação: 289   r: 515.13   z0: 444.49   misfit: 2.52e+01
# itreação: 290   r: 515.06   z0: 444.69   misfit: 2.51e+01
# itreação: 291   r: 515.00   z0: 444.90   misfit: 2.51e+01
# itreação: 292   r: 514.94   z0: 445.11   misfit: 2.50e+01
# itreação: 293   r: 514.88   z0: 445.31   misfit: 2.50e+01
# itreação: 294   r: 514.82   z0: 445.51   misfit: 2.49e+01
# itreação: 295   r: 514.76   z0: 445.72   misfit: 2.49e+01
# itreação: 296   r: 514.70   z0: 445.92   misfit: 2.48e+01
# itreação: 297   r: 514.64   z0: 446.12   misfit: 2.48e+01
# itreação: 298   r: 514.59   z0: 446.32   misfit: 2.48e+01
# itreação: 299   r: 514.53   z0: 446.52   misfit: 2.47e+01
# itreação: 300   r: 514.47   z0: 446.71   misfit: 2.47e+01
# itreação: 301   r: 514.41   z0: 446.91   misfit: 2.46e+01
# itreação: 302   r: 514.35   z0: 447.10   misfit: 2.46e+01
# itreação: 303   r: 514.30   z0: 447.30   misfit: 2.45e+01
# itreação: 304   r: 514.24   z0: 447.49   misfit: 2.45e+01
# itreação: 305   r: 514.18   z0: 447.68   misfit: 2.45e+01
# itreação: 306   r: 514.13   z0: 447.88   misfit: 2.44e+01
# itreação: 307   r: 514.07   z0: 448.07   misfit: 2.44e+01
# itreação: 308   r: 514.02   z0: 448.26   misfit: 2.43e+01
# itreação: 309   r: 513.96   z0: 448.44   misfit: 2.43e+01
# itreação: 310   r: 513.91   z0: 448.63   misfit: 2.43e+01
# itreação: 311   r: 513.85   z0: 448.82   misfit: 2.42e+01
# itreação: 312   r: 513.80   z0: 449.00   misfit: 2.42e+01
# itreação: 313   r: 513.74   z0: 449.19   misfit: 2.42e+01
# itreação: 314   r: 513.69   z0: 449.37   misfit: 2.41e+01
# itreação: 315   r: 513.64   z0: 449.56   misfit: 2.41e+01
# itreação: 316   r: 513.58   z0: 449.74   misfit: 2.41e+01
# itreação: 317   r: 513.53   z0: 449.92   misfit: 2.40e+01
# itreação: 318   r: 513.48   z0: 450.10   misfit: 2.40e+01
# itreação: 319   r: 513.43   z0: 450.28   misfit: 2.39e+01
# itreação: 320   r: 513.38   z0: 450.46   misfit: 2.39e+01
# itreação: 321   r: 513.32   z0: 450.63   misfit: 2.39e+01
# itreação: 322   r: 513.27   z0: 450.81   misfit: 2.38e+01
# itreação: 323   r: 513.22   z0: 450.99   misfit: 2.38e+01
# itreação: 324   r: 513.17   z0: 451.16   misfit: 2.38e+01
# itreação: 325   r: 513.12   z0: 451.34   misfit: 2.37e+01
# itreação: 326   r: 513.07   z0: 451.51   misfit: 2.37e+01
# itreação: 327   r: 513.02   z0: 451.68   misfit: 2.37e+01
# itreação: 328   r: 512.97   z0: 451.85   misfit: 2.36e+01
# itreação: 329   r: 512.92   z0: 452.02   misfit: 2.36e+01
# itreação: 330   r: 512.87   z0: 452.19   misfit: 2.36e+01
# itreação: 331   r: 512.82   z0: 452.36   misfit: 2.36e+01
# itreação: 332   r: 512.78   z0: 452.53   misfit: 2.35e+01
# itreação: 333   r: 512.73   z0: 452.70   misfit: 2.35e+01
# itreação: 334   r: 512.68   z0: 452.87   misfit: 2.35e+01
# itreação: 335   r: 512.63   z0: 453.03   misfit: 2.34e+01
# itreação: 336   r: 512.58   z0: 453.20   misfit: 2.34e+01
# itreação: 337   r: 512.54   z0: 453.36   misfit: 2.34e+01
# itreação: 338   r: 512.49   z0: 453.52   misfit: 2.33e+01
# itreação: 339   r: 512.44   z0: 453.69   misfit: 2.33e+01
# itreação: 340   r: 512.40   z0: 453.85   misfit: 2.33e+01
# itreação: 341   r: 512.35   z0: 454.01   misfit: 2.33e+01
# itreação: 342   r: 512.30   z0: 454.17   misfit: 2.32e+01
# itreação: 343   r: 512.26   z0: 454.33   misfit: 2.32e+01
# itreação: 344   r: 512.21   z0: 454.49   misfit: 2.32e+01
# itreação: 345   r: 512.17   z0: 454.65   misfit: 2.32e+01
# itreação: 346   r: 512.12   z0: 454.81   misfit: 2.31e+01
# itreação: 347   r: 512.08   z0: 454.96   misfit: 2.31e+01
# itreação: 348   r: 512.03   z0: 455.12   misfit: 2.31e+01
# itreação: 349   r: 511.99   z0: 455.27   misfit: 2.31e+01
# itreação: 350   r: 511.94   z0: 455.43   misfit: 2.30e+01
# itreação: 351   r: 511.90   z0: 455.58   misfit: 2.30e+01
# itreação: 352   r: 511.86   z0: 455.74   misfit: 2.30e+01
# itreação: 353   r: 511.81   z0: 455.89   misfit: 2.29e+01
# itreação: 354   r: 511.77   z0: 456.04   misfit: 2.29e+01
# itreação: 355   r: 511.73   z0: 456.19   misfit: 2.29e+01
# itreação: 356   r: 511.68   z0: 456.34   misfit: 2.29e+01
# itreação: 357   r: 511.64   z0: 456.49   misfit: 2.29e+01
# itreação: 358   r: 511.60   z0: 456.64   misfit: 2.28e+01
# itreação: 359   r: 511.56   z0: 456.79   misfit: 2.28e+01
# itreação: 360   r: 511.51   z0: 456.94   misfit: 2.28e+01
# itreação: 361   r: 511.47   z0: 457.08   misfit: 2.28e+01
# itreação: 362   r: 511.43   z0: 457.23   misfit: 2.27e+01
# itreação: 363   r: 511.39   z0: 457.37   misfit: 2.27e+01
# itreação: 364   r: 511.35   z0: 457.52   misfit: 2.27e+01
# itreação: 365   r: 511.31   z0: 457.66   misfit: 2.27e+01
# itreação: 366   r: 511.27   z0: 457.81   misfit: 2.26e+01
# itreação: 367   r: 511.23   z0: 457.95   misfit: 2.26e+01
# itreação: 368   r: 511.18   z0: 458.09   misfit: 2.26e+01
# itreação: 369   r: 511.14   z0: 458.23   misfit: 2.26e+01
# itreação: 370   r: 511.10   z0: 458.38   misfit: 2.26e+01
# itreação: 371   r: 511.06   z0: 458.52   misfit: 2.25e+01
# itreação: 372   r: 511.03   z0: 458.66   misfit: 2.25e+01
# itreação: 373   r: 510.99   z0: 458.80   misfit: 2.25e+01
# itreação: 374   r: 510.95   z0: 458.93   misfit: 2.25e+01
# itreação: 375   r: 510.91   z0: 459.07   misfit: 2.25e+01
# itreação: 376   r: 510.87   z0: 459.21   misfit: 2.24e+01
# itreação: 377   r: 510.83   z0: 459.35   misfit: 2.24e+01
# itreação: 378   r: 510.79   z0: 459.48   misfit: 2.24e+01
# itreação: 379   r: 510.75   z0: 459.62   misfit: 2.24e+01
# itreação: 380   r: 510.72   z0: 459.75   misfit: 2.24e+01
# itreação: 381   r: 510.68   z0: 459.89   misfit: 2.23e+01
# itreação: 382   r: 510.64   z0: 460.02   misfit: 2.23e+01
# itreação: 383   r: 510.60   z0: 460.15   misfit: 2.23e+01
# itreação: 384   r: 510.56   z0: 460.29   misfit: 2.23e+01
# itreação: 385   r: 510.53   z0: 460.42   misfit: 2.23e+01
# itreação: 386   r: 510.49   z0: 460.55   misfit: 2.22e+01
# itreação: 387   r: 510.45   z0: 460.68   misfit: 2.22e+01
# itreação: 388   r: 510.42   z0: 460.81   misfit: 2.22e+01
# itreação: 389   r: 510.38   z0: 460.94   misfit: 2.22e+01
# itreação: 390   r: 510.34   z0: 461.07   misfit: 2.22e+01
# itreação: 391   r: 510.31   z0: 461.20   misfit: 2.22e+01
# itreação: 392   r: 510.27   z0: 461.33   misfit: 2.21e+01
# itreação: 393   r: 510.24   z0: 461.46   misfit: 2.21e+01
# itreação: 394   r: 510.20   z0: 461.58   misfit: 2.21e+01
# itreação: 395   r: 510.17   z0: 461.71   misfit: 2.21e+01
# itreação: 396   r: 510.13   z0: 461.83   misfit: 2.21e+01
# itreação: 397   r: 510.10   z0: 461.96   misfit: 2.20e+01
# itreação: 398   r: 510.06   z0: 462.08   misfit: 2.20e+01
# itreação: 399   r: 510.03   z0: 462.21   misfit: 2.20e+01
# itreação: 400   r: 509.99   z0: 462.33   misfit: 2.20e+01
# itreação: 401   r: 509.96   z0: 462.46   misfit: 2.20e+01
# itreação: 402   r: 509.92   z0: 462.58   misfit: 2.20e+01
# itreação: 403   r: 509.89   z0: 462.70   misfit: 2.20e+01
# itreação: 404   r: 509.85   z0: 462.82   misfit: 2.19e+01
# itreação: 405   r: 509.82   z0: 462.94   misfit: 2.19e+01
# itreação: 406   r: 509.79   z0: 463.06   misfit: 2.19e+01
# itreação: 407   r: 509.75   z0: 463.18   misfit: 2.19e+01
# itreação: 408   r: 509.72   z0: 463.30   misfit: 2.19e+01
# itreação: 409   r: 509.69   z0: 463.42   misfit: 2.19e+01
# itreação: 410   r: 509.65   z0: 463.54   misfit: 2.18e+01
# itreação: 411   r: 509.62   z0: 463.66   misfit: 2.18e+01
# itreação: 412   r: 509.59   z0: 463.78   misfit: 2.18e+01
# itreação: 413   r: 509.56   z0: 463.90   misfit: 2.18e+01
# itreação: 414   r: 509.52   z0: 464.01   misfit: 2.18e+01
# itreação: 415   r: 509.49   z0: 464.13   misfit: 2.18e+01
# itreação: 416   r: 509.46   z0: 464.24   misfit: 2.18e+01
# itreação: 417   r: 509.43   z0: 464.36   misfit: 2.17e+01
# itreação: 418   r: 509.39   z0: 464.47   misfit: 2.17e+01
# itreação: 419   r: 509.36   z0: 464.59   misfit: 2.17e+01
# itreação: 420   r: 509.33   z0: 464.70   misfit: 2.17e+01
# itreação: 421   r: 509.30   z0: 464.82   misfit: 2.17e+01
# itreação: 422   r: 509.27   z0: 464.93   misfit: 2.17e+01
# itreação: 423   r: 509.24   z0: 465.04   misfit: 2.17e+01
# itreação: 424   r: 509.21   z0: 465.15   misfit: 2.16e+01
# itreação: 425   r: 509.18   z0: 465.26   misfit: 2.16e+01
# itreação: 426   r: 509.14   z0: 465.37   misfit: 2.16e+01
# itreação: 427   r: 509.11   z0: 465.49   misfit: 2.16e+01
# itreação: 428   r: 509.08   z0: 465.60   misfit: 2.16e+01
# itreação: 429   r: 509.05   z0: 465.71   misfit: 2.16e+01
# itreação: 430   r: 509.02   z0: 465.81   misfit: 2.16e+01
# itreação: 431   r: 508.99   z0: 465.92   misfit: 2.16e+01
# itreação: 432   r: 508.96   z0: 466.03   misfit: 2.15e+01
# itreação: 433   r: 508.93   z0: 466.14   misfit: 2.15e+01
# itreação: 434   r: 508.90   z0: 466.25   misfit: 2.15e+01
# itreação: 435   r: 508.87   z0: 466.35   misfit: 2.15e+01
# itreação: 436   r: 508.84   z0: 466.46   misfit: 2.15e+01
# itreação: 437   r: 508.81   z0: 466.57   misfit: 2.15e+01
# itreação: 438   r: 508.79   z0: 466.67   misfit: 2.15e+01
# itreação: 439   r: 508.76   z0: 466.78   misfit: 2.15e+01
# itreação: 440   r: 508.73   z0: 466.88   misfit: 2.14e+01
# itreação: 441   r: 508.70   z0: 466.99   misfit: 2.14e+01
# itreação: 442   r: 508.67   z0: 467.09   misfit: 2.14e+01
# itreação: 443   r: 508.64   z0: 467.19   misfit: 2.14e+01
# itreação: 444   r: 508.61   z0: 467.30   misfit: 2.14e+01
# itreação: 445   r: 508.58   z0: 467.40   misfit: 2.14e+01
# itreação: 446   r: 508.56   z0: 467.50   misfit: 2.14e+01
# itreação: 447   r: 508.53   z0: 467.60   misfit: 2.14e+01
# itreação: 448   r: 508.50   z0: 467.71   misfit: 2.14e+01
# itreação: 449   r: 508.47   z0: 467.81   misfit: 2.13e+01
# itreação: 450   r: 508.45   z0: 467.91   misfit: 2.13e+01
# itreação: 451   r: 508.42   z0: 468.01   misfit: 2.13e+01
# itreação: 452   r: 508.39   z0: 468.11   misfit: 2.13e+01
# itreação: 453   r: 508.36   z0: 468.21   misfit: 2.13e+01
# itreação: 454   r: 508.34   z0: 468.31   misfit: 2.13e+01
# itreação: 455   r: 508.31   z0: 468.40   misfit: 2.13e+01
# itreação: 456   r: 508.28   z0: 468.50   misfit: 2.13e+01
# itreação: 457   r: 508.25   z0: 468.60   misfit: 2.13e+01
# itreação: 458   r: 508.23   z0: 468.70   misfit: 2.13e+01
# itreação: 459   r: 508.20   z0: 468.80   misfit: 2.12e+01
# itreação: 460   r: 508.17   z0: 468.89   misfit: 2.12e+01
# itreação: 461   r: 508.15   z0: 468.99   misfit: 2.12e+01
# itreação: 462   r: 508.12   z0: 469.09   misfit: 2.12e+01
# itreação: 463   r: 508.10   z0: 469.18   misfit: 2.12e+01
# itreação: 464   r: 508.07   z0: 469.28   misfit: 2.12e+01
# itreação: 465   r: 508.04   z0: 469.37   misfit: 2.12e+01
# itreação: 466   r: 508.02   z0: 469.47   misfit: 2.12e+01
# itreação: 467   r: 507.99   z0: 469.56   misfit: 2.12e+01
# itreação: 468   r: 507.97   z0: 469.65   misfit: 2.12e+01
# itreação: 469   r: 507.94   z0: 469.75   misfit: 2.11e+01
# itreação: 470   r: 507.92   z0: 469.84   misfit: 2.11e+01
# itreação: 471   r: 507.89   z0: 469.93   misfit: 2.11e+01
# itreação: 472   r: 507.87   z0: 470.03   misfit: 2.11e+01
# itreação: 473   r: 507.84   z0: 470.12   misfit: 2.11e+01
# itreação: 474   r: 507.82   z0: 470.21   misfit: 2.11e+01
# itreação: 475   r: 507.79   z0: 470.30   misfit: 2.11e+01
# itreação: 476   r: 507.77   z0: 470.39   misfit: 2.11e+01
# itreação: 477   r: 507.74   z0: 470.48   misfit: 2.11e+01
# itreação: 478   r: 507.72   z0: 470.57   misfit: 2.11e+01
# itreação: 479   r: 507.69   z0: 470.66   misfit: 2.11e+01
# itreação: 480   r: 507.67   z0: 470.75   misfit: 2.10e+01
# itreação: 481   r: 507.64   z0: 470.84   misfit: 2.10e+01
# itreação: 482   r: 507.62   z0: 470.93   misfit: 2.10e+01
# itreação: 483   r: 507.59   z0: 471.02   misfit: 2.10e+01
# itreação: 484   r: 507.57   z0: 471.11   misfit: 2.10e+01
# itreação: 485   r: 507.55   z0: 471.19   misfit: 2.10e+01
# itreação: 486   r: 507.52   z0: 471.28   misfit: 2.10e+01
# itreação: 487   r: 507.50   z0: 471.37   misfit: 2.10e+01
# itreação: 488   r: 507.48   z0: 471.45   misfit: 2.10e+01
# itreação: 489   r: 507.45   z0: 471.54   misfit: 2.10e+01
# itreação: 490   r: 507.43   z0: 471.63   misfit: 2.10e+01
# itreação: 491   r: 507.41   z0: 471.71   misfit: 2.10e+01
# itreação: 492   r: 507.38   z0: 471.80   misfit: 2.09e+01
# itreação: 493   r: 507.36   z0: 471.88   misfit: 2.09e+01
# itreação: 494   r: 507.34   z0: 471.97   misfit: 2.09e+01
# itreação: 495   r: 507.31   z0: 472.05   misfit: 2.09e+01
# itreação: 496   r: 507.29   z0: 472.14   misfit: 2.09e+01
# itreação: 497   r: 507.27   z0: 472.22   misfit: 2.09e+01
# itreação: 498   r: 507.24   z0: 472.31   misfit: 2.09e+01
# itreação: 499   r: 507.22   z0: 472.39   misfit: 2.09e+01
# itreação: 500   r: 507.20   z0: 472.47   misfit: 2.09e+01
# itreação: 501   r: 507.18   z0: 472.55   misfit: 2.09e+01
# itreação: 502   r: 507.15   z0: 472.64   misfit: 2.09e+01
# itreação: 503   r: 507.13   z0: 472.72   misfit: 2.09e+01
# itreação: 504   r: 507.11   z0: 472.80   misfit: 2.09e+01
# itreação: 505   r: 507.09   z0: 472.88   misfit: 2.09e+01
# itreação: 506   r: 507.07   z0: 472.96   misfit: 2.08e+01
# itreação: 507   r: 507.04   z0: 473.04   misfit: 2.08e+01
# itreação: 508   r: 507.02   z0: 473.12   misfit: 2.08e+01
# itreação: 509   r: 507.00   z0: 473.20   misfit: 2.08e+01
# itreação: 510   r: 506.98   z0: 473.28   misfit: 2.08e+01
# itreação: 511   r: 506.96   z0: 473.36   misfit: 2.08e+01
# itreação: 512   r: 506.94   z0: 473.44   misfit: 2.08e+01
# itreação: 513   r: 506.92   z0: 473.52   misfit: 2.08e+01
# itreação: 514   r: 506.89   z0: 473.60   misfit: 2.08e+01
# itreação: 515   r: 506.87   z0: 473.68   misfit: 2.08e+01
# itreação: 516   r: 506.85   z0: 473.76   misfit: 2.08e+01
# itreação: 517   r: 506.83   z0: 473.83   misfit: 2.08e+01
# itreação: 518   r: 506.81   z0: 473.91   misfit: 2.08e+01
# itreação: 519   r: 506.79   z0: 473.99   misfit: 2.08e+01
# itreação: 520   r: 506.77   z0: 474.07   misfit: 2.08e+01
# itreação: 521   r: 506.75   z0: 474.14   misfit: 2.07e+01
# itreação: 522   r: 506.73   z0: 474.22   misfit: 2.07e+01
# itreação: 523   r: 506.71   z0: 474.30   misfit: 2.07e+01
# itreação: 524   r: 506.69   z0: 474.37   misfit: 2.07e+01
# itreação: 525   r: 506.67   z0: 474.45   misfit: 2.07e+01
# itreação: 526   r: 506.65   z0: 474.52   misfit: 2.07e+01
# itreação: 527   r: 506.63   z0: 474.60   misfit: 2.07e+01
# itreação: 528   r: 506.61   z0: 474.67   misfit: 2.07e+01
# itreação: 529   r: 506.59   z0: 474.75   misfit: 2.07e+01
# itreação: 530   r: 506.57   z0: 474.82   misfit: 2.07e+01
# itreação: 531   r: 506.55   z0: 474.89   misfit: 2.07e+01
# itreação: 532   r: 506.53   z0: 474.97   misfit: 2.07e+01
# itreação: 533   r: 506.51   z0: 475.04   misfit: 2.07e+01
# itreação: 534   r: 506.49   z0: 475.11   misfit: 2.07e+01
# itreação: 535   r: 506.47   z0: 475.19   misfit: 2.07e+01
# itreação: 536   r: 506.45   z0: 475.26   misfit: 2.07e+01
# itreação: 537   r: 506.43   z0: 475.33   misfit: 2.07e+01
# itreação: 538   r: 506.41   z0: 475.40   misfit: 2.06e+01
# itreação: 539   r: 506.39   z0: 475.48   misfit: 2.06e+01
# itreação: 540   r: 506.37   z0: 475.55   misfit: 2.06e+01
# itreação: 541   r: 506.35   z0: 475.62   misfit: 2.06e+01
# itreação: 542   r: 506.33   z0: 475.69   misfit: 2.06e+01
# itreação: 543   r: 506.31   z0: 475.76   misfit: 2.06e+01
# itreação: 544   r: 506.29   z0: 475.83   misfit: 2.06e+01
# itreação: 545   r: 506.27   z0: 475.90   misfit: 2.06e+01
# itreação: 546   r: 506.26   z0: 475.97   misfit: 2.06e+01
# itreação: 547   r: 506.24   z0: 476.04   misfit: 2.06e+01
# itreação: 548   r: 506.22   z0: 476.11   misfit: 2.06e+01
# itreação: 549   r: 506.20   z0: 476.18   misfit: 2.06e+01
# itreação: 550   r: 506.18   z0: 476.25   misfit: 2.06e+01
# itreação: 551   r: 506.16   z0: 476.32   misfit: 2.06e+01
# itreação: 552   r: 506.14   z0: 476.39   misfit: 2.06e+01
# itreação: 553   r: 506.13   z0: 476.45   misfit: 2.06e+01
# itreação: 554   r: 506.11   z0: 476.52   misfit: 2.06e+01
# itreação: 555   r: 506.09   z0: 476.59   misfit: 2.06e+01
# itreação: 556   r: 506.07   z0: 476.66   misfit: 2.06e+01
# itreação: 557   r: 506.05   z0: 476.73   misfit: 2.06e+01
# itreação: 558   r: 506.04   z0: 476.79   misfit: 2.05e+01
# itreação: 559   r: 506.02   z0: 476.86   misfit: 2.05e+01
# itreação: 560   r: 506.00   z0: 476.93   misfit: 2.05e+01
# itreação: 561   r: 505.98   z0: 476.99   misfit: 2.05e+01
# itreação: 562   r: 505.97   z0: 477.06   misfit: 2.05e+01
# itreação: 563   r: 505.95   z0: 477.12   misfit: 2.05e+01
# itreação: 564   r: 505.93   z0: 477.19   misfit: 2.05e+01
# itreação: 565   r: 505.91   z0: 477.25   misfit: 2.05e+01
# itreação: 566   r: 505.90   z0: 477.32   misfit: 2.05e+01
# itreação: 567   r: 505.88   z0: 477.38   misfit: 2.05e+01
# itreação: 568   r: 505.86   z0: 477.45   misfit: 2.05e+01
# itreação: 569   r: 505.84   z0: 477.51   misfit: 2.05e+01
# itreação: 570   r: 505.83   z0: 477.58   misfit: 2.05e+01
# itreação: 571   r: 505.81   z0: 477.64   misfit: 2.05e+01
# itreação: 572   r: 505.79   z0: 477.71   misfit: 2.05e+01
# itreação: 573   r: 505.78   z0: 477.77   misfit: 2.05e+01
# itreação: 574   r: 505.76   z0: 477.83   misfit: 2.05e+01
# itreação: 575   r: 505.74   z0: 477.90   misfit: 2.05e+01
# itreação: 576   r: 505.72   z0: 477.96   misfit: 2.05e+01
# itreação: 577   r: 505.71   z0: 478.02   misfit: 2.05e+01
# itreação: 578   r: 505.69   z0: 478.08   misfit: 2.05e+01
# itreação: 579   r: 505.67   z0: 478.15   misfit: 2.05e+01
# itreação: 580   r: 505.66   z0: 478.21   misfit: 2.05e+01
# itreação: 581   r: 505.64   z0: 478.27   misfit: 2.04e+01
# itreação: 582   r: 505.63   z0: 478.33   misfit: 2.04e+01
# itreação: 583   r: 505.61   z0: 478.39   misfit: 2.04e+01
# itreação: 584   r: 505.59   z0: 478.45   misfit: 2.04e+01
# itreação: 585   r: 505.58   z0: 478.51   misfit: 2.04e+01
# itreação: 586   r: 505.56   z0: 478.58   misfit: 2.04e+01
# itreação: 587   r: 505.54   z0: 478.64   misfit: 2.04e+01
# itreação: 588   r: 505.53   z0: 478.70   misfit: 2.04e+01
# itreação: 589   r: 505.51   z0: 478.76   misfit: 2.04e+01
# itreação: 590   r: 505.50   z0: 478.82   misfit: 2.04e+01
# itreação: 591   r: 505.48   z0: 478.88   misfit: 2.04e+01
# itreação: 592   r: 505.46   z0: 478.93   misfit: 2.04e+01
# itreação: 593   r: 505.45   z0: 478.99   misfit: 2.04e+01
# itreação: 594   r: 505.43   z0: 479.05   misfit: 2.04e+01
# itreação: 595   r: 505.42   z0: 479.11   misfit: 2.04e+01
# itreação: 596   r: 505.40   z0: 479.17   misfit: 2.04e+01
# itreação: 597   r: 505.39   z0: 479.23   misfit: 2.04e+01
# itreação: 598   r: 505.37   z0: 479.29   misfit: 2.04e+01
# itreação: 599   r: 505.36   z0: 479.35   misfit: 2.04e+01
# itreação: 600   r: 505.34   z0: 479.40   misfit: 2.04e+01
# itreação: 601   r: 505.33   z0: 479.46   misfit: 2.04e+01
# itreação: 602   r: 505.31   z0: 479.52   misfit: 2.04e+01
# itreação: 603   r: 505.29   z0: 479.58   misfit: 2.04e+01
# itreação: 604   r: 505.28   z0: 479.63   misfit: 2.04e+01
# itreação: 605   r: 505.26   z0: 479.69   misfit: 2.04e+01
# itreação: 606   r: 505.25   z0: 479.75   misfit: 2.04e+01
# itreação: 607   r: 505.23   z0: 479.80   misfit: 2.04e+01
# itreação: 608   r: 505.22   z0: 479.86   misfit: 2.03e+01
# itreação: 609   r: 505.20   z0: 479.91   misfit: 2.03e+01
# itreação: 610   r: 505.19   z0: 479.97   misfit: 2.03e+01
# itreação: 611   r: 505.18   z0: 480.03   misfit: 2.03e+01
# itreação: 612   r: 505.16   z0: 480.08   misfit: 2.03e+01
# itreação: 613   r: 505.15   z0: 480.14   misfit: 2.03e+01
# itreação: 614   r: 505.13   z0: 480.19   misfit: 2.03e+01
# itreação: 615   r: 505.12   z0: 480.25   misfit: 2.03e+01
# itreação: 616   r: 505.10   z0: 480.30   misfit: 2.03e+01
# itreação: 617   r: 505.09   z0: 480.36   misfit: 2.03e+01
# itreação: 618   r: 505.07   z0: 480.41   misfit: 2.03e+01
# itreação: 619   r: 505.06   z0: 480.46   misfit: 2.03e+01
# itreação: 620   r: 505.05   z0: 480.52   misfit: 2.03e+01
# itreação: 621   r: 505.03   z0: 480.57   misfit: 2.03e+01
# itreação: 622   r: 505.02   z0: 480.63   misfit: 2.03e+01
# itreação: 623   r: 505.00   z0: 480.68   misfit: 2.03e+01
# itreação: 624   r: 504.99   z0: 480.73   misfit: 2.03e+01
# itreação: 625   r: 504.97   z0: 480.79   misfit: 2.03e+01
# itreação: 626   r: 504.96   z0: 480.84   misfit: 2.03e+01
# itreação: 627   r: 504.95   z0: 480.89   misfit: 2.03e+01
# itreação: 628   r: 504.93   z0: 480.94   misfit: 2.03e+01
# itreação: 629   r: 504.92   z0: 481.00   misfit: 2.03e+01
# itreação: 630   r: 504.91   z0: 481.05   misfit: 2.03e+01
# itreação: 631   r: 504.89   z0: 481.10   misfit: 2.03e+01
# itreação: 632   r: 504.88   z0: 481.15   misfit: 2.03e+01
# itreação: 633   r: 504.86   z0: 481.20   misfit: 2.03e+01
# itreação: 634   r: 504.85   z0: 481.25   misfit: 2.03e+01
# itreação: 635   r: 504.84   z0: 481.31   misfit: 2.03e+01
# itreação: 636   r: 504.82   z0: 481.36   misfit: 2.03e+01
# itreação: 637   r: 504.81   z0: 481.41   misfit: 2.03e+01
# itreação: 638   r: 504.80   z0: 481.46   misfit: 2.03e+01
# itreação: 639   r: 504.78   z0: 481.51   misfit: 2.03e+01
# itreação: 640   r: 504.77   z0: 481.56   misfit: 2.03e+01
# itreação: 641   r: 504.76   z0: 481.61   misfit: 2.03e+01
# itreação: 642   r: 504.74   z0: 481.66   misfit: 2.02e+01
# itreação: 643   r: 504.73   z0: 481.71   misfit: 2.02e+01
# itreação: 644   r: 504.72   z0: 481.76   misfit: 2.02e+01
# itreação: 645   r: 504.70   z0: 481.81   misfit: 2.02e+01
# itreação: 646   r: 504.69   z0: 481.86   misfit: 2.02e+01
# itreação: 647   r: 504.68   z0: 481.91   misfit: 2.02e+01
# itreação: 648   r: 504.67   z0: 481.96   misfit: 2.02e+01
# itreação: 649   r: 504.65   z0: 482.01   misfit: 2.02e+01
# itreação: 650   r: 504.64   z0: 482.05   misfit: 2.02e+01
# itreação: 651   r: 504.63   z0: 482.10   misfit: 2.02e+01
# itreação: 652   r: 504.61   z0: 482.15   misfit: 2.02e+01
# itreação: 653   r: 504.60   z0: 482.20   misfit: 2.02e+01
# itreação: 654   r: 504.59   z0: 482.25   misfit: 2.02e+01
# itreação: 655   r: 504.58   z0: 482.30   misfit: 2.02e+01
# itreação: 656   r: 504.56   z0: 482.34   misfit: 2.02e+01
# itreação: 657   r: 504.55   z0: 482.39   misfit: 2.02e+01
# itreação: 658   r: 504.54   z0: 482.44   misfit: 2.02e+01
# itreação: 659   r: 504.53   z0: 482.49   misfit: 2.02e+01
# itreação: 660   r: 504.51   z0: 482.53   misfit: 2.02e+01
# itreação: 661   r: 504.50   z0: 482.58   misfit: 2.02e+01
# itreação: 662   r: 504.49   z0: 482.63   misfit: 2.02e+01
# itreação: 663   r: 504.48   z0: 482.67   misfit: 2.02e+01
# itreação: 664   r: 504.46   z0: 482.72   misfit: 2.02e+01
# itreação: 665   r: 504.45   z0: 482.77   misfit: 2.02e+01
# itreação: 666   r: 504.44   z0: 482.81   misfit: 2.02e+01
# itreação: 667   r: 504.43   z0: 482.86   misfit: 2.02e+01
# itreação: 668   r: 504.42   z0: 482.90   misfit: 2.02e+01
# itreação: 669   r: 504.40   z0: 482.95   misfit: 2.02e+01
# itreação: 670   r: 504.39   z0: 483.00   misfit: 2.02e+01
# itreação: 671   r: 504.38   z0: 483.04   misfit: 2.02e+01
# itreação: 672   r: 504.37   z0: 483.09   misfit: 2.02e+01
# itreação: 673   r: 504.36   z0: 483.13   misfit: 2.02e+01
# itreação: 674   r: 504.34   z0: 483.18   misfit: 2.02e+01
# itreação: 675   r: 504.33   z0: 483.22   misfit: 2.02e+01
# itreação: 676   r: 504.32   z0: 483.27   misfit: 2.02e+01
# itreação: 677   r: 504.31   z0: 483.31   misfit: 2.02e+01
# itreação: 678   r: 504.30   z0: 483.36   misfit: 2.02e+01
# itreação: 679   r: 504.29   z0: 483.40   misfit: 2.02e+01
# itreação: 680   r: 504.27   z0: 483.44   misfit: 2.02e+01
# itreação: 681   r: 504.26   z0: 483.49   misfit: 2.02e+01
# itreação: 682   r: 504.25   z0: 483.53   misfit: 2.02e+01
# itreação: 683   r: 504.24   z0: 483.58   misfit: 2.02e+01
# itreação: 684   r: 504.23   z0: 483.62   misfit: 2.02e+01
# itreação: 685   r: 504.22   z0: 483.66   misfit: 2.01e+01
# itreação: 686   r: 504.21   z0: 483.71   misfit: 2.01e+01
# itreação: 687   r: 504.19   z0: 483.75   misfit: 2.01e+01
# itreação: 688   r: 504.18   z0: 483.79   misfit: 2.01e+01
# itreação: 689   r: 504.17   z0: 483.83   misfit: 2.01e+01
# itreação: 690   r: 504.16   z0: 483.88   misfit: 2.01e+01
# itreação: 691   r: 504.15   z0: 483.92   misfit: 2.01e+01
# itreação: 692   r: 504.14   z0: 483.96   misfit: 2.01e+01
# itreação: 693   r: 504.13   z0: 484.00   misfit: 2.01e+01
# itreação: 694   r: 504.12   z0: 484.05   misfit: 2.01e+01
# itreação: 695   r: 504.11   z0: 484.09   misfit: 2.01e+01
# itreação: 696   r: 504.09   z0: 484.13   misfit: 2.01e+01
# itreação: 697   r: 504.08   z0: 484.17   misfit: 2.01e+01
# itreação: 698   r: 504.07   z0: 484.21   misfit: 2.01e+01
# itreação: 699   r: 504.06   z0: 484.26   misfit: 2.01e+01
# itreação: 700   r: 504.05   z0: 484.30   misfit: 2.01e+01
# itreação: 701   r: 504.04   z0: 484.34   misfit: 2.01e+01
# itreação: 702   r: 504.03   z0: 484.38   misfit: 2.01e+01
# itreação: 703   r: 504.02   z0: 484.42   misfit: 2.01e+01
# itreação: 704   r: 504.01   z0: 484.46   misfit: 2.01e+01
# itreação: 705   r: 504.00   z0: 484.50   misfit: 2.01e+01
# itreação: 706   r: 503.99   z0: 484.54   misfit: 2.01e+01
# itreação: 707   r: 503.98   z0: 484.58   misfit: 2.01e+01
# itreação: 708   r: 503.97   z0: 484.62   misfit: 2.01e+01
# itreação: 709   r: 503.96   z0: 484.66   misfit: 2.01e+01
# itreação: 710   r: 503.95   z0: 484.70   misfit: 2.01e+01
# itreação: 711   r: 503.94   z0: 484.74   misfit: 2.01e+01
# itreação: 712   r: 503.92   z0: 484.78   misfit: 2.01e+01
# itreação: 713   r: 503.91   z0: 484.82   misfit: 2.01e+01
# itreação: 714   r: 503.90   z0: 484.86   misfit: 2.01e+01
# itreação: 715   r: 503.89   z0: 484.90   misfit: 2.01e+01
# itreação: 716   r: 503.88   z0: 484.94   misfit: 2.01e+01
# itreação: 717   r: 503.87   z0: 484.98   misfit: 2.01e+01
# itreação: 718   r: 503.86   z0: 485.02   misfit: 2.01e+01
# itreação: 719   r: 503.85   z0: 485.06   misfit: 2.01e+01
# itreação: 720   r: 503.84   z0: 485.10   misfit: 2.01e+01
# itreação: 721   r: 503.83   z0: 485.13   misfit: 2.01e+01
# itreação: 722   r: 503.82   z0: 485.17   misfit: 2.01e+01
# itreação: 723   r: 503.81   z0: 485.21   misfit: 2.01e+01
# itreação: 724   r: 503.80   z0: 485.25   misfit: 2.01e+01
# itreação: 725   r: 503.79   z0: 485.29   misfit: 2.01e+01
# itreação: 726   r: 503.78   z0: 485.32   misfit: 2.01e+01
# itreação: 727   r: 503.77   z0: 485.36   misfit: 2.01e+01
# itreação: 728   r: 503.76   z0: 485.40   misfit: 2.01e+01
# itreação: 729   r: 503.75   z0: 485.44   misfit: 2.01e+01
# itreação: 730   r: 503.74   z0: 485.48   misfit: 2.01e+01
# itreação: 731   r: 503.73   z0: 485.51   misfit: 2.01e+01
# itreação: 732   r: 503.72   z0: 485.55   misfit: 2.01e+01
# itreação: 733   r: 503.71   z0: 485.59   misfit: 2.01e+01
# itreação: 734   r: 503.70   z0: 485.62   misfit: 2.01e+01
# itreação: 735   r: 503.70   z0: 485.66   misfit: 2.01e+01
# itreação: 736   r: 503.69   z0: 485.70   misfit: 2.01e+01
# itreação: 737   r: 503.68   z0: 485.73   misfit: 2.01e+01
# itreação: 738   r: 503.67   z0: 485.77   misfit: 2.01e+01
# itreação: 739   r: 503.66   z0: 485.81   misfit: 2.01e+01
# itreação: 740   r: 503.65   z0: 485.84   misfit: 2.01e+01
# itreação: 741   r: 503.64   z0: 485.88   misfit: 2.01e+01
# itreação: 742   r: 503.63   z0: 485.92   misfit: 2.01e+01
# itreação: 743   r: 503.62   z0: 485.95   misfit: 2.01e+01
# itreação: 744   r: 503.61   z0: 485.99   misfit: 2.01e+01
# itreação: 745   r: 503.60   z0: 486.02   misfit: 2.01e+01
# itreação: 746   r: 503.59   z0: 486.06   misfit: 2.01e+01
# itreação: 747   r: 503.58   z0: 486.09   misfit: 2.00e+01
# itreação: 748   r: 503.57   z0: 486.13   misfit: 2.00e+01
# itreação: 749   r: 503.56   z0: 486.17   misfit: 2.00e+01
# itreação: 750   r: 503.55   z0: 486.20   misfit: 2.00e+01
# itreação: 751   r: 503.55   z0: 486.24   misfit: 2.00e+01
# itreação: 752   r: 503.54   z0: 486.27   misfit: 2.00e+01
# itreação: 753   r: 503.53   z0: 486.31   misfit: 2.00e+01
# itreação: 754   r: 503.52   z0: 486.34   misfit: 2.00e+01
# itreação: 755   r: 503.51   z0: 486.37   misfit: 2.00e+01
# itreação: 756   r: 503.50   z0: 486.41   misfit: 2.00e+01
# itreação: 757   r: 503.49   z0: 486.44   misfit: 2.00e+01
# itreação: 758   r: 503.48   z0: 486.48   misfit: 2.00e+01
# itreação: 759   r: 503.47   z0: 486.51   misfit: 2.00e+01
# itreação: 760   r: 503.47   z0: 486.55   misfit: 2.00e+01
# itreação: 761   r: 503.46   z0: 486.58   misfit: 2.00e+01
# itreação: 762   r: 503.45   z0: 486.61   misfit: 2.00e+01
# itreação: 763   r: 503.44   z0: 486.65   misfit: 2.00e+01
# itreação: 764   r: 503.43   z0: 486.68   misfit: 2.00e+01
# itreação: 765   r: 503.42   z0: 486.71   misfit: 2.00e+01
# itreação: 766   r: 503.41   z0: 486.75   misfit: 2.00e+01
# itreação: 767   r: 503.40   z0: 486.78   misfit: 2.00e+01
# itreação: 768   r: 503.40   z0: 486.81   misfit: 2.00e+01
# itreação: 769   r: 503.39   z0: 486.85   misfit: 2.00e+01
# itreação: 770   r: 503.38   z0: 486.88   misfit: 2.00e+01
# itreação: 771   r: 503.37   z0: 486.91   misfit: 2.00e+01
# itreação: 772   r: 503.36   z0: 486.95   misfit: 2.00e+01
# itreação: 773   r: 503.35   z0: 486.98   misfit: 2.00e+01
# itreação: 774   r: 503.34   z0: 487.01   misfit: 2.00e+01
# itreação: 775   r: 503.34   z0: 487.04   misfit: 2.00e+01
# itreação: 776   r: 503.33   z0: 487.08   misfit: 2.00e+01
# itreação: 777   r: 503.32   z0: 487.11   misfit: 2.00e+01
# itreação: 778   r: 503.31   z0: 487.14   misfit: 2.00e+01
# itreação: 779   r: 503.30   z0: 487.17   misfit: 2.00e+01
# itreação: 780   r: 503.29   z0: 487.21   misfit: 2.00e+01
# itreação: 781   r: 503.29   z0: 487.24   misfit: 2.00e+01
# itreação: 782   r: 503.28   z0: 487.27   misfit: 2.00e+01
# itreação: 783   r: 503.27   z0: 487.30   misfit: 2.00e+01
# itreação: 784   r: 503.26   z0: 487.33   misfit: 2.00e+01
# itreação: 785   r: 503.25   z0: 487.36   misfit: 2.00e+01
# itreação: 786   r: 503.24   z0: 487.40   misfit: 2.00e+01
# itreação: 787   r: 503.24   z0: 487.43   misfit: 2.00e+01
# itreação: 788   r: 503.23   z0: 487.46   misfit: 2.00e+01
# itreação: 789   r: 503.22   z0: 487.49   misfit: 2.00e+01
# itreação: 790   r: 503.21   z0: 487.52   misfit: 2.00e+01
# itreação: 791   r: 503.20   z0: 487.55   misfit: 2.00e+01
# itreação: 792   r: 503.20   z0: 487.58   misfit: 2.00e+01
# itreação: 793   r: 503.19   z0: 487.61   misfit: 2.00e+01
# itreação: 794   r: 503.18   z0: 487.64   misfit: 2.00e+01
# itreação: 795   r: 503.17   z0: 487.67   misfit: 2.00e+01
# itreação: 796   r: 503.17   z0: 487.70   misfit: 2.00e+01
# itreação: 797   r: 503.16   z0: 487.73   misfit: 2.00e+01
# itreação: 798   r: 503.15   z0: 487.76   misfit: 2.00e+01
# itreação: 799   r: 503.14   z0: 487.79   misfit: 2.00e+01
# itreação: 800   r: 503.13   z0: 487.82   misfit: 2.00e+01
# itreação: 801   r: 503.13   z0: 487.85   misfit: 2.00e+01
# itreação: 802   r: 503.12   z0: 487.88   misfit: 2.00e+01
# itreação: 803   r: 503.11   z0: 487.91   misfit: 2.00e+01
# itreação: 804   r: 503.10   z0: 487.94   misfit: 2.00e+01
# itreação: 805   r: 503.10   z0: 487.97   misfit: 2.00e+01
# itreação: 806   r: 503.09   z0: 488.00   misfit: 2.00e+01
# itreação: 807   r: 503.08   z0: 488.03   misfit: 2.00e+01
# itreação: 808   r: 503.07   z0: 488.06   misfit: 2.00e+01
# itreação: 809   r: 503.06   z0: 488.09   misfit: 2.00e+01
# itreação: 810   r: 503.06   z0: 488.12   misfit: 2.00e+01
# itreação: 811   r: 503.05   z0: 488.15   misfit: 2.00e+01
# itreação: 812   r: 503.04   z0: 488.18   misfit: 2.00e+01
# itreação: 813   r: 503.04   z0: 488.21   misfit: 2.00e+01
# itreação: 814   r: 503.03   z0: 488.23   misfit: 2.00e+01
# itreação: 815   r: 503.02   z0: 488.26   misfit: 2.00e+01
# itreação: 816   r: 503.01   z0: 488.29   misfit: 2.00e+01
# itreação: 817   r: 503.01   z0: 488.32   misfit: 2.00e+01
# itreação: 818   r: 503.00   z0: 488.35   misfit: 2.00e+01
# itreação: 819   r: 502.99   z0: 488.38   misfit: 2.00e+01
# itreação: 820   r: 502.98   z0: 488.41   misfit: 2.00e+01
# itreação: 821   r: 502.98   z0: 488.43   misfit: 2.00e+01
# itreação: 822   r: 502.97   z0: 488.46   misfit: 2.00e+01
# itreação: 823   r: 502.96   z0: 488.49   misfit: 2.00e+01
# itreação: 824   r: 502.95   z0: 488.52   misfit: 2.00e+01
# itreação: 825   r: 502.95   z0: 488.55   misfit: 2.00e+01
# itreação: 826   r: 502.94   z0: 488.57   misfit: 2.00e+01
# itreação: 827   r: 502.93   z0: 488.60   misfit: 2.00e+01
# itreação: 828   r: 502.93   z0: 488.63   misfit: 2.00e+01
# itreação: 829   r: 502.92   z0: 488.66   misfit: 2.00e+01
# itreação: 830   r: 502.91   z0: 488.68   misfit: 2.00e+01
# itreação: 831   r: 502.90   z0: 488.71   misfit: 2.00e+01
# itreação: 832   r: 502.90   z0: 488.74   misfit: 2.00e+01
# itreação: 833   r: 502.89   z0: 488.76   misfit: 2.00e+01
# itreação: 834   r: 502.88   z0: 488.79   misfit: 2.00e+01
# itreação: 835   r: 502.88   z0: 488.82   misfit: 2.00e+01
# itreação: 836   r: 502.87   z0: 488.85   misfit: 2.00e+01
# itreação: 837   r: 502.86   z0: 488.87   misfit: 2.00e+01
# itreação: 838   r: 502.86   z0: 488.90   misfit: 2.00e+01
# itreação: 839   r: 502.85   z0: 488.93   misfit: 2.00e+01
# itreação: 840   r: 502.84   z0: 488.95   misfit: 2.00e+01
# itreação: 841   r: 502.84   z0: 488.98   misfit: 2.00e+01
# itreação: 842   r: 502.83   z0: 489.00   misfit: 2.00e+01
# itreação: 843   r: 502.82   z0: 489.03   misfit: 2.00e+01
# itreação: 844   r: 502.82   z0: 489.06   misfit: 2.00e+01
# itreação: 845   r: 502.81   z0: 489.08   misfit: 2.00e+01
# itreação: 846   r: 502.80   z0: 489.11   misfit: 2.00e+01
# itreação: 847   r: 502.80   z0: 489.14   misfit: 2.00e+01
# itreação: 848   r: 502.79   z0: 489.16   misfit: 2.00e+01
# itreação: 849   r: 502.78   z0: 489.19   misfit: 2.00e+01
# itreação: 850   r: 502.78   z0: 489.21   misfit: 2.00e+01
# itreação: 851   r: 502.77   z0: 489.24   misfit: 2.00e+01
# itreação: 852   r: 502.76   z0: 489.26   misfit: 1.99e+01
# itreação: 853   r: 502.76   z0: 489.29   misfit: 1.99e+01
# itreação: 854   r: 502.75   z0: 489.32   misfit: 1.99e+01
# itreação: 855   r: 502.74   z0: 489.34   misfit: 1.99e+01
# itreação: 856   r: 502.74   z0: 489.37   misfit: 1.99e+01
# itreação: 857   r: 502.73   z0: 489.39   misfit: 1.99e+01
# itreação: 858   r: 502.72   z0: 489.42   misfit: 1.99e+01
# itreação: 859   r: 502.72   z0: 489.44   misfit: 1.99e+01
# itreação: 860   r: 502.71   z0: 489.47   misfit: 1.99e+01
# itreação: 861   r: 502.70   z0: 489.49   misfit: 1.99e+01
# itreação: 862   r: 502.70   z0: 489.52   misfit: 1.99e+01
# itreação: 863   r: 502.69   z0: 489.54   misfit: 1.99e+01
# itreação: 864   r: 502.68   z0: 489.57   misfit: 1.99e+01
# itreação: 865   r: 502.68   z0: 489.59   misfit: 1.99e+01
# itreação: 866   r: 502.67   z0: 489.61   misfit: 1.99e+01
# itreação: 867   r: 502.67   z0: 489.64   misfit: 1.99e+01
# itreação: 868   r: 502.66   z0: 489.66   misfit: 1.99e+01
# itreação: 869   r: 502.65   z0: 489.69   misfit: 1.99e+01
# itreação: 870   r: 502.65   z0: 489.71   misfit: 1.99e+01
# itreação: 871   r: 502.64   z0: 489.74   misfit: 1.99e+01
# itreação: 872   r: 502.63   z0: 489.76   misfit: 1.99e+01
# itreação: 873   r: 502.63   z0: 489.78   misfit: 1.99e+01
# itreação: 874   r: 502.62   z0: 489.81   misfit: 1.99e+01
# itreação: 875   r: 502.62   z0: 489.83   misfit: 1.99e+01
# itreação: 876   r: 502.61   z0: 489.86   misfit: 1.99e+01
# itreação: 877   r: 502.60   z0: 489.88   misfit: 1.99e+01
# itreação: 878   r: 502.60   z0: 489.90   misfit: 1.99e+01
# itreação: 879   r: 502.59   z0: 489.93   misfit: 1.99e+01
# itreação: 880   r: 502.59   z0: 489.95   misfit: 1.99e+01
# itreação: 881   r: 502.58   z0: 489.97   misfit: 1.99e+01
# itreação: 882   r: 502.57   z0: 490.00   misfit: 1.99e+01
# itreação: 883   r: 502.57   z0: 490.02   misfit: 1.99e+01
# itreação: 884   r: 502.56   z0: 490.04   misfit: 1.99e+01
# itreação: 885   r: 502.56   z0: 490.07   misfit: 1.99e+01
# itreação: 886   r: 502.55   z0: 490.09   misfit: 1.99e+01
# itreação: 887   r: 502.54   z0: 490.11   misfit: 1.99e+01
# itreação: 888   r: 502.54   z0: 490.13   misfit: 1.99e+01
# itreação: 889   r: 502.53   z0: 490.16   misfit: 1.99e+01
# itreação: 890   r: 502.53   z0: 490.18   misfit: 1.99e+01
# itreação: 891   r: 502.52   z0: 490.20   misfit: 1.99e+01
# itreação: 892   r: 502.51   z0: 490.23   misfit: 1.99e+01
# itreação: 893   r: 502.51   z0: 490.25   misfit: 1.99e+01
# itreação: 894   r: 502.50   z0: 490.27   misfit: 1.99e+01
# itreação: 895   r: 502.50   z0: 490.29   misfit: 1.99e+01
# itreação: 896   r: 502.49   z0: 490.32   misfit: 1.99e+01
# itreação: 897   r: 502.49   z0: 490.34   misfit: 1.99e+01
# itreação: 898   r: 502.48   z0: 490.36   misfit: 1.99e+01
# itreação: 899   r: 502.47   z0: 490.38   misfit: 1.99e+01
# itreação: 900   r: 502.47   z0: 490.40   misfit: 1.99e+01
# itreação: 901   r: 502.46   z0: 490.43   misfit: 1.99e+01
# itreação: 902   r: 502.46   z0: 490.45   misfit: 1.99e+01
# itreação: 903   r: 502.45   z0: 490.47   misfit: 1.99e+01
# itreação: 904   r: 502.45   z0: 490.49   misfit: 1.99e+01
# itreação: 905   r: 502.44   z0: 490.51   misfit: 1.99e+01
# itreação: 906   r: 502.44   z0: 490.54   misfit: 1.99e+01
# itreação: 907   r: 502.43   z0: 490.56   misfit: 1.99e+01
# itreação: 908   r: 502.42   z0: 490.58   misfit: 1.99e+01
# itreação: 909   r: 502.42   z0: 490.60   misfit: 1.99e+01
# itreação: 910   r: 502.41   z0: 490.62   misfit: 1.99e+01
# itreação: 911   r: 502.41   z0: 490.64   misfit: 1.99e+01
# itreação: 912   r: 502.40   z0: 490.66   misfit: 1.99e+01
# itreação: 913   r: 502.40   z0: 490.69   misfit: 1.99e+01
# itreação: 914   r: 502.39   z0: 490.71   misfit: 1.99e+01
# itreação: 915   r: 502.39   z0: 490.73   misfit: 1.99e+01
# itreação: 916   r: 502.38   z0: 490.75   misfit: 1.99e+01
# itreação: 917   r: 502.37   z0: 490.77   misfit: 1.99e+01
# itreação: 918   r: 502.37   z0: 490.79   misfit: 1.99e+01
# itreação: 919   r: 502.36   z0: 490.81   misfit: 1.99e+01
# itreação: 920   r: 502.36   z0: 490.83   misfit: 1.99e+01
# itreação: 921   r: 502.35   z0: 490.85   misfit: 1.99e+01
# itreação: 922   r: 502.35   z0: 490.87   misfit: 1.99e+01
# itreação: 923   r: 502.34   z0: 490.89   misfit: 1.99e+01
# itreação: 924   r: 502.34   z0: 490.92   misfit: 1.99e+01
# itreação: 925   r: 502.33   z0: 490.94   misfit: 1.99e+01
# itreação: 926   r: 502.33   z0: 490.96   misfit: 1.99e+01
# itreação: 927   r: 502.32   z0: 490.98   misfit: 1.99e+01
# itreação: 928   r: 502.32   z0: 491.00   misfit: 1.99e+01
# itreação: 929   r: 502.31   z0: 491.02   misfit: 1.99e+01
# itreação: 930   r: 502.31   z0: 491.04   misfit: 1.99e+01
# itreação: 931   r: 502.30   z0: 491.06   misfit: 1.99e+01
# itreação: 932   r: 502.30   z0: 491.08   misfit: 1.99e+01
# itreação: 933   r: 502.29   z0: 491.10   misfit: 1.99e+01
# itreação: 934   r: 502.29   z0: 491.12   misfit: 1.99e+01
# itreação: 935   r: 502.28   z0: 491.14   misfit: 1.99e+01
# itreação: 936   r: 502.28   z0: 491.16   misfit: 1.99e+01
# itreação: 937   r: 502.27   z0: 491.18   misfit: 1.99e+01
# itreação: 938   r: 502.27   z0: 491.20   misfit: 1.99e+01
# itreação: 939   r: 502.26   z0: 491.22   misfit: 1.99e+01
# itreação: 940   r: 502.26   z0: 491.24   misfit: 1.99e+01
# itreação: 941   r: 502.25   z0: 491.26   misfit: 1.99e+01
# itreação: 942   r: 502.25   z0: 491.27   misfit: 1.99e+01
# itreação: 943   r: 502.24   z0: 491.29   misfit: 1.99e+01
# itreação: 944   r: 502.24   z0: 491.31   misfit: 1.99e+01
# itreação: 945   r: 502.23   z0: 491.33   misfit: 1.99e+01
# itreação: 946   r: 502.23   z0: 491.35   misfit: 1.99e+01
# itreação: 947   r: 502.22   z0: 491.37   misfit: 1.99e+01
# itreação: 948   r: 502.22   z0: 491.39   misfit: 1.99e+01
# itreação: 949   r: 502.21   z0: 491.41   misfit: 1.99e+01
# itreação: 950   r: 502.21   z0: 491.43   misfit: 1.99e+01
# itreação: 951   r: 502.20   z0: 491.45   misfit: 1.99e+01
# itreação: 952   r: 502.20   z0: 491.47   misfit: 1.99e+01
# itreação: 953   r: 502.19   z0: 491.49   misfit: 1.99e+01
# itreação: 954   r: 502.19   z0: 491.50   misfit: 1.99e+01
# itreação: 955   r: 502.18   z0: 491.52   misfit: 1.99e+01
# itreação: 956   r: 502.18   z0: 491.54   misfit: 1.99e+01
# itreação: 957   r: 502.17   z0: 491.56   misfit: 1.99e+01
# itreação: 958   r: 502.17   z0: 491.58   misfit: 1.99e+01
# itreação: 959   r: 502.16   z0: 491.60   misfit: 1.99e+01
# itreação: 960   r: 502.16   z0: 491.62   misfit: 1.99e+01
# itreação: 961   r: 502.15   z0: 491.63   misfit: 1.99e+01
# itreação: 962   r: 502.15   z0: 491.65   misfit: 1.99e+01
# itreação: 963   r: 502.14   z0: 491.67   misfit: 1.99e+01
# itreação: 964   r: 502.14   z0: 491.69   misfit: 1.99e+01
# itreação: 965   r: 502.13   z0: 491.71   misfit: 1.99e+01
# itreação: 966   r: 502.13   z0: 491.73   misfit: 1.99e+01
# itreação: 967   r: 502.13   z0: 491.74   misfit: 1.99e+01
# itreação: 968   r: 502.12   z0: 491.76   misfit: 1.99e+01
# itreação: 969   r: 502.12   z0: 491.78   misfit: 1.99e+01
# itreação: 970   r: 502.11   z0: 491.80   misfit: 1.99e+01
# itreação: 971   r: 502.11   z0: 491.81   misfit: 1.99e+01
# itreação: 972   r: 502.10   z0: 491.83   misfit: 1.99e+01
# itreação: 973   r: 502.10   z0: 491.85   misfit: 1.99e+01
# itreação: 974   r: 502.09   z0: 491.87   misfit: 1.99e+01
# itreação: 975   r: 502.09   z0: 491.89   misfit: 1.99e+01
# itreação: 976   r: 502.08   z0: 491.90   misfit: 1.99e+01
# itreação: 977   r: 502.08   z0: 491.92   misfit: 1.99e+01
# itreação: 978   r: 502.08   z0: 491.94   misfit: 1.99e+01
# itreação: 979   r: 502.07   z0: 491.96   misfit: 1.99e+01
# itreação: 980   r: 502.07   z0: 491.97   misfit: 1.99e+01
# itreação: 981   r: 502.06   z0: 491.99   misfit: 1.99e+01
# itreação: 982   r: 502.06   z0: 492.01   misfit: 1.99e+01
# itreação: 983   r: 502.05   z0: 492.03   misfit: 1.99e+01
# itreação: 984   r: 502.05   z0: 492.04   misfit: 1.99e+01
# itreação: 985   r: 502.04   z0: 492.06   misfit: 1.99e+01
# itreação: 986   r: 502.04   z0: 492.08   misfit: 1.99e+01
# itreação: 987   r: 502.04   z0: 492.09   misfit: 1.99e+01
# itreação: 988   r: 502.03   z0: 492.11   misfit: 1.99e+01
# itreação: 989   r: 502.03   z0: 492.13   misfit: 1.99e+01
# itreação: 990   r: 502.02   z0: 492.14   misfit: 1.99e+01
# itreação: 991   r: 502.02   z0: 492.16   misfit: 1.99e+01
# itreação: 992   r: 502.01   z0: 492.18   misfit: 1.99e+01
# itreação: 993   r: 502.01   z0: 492.19   misfit: 1.99e+01
# itreação: 994   r: 502.01   z0: 492.21   misfit: 1.99e+01
# itreação: 995   r: 502.00   z0: 492.23   misfit: 1.99e+01
# itreação: 996   r: 502.00   z0: 492.24   misfit: 1.99e+01
# itreação: 997   r: 501.99   z0: 492.26   misfit: 1.99e+01
# itreação: 998   r: 501.99   z0: 492.28   misfit: 1.99e+01
# itreação: 999   r: 501.98   z0: 492.29   misfit: 1.99e+01

# %% [markdown]
# # Plots de resultados

# %%
res_norm = (res - np.mean(res))/np.std(res)
res_plot = res.reshape(shape)
xp = xp.reshape(shape)
yp = yp.reshape(shape)
dpred = data.reshape(shape)
dobs = data_noise.reshape(shape)

# %%
#plot
plt.figure(figsize=(5,5))
plt.plot(r_true, dz_true, 'oy')
plt.plot(p1_list, p2_list, '.w-', markersize=5)
plt.title('SD - geofisica', fontsize=18)
plt.contourf(r_plot, dz_plot, phi_eq, 40, cmap='jet')
plt.xlabel('$r$', fontsize=18)
plt.ylabel('$dz$', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1)
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Convergencia', fontsize = 18)
plt.xlabel('Iteration number')
plt.plot(phi_list, 'o')

plt.subplot(1, 3, 2)
plt.title('Estimativas de  r', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('r')
plt.plot(p1_list, 'o')
plt.plot(np.zeros(len(p1_list)) + r_true, '-')

plt.subplot(1, 3, 3)
plt.title('Estimativas de  dz', fontsize = 18)
plt.xlabel('Iteration number')
plt.ylabel('z0')
plt.plot(p2_list, 'o')
plt.plot(np.zeros(len(p1_list)) + dz_true, '-')
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Dado predito', fontsize=20)
plt.contourf(yp, xp, dpred, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 2)
plt.title('Dado observado', fontsize=20)
plt.contourf(yp, xp, dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 3)
plt.title('SD - ajuste', fontsize=20)
plt.contourf(yp, xp, res_plot, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)
plt.show()

# %%
plt.plot(figsize=(20,5))
plt.title('Histogram', fontsize = 20)
plt.xlabel('$\mu$ = %.7f  $\sigma$ = %.7f' % (np.mean(res_norm), np.std(res_norm)), fontsize=20)
nbins = int((np.max(res_norm) - np.min(res_norm)))
plt.hist(res_norm,bins=nbins, normed=True)
plt.ylim(0.,0.5)
plt.xlim(-10., 10.)
plt.show()
