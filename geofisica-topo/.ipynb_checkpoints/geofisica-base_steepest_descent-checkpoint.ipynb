# %% [markdown]
# # Steepest descent aplicado à função geofísica

# %% [markdown]
# Algoritmo de Steepest Descent aplicado a um problema geofísico para estimar o raio e a base de um prisma de base poligonal próximo de um cilindro.

# %% [markdown]
# # Importando pacotes

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.mlab import normpdf
import cPickle as pickle
from visual import histeq
from fatiando import utils
from fatiando.mesher import PolygonalPrism
from IPython.display import Image as img
from fatiando.gravmag import polyprism
from copy import deepcopy
from fatiando.gridder import regular
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %% [markdown]
# # Função geofísica

# %%
def geofisica(xp, yp, zp, p, M, z0, props, dobs, inc, dec):
    '''
    This function calculates the data for polygonal
    prisms of the Fatiando a Terra with the two given parameters.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    p: 1D array - parameter vector
    M: int - number of vertices
    L: int - number of prisms
    z0: float - top of the model
    props: dictionary - physical property
    dobs: 1D array - observed data
    inc: float - inclination
    dec: declination

    output

    prism: list - list of objects of the class fatiando.mesher.PolygonalPrism
    d: 1D array - data vector
    res: 1D array - residual data
    phi: float - misfit function value
    '''
    
    r = np.zeros(M) + p[0] # radial distance for each vertice

    # Cartesian coordinates of the origin of each prism
    x0 = 0. 
    y0 = 0.

    l = [r, x0, y0, z0, z0 + p[1], props]   # list of parameters of the prisms
    
    ang = 2*np.pi/M # angle between two vertices
    
    prism = []
    verts=[]
    for i in range(M):
        verts.append([r[i]*np.cos(i*ang) + l[1], r[i]*np.sin(i*ang) + l[2]])
    prism.append(PolygonalPrism(verts, l[3], l[4], l[5]))
    
    d = polyprism.tf(xp, yp, zp, prism, inc, dec)
    res = dobs - d
    phi = np.dot(res, res)
    
    return prism, d, res, phi

# %% [markdown]
# # Modelagem direta

# %%
M = 10 # number of vertices per prism
L = 1 # number of prisms
P = L*(M+2) # number of parameters

z0 = 100.    # depth of the top the shallowest prism
dz_true = 500.    # thickness of each prism

inc = -60.  # inclination
dec = 50.   # declination
intensity = 0.035 # intensity

props={'magnetization': utils.ang2vec(intensity, inc, dec)} # physical property: magnetization

r_true = 500.

r = np.zeros(M) + r_true # radial distance for each vertice

# %%
img(filename='bolacha.png')

# %% [markdown]
# # Pontos de observação

# %%
area = [-2000, 2000, -2000, 2000] #x minimum, x maximum, y minimum and y maximum
shape = (50,50) #number of data along the y and x directions
N = shape[0]*shape[1] #total number of data

#coordinates x and y of the data
xp, yp = regular(area, shape)

zp = np.zeros(N) - 100.

# %% [markdown]
# # Dados observados

# %%
p_true = np.array([r_true, dz_true])
prism_true, data, res_, phi_true = geofisica(xp, yp, zp, p_true, M, z0, props, np.zeros(xp.size), inc, dec)
amp_noise = 0.01*np.max(data)
data_noise = data + np.random.normal(loc=0., scale=amp_noise, size=shape[0]*shape[1]) # noise corrupted data

# %% [markdown]
# # Plot função desajuste

# %%
shape2 = (15,15)
r_plot = np.linspace(10., 1000., shape2[0])
dz_plot = np.linspace(-100., 1000., shape2[1])
r_plot,dz_plot = np.meshgrid(r_plot, dz_plot)
r_plot = r_plot.ravel()
dz_plot = dz_plot.ravel()
phi_plot = np.zeros_like(r_plot)

for i, (r, z) in enumerate(zip(r_plot,dz_plot)):
    p = np.array([r, z])
    prism_pred, d_pred, res, phi_plot[i] = geofisica(xp, yp, zp, p, M, z0, props, data_noise, inc, dec)

r_plot = r_plot.reshape(shape2)
dz_plot = dz_plot.reshape(shape2)
phi_plot = phi_plot.reshape(shape2)

# equalizando as cores
phi_eq = histeq(phi_plot)
phi_eq = np.reshape(phi_eq,shape2)
phi_eq = phi_eq

# %%
plt.figure(figsize=(5,5))
plt.plot(r_true, dz_true, 'oy', label='Parametros verdadeiros')
plt.title('Funcao objetivo', fontsize=18)
plt.contourf(r_plot, dz_plot, phi_eq, 50, cmap='jet')
plt.xlabel('$r$ (m)', fontsize=18)
plt.ylabel('$z_0$ (m)', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1).set_label('nT', fontsize=18)
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, facecolor='gray', edgecolor='black')
plt.show()

# %% [markdown]
# # Funções

# %%
def derivative_tf_z(xp, yp, zp, prism, M, deltaz, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of one fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    delta: float - increment in x coordinate in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'

    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - deltaa
    prism_plus[0].z2 += deltaz
    prism_minus[0].z2 -= deltaz

    df1 = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df2 = polyprism.tf(xp, yp, zp, prism_minus, inc, dec)

    return df1, df2

def derivative_tf_radiall(xp, yp, zp, prism, M, deltar, inc, dec):
    '''
    This function calculates the derivative for total field anomaly
    from a model of polygonal prisms using finite difference.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of a fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in radial distance in meters
    inc: float - inclination
    dec: declination

    output

    df: 1D array - derivative
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'
    
    ang = 2.*np.pi/M # angle between two vertices
    
    prism_plus = deepcopy([prism])  # m.x + delta
    prism_minus = deepcopy([prism])  # m.x - delta

    for i in range(M):
        deltax = deltar*np.cos(i*ang)
        deltay = deltar*np.sin(i*ang)
        prism_plus[0].x[i] += deltax
        prism_plus[0].y[i] += deltay
        prism_minus[0].x[i] -= deltax
        prism_minus[0].y[i] -= deltay

    df1 = polyprism.tf(xp, yp, zp, prism_plus, inc, dec)
    df2 = polyprism.tf(xp, yp, zp, prism_minus, inc, dec)

    return df1, df2

# calculando gradiente
def grad_geo(xp, yp, zp, prism, M, deltar, deltaz, inc, dec, dobs):
    '''
    Returns the gradient vector for polygonal prisms using finite
    differences.

    input

    xp: array - x observation points
    yp: array - y observation points
    zp: array - z observation points
    prism: list - list of fatiando.mesher.PolygonalPrism
    M: int - number of vertices per prism
    deltar: float - increment in meters for radial distance
    deltaz: float - increment in meters for depth
    inc: float - inclination of the local-geomagnetic field
    dec: float - declination of the local-geomagnetic field
    dobs: 1D array - data vector

    output

    grad: 1D array - gradient
    '''
    assert xp.size == yp.size == zp.size, 'The number of points in x, y and z must be equal'
    
    drp, drm = derivative_tf_radiall(xp, yp, zp, prism[0], M, deltar, inc, dec)
    dzp, dzm = derivative_tf_z(xp, yp, zp, prism[0], M, deltaz, inc, dec)
    grad = np.zeros(2)
    grad[0] = (np.sum((dobs - drp)*(dobs - drp)) - np.sum((dobs - drm)*(dobs - drm)))/(2.*deltar)
    grad[1] = (np.sum((dobs - dzp)*(dobs - dzp)) - np.sum((dobs - dzm)*(dobs - dzm)))/(2.*deltaz)
    
    return grad

# %% [markdown]
# # Modelo interpretativo

# %%
# chute inicial
p01 = 200.
p02 = 400.

# incremento para as derivadas
deltar = 0.01*p01
deltaz = 0.01*p02

r = np.zeros(M) + p01 # radial distance for each vertice

# Cartesian coordinates of the origin of each prism
x0 = 0. 
y0 = 0.

# vetor do chute inicial
p0 = np.array([p01,p02]) 

# calculando o dado predito, o valor da função e do resíduo em p0
prism0, d0, res0, phi0 = geofisica(xp, yp, zp, p0, M, z0, props, data_noise, inc, dec)

# parâmetros para o critério de Armijo
mi = 0.0000000

#tamanho do passo
lamb = 1.

# critério de parada
epsilon = 0.0000001

# listas para armazenar as estimativas
p1_list = [p01]
p2_list = [p02]
phi_list = [phi0]

# iterações do algoritmo
itmax = 1000

# %% [markdown]
# # Algoritmo Steepest Descent

# %%
for i in range(itmax):
    # calculando a Jacobiana e o gradiente
    grad = grad_geo(xp, yp, zp, prism0, M, deltar, deltaz, inc, dec, data_noise)
    #print grad
    # calculando p e atualizando para a próxima iteração
    p = p0 - lamb*grad
    #print p, p0
    prism, d, res, phi = geofisica(xp, yp, zp, p, M, z0, props, data_noise, inc, dec)
    
    # printa os valores
    print 'itreação: %3d   r: %.2f   dz: %.2f   misfit: %.2e' % (i, p[0], p[1], phi)
    
    # armazenando os resultados em listas para o plot
    phi_list.append(phi)
    p1_list.append(p[0])
    p2_list.append(p[1])
    
    if (abs(phi-phi0)/phi0 <= epsilon):
        break
    else:
        # atualizando parâmetros
        p0 = p.copy()
        d0 = d.copy()
        res0 = res.copy()
        phi0 = phi
        prism0 = prism
# Out:
# itreação:   0   r: 213.99   dz: 401.93   misfit: 3.20e+03
# itreação:   1   r: 228.25   dz: 404.03   misfit: 2.99e+03
# itreação:   2   r: 242.70   dz: 406.29   misfit: 2.78e+03
# itreação:   3   r: 257.26   dz: 408.71   misfit: 2.56e+03
# itreação:   4   r: 271.84   dz: 411.26   misfit: 2.34e+03
# itreação:   5   r: 286.34   dz: 413.91   misfit: 2.12e+03
# itreação:   6   r: 300.67   dz: 416.66   misfit: 1.91e+03
# itreação:   7   r: 314.75   dz: 419.46   misfit: 1.71e+03
# itreação:   8   r: 328.49   dz: 422.29   misfit: 1.51e+03
# itreação:   9   r: 341.81   dz: 425.13   misfit: 1.33e+03
# itreação:  10   r: 354.65   dz: 427.95   misfit: 1.16e+03
# itreação:  11   r: 366.93   dz: 430.72   misfit: 1.01e+03
# itreação:  12   r: 378.63   dz: 433.43   misfit: 8.67e+02
# itreação:  13   r: 389.69   dz: 436.04   misfit: 7.41e+02
# itreação:  14   r: 400.09   dz: 438.55   misfit: 6.30e+02
# itreação:  15   r: 409.82   dz: 440.95   misfit: 5.33e+02
# itreação:  16   r: 418.88   dz: 443.23   misfit: 4.49e+02
# itreação:  17   r: 427.28   dz: 445.37   misfit: 3.77e+02
# itreação:  18   r: 435.02   dz: 447.38   misfit: 3.15e+02
# itreação:  19   r: 442.14   dz: 449.26   misfit: 2.63e+02
# itreação:  20   r: 448.66   dz: 451.00   misfit: 2.20e+02
# itreação:  21   r: 454.61   dz: 452.62   misfit: 1.84e+02
# itreação:  22   r: 460.02   dz: 454.11   misfit: 1.53e+02
# itreação:  23   r: 464.94   dz: 455.49   misfit: 1.29e+02
# itreação:  24   r: 469.39   dz: 456.75   misfit: 1.08e+02
# itreação:  25   r: 473.42   dz: 457.91   misfit: 9.15e+01
# itreação:  26   r: 477.05   dz: 458.97   misfit: 7.79e+01
# itreação:  27   r: 480.31   dz: 459.94   misfit: 6.68e+01
# itreação:  28   r: 483.25   dz: 460.83   misfit: 5.79e+01
# itreação:  29   r: 485.89   dz: 461.64   misfit: 5.06e+01
# itreação:  30   r: 488.26   dz: 462.38   misfit: 4.48e+01
# itreação:  31   r: 490.38   dz: 463.06   misfit: 4.01e+01
# itreação:  32   r: 492.28   dz: 463.68   misfit: 3.63e+01
# itreação:  33   r: 493.98   dz: 464.25   misfit: 3.33e+01
# itreação:  34   r: 495.49   dz: 464.76   misfit: 3.09e+01
# itreação:  35   r: 496.84   dz: 465.24   misfit: 2.89e+01
# itreação:  36   r: 498.05   dz: 465.67   misfit: 2.74e+01
# itreação:  37   r: 499.12   dz: 466.07   misfit: 2.61e+01
# itreação:  38   r: 500.08   dz: 466.44   misfit: 2.51e+01
# itreação:  39   r: 500.93   dz: 466.78   misfit: 2.43e+01
# itreação:  40   r: 501.69   dz: 467.09   misfit: 2.37e+01
# itreação:  41   r: 502.36   dz: 467.38   misfit: 2.32e+01
# itreação:  42   r: 502.96   dz: 467.65   misfit: 2.28e+01
# itreação:  43   r: 503.49   dz: 467.90   misfit: 2.24e+01
# itreação:  44   r: 503.96   dz: 468.13   misfit: 2.22e+01
# itreação:  45   r: 504.37   dz: 468.35   misfit: 2.20e+01
# itreação:  46   r: 504.74   dz: 468.56   misfit: 2.18e+01
# itreação:  47   r: 505.06   dz: 468.75   misfit: 2.17e+01
# itreação:  48   r: 505.35   dz: 468.93   misfit: 2.16e+01
# itreação:  49   r: 505.60   dz: 469.11   misfit: 2.15e+01
# itreação:  50   r: 505.82   dz: 469.27   misfit: 2.14e+01
# itreação:  51   r: 506.02   dz: 469.43   misfit: 2.13e+01
# itreação:  52   r: 506.19   dz: 469.58   misfit: 2.13e+01
# itreação:  53   r: 506.34   dz: 469.72   misfit: 2.13e+01
# itreação:  54   r: 506.47   dz: 469.86   misfit: 2.12e+01
# itreação:  55   r: 506.58   dz: 469.99   misfit: 2.12e+01
# itreação:  56   r: 506.68   dz: 470.12   misfit: 2.12e+01
# itreação:  57   r: 506.76   dz: 470.24   misfit: 2.11e+01
# itreação:  58   r: 506.83   dz: 470.36   misfit: 2.11e+01
# itreação:  59   r: 506.90   dz: 470.48   misfit: 2.11e+01
# itreação:  60   r: 506.95   dz: 470.60   misfit: 2.11e+01
# itreação:  61   r: 506.99   dz: 470.71   misfit: 2.11e+01
# itreação:  62   r: 507.03   dz: 470.82   misfit: 2.11e+01
# itreação:  63   r: 507.06   dz: 470.92   misfit: 2.11e+01
# itreação:  64   r: 507.08   dz: 471.03   misfit: 2.10e+01
# itreação:  65   r: 507.10   dz: 471.13   misfit: 2.10e+01
# itreação:  66   r: 507.11   dz: 471.23   misfit: 2.10e+01
# itreação:  67   r: 507.12   dz: 471.33   misfit: 2.10e+01
# itreação:  68   r: 507.13   dz: 471.43   misfit: 2.10e+01
# itreação:  69   r: 507.13   dz: 471.53   misfit: 2.10e+01
# itreação:  70   r: 507.13   dz: 471.63   misfit: 2.10e+01
# itreação:  71   r: 507.13   dz: 471.72   misfit: 2.10e+01
# itreação:  72   r: 507.12   dz: 471.82   misfit: 2.10e+01
# itreação:  73   r: 507.12   dz: 471.91   misfit: 2.10e+01
# itreação:  74   r: 507.11   dz: 472.00   misfit: 2.09e+01
# itreação:  75   r: 507.10   dz: 472.09   misfit: 2.09e+01
# itreação:  76   r: 507.09   dz: 472.18   misfit: 2.09e+01
# itreação:  77   r: 507.07   dz: 472.27   misfit: 2.09e+01
# itreação:  78   r: 507.06   dz: 472.36   misfit: 2.09e+01
# itreação:  79   r: 507.04   dz: 472.45   misfit: 2.09e+01
# itreação:  80   r: 507.03   dz: 472.54   misfit: 2.09e+01
# itreação:  81   r: 507.01   dz: 472.63   misfit: 2.09e+01
# itreação:  82   r: 506.99   dz: 472.72   misfit: 2.09e+01
# itreação:  83   r: 506.98   dz: 472.80   misfit: 2.09e+01
# itreação:  84   r: 506.96   dz: 472.89   misfit: 2.09e+01
# itreação:  85   r: 506.94   dz: 472.98   misfit: 2.09e+01
# itreação:  86   r: 506.92   dz: 473.06   misfit: 2.08e+01
# itreação:  87   r: 506.90   dz: 473.15   misfit: 2.08e+01
# itreação:  88   r: 506.88   dz: 473.23   misfit: 2.08e+01
# itreação:  89   r: 506.86   dz: 473.31   misfit: 2.08e+01
# itreação:  90   r: 506.84   dz: 473.40   misfit: 2.08e+01
# itreação:  91   r: 506.82   dz: 473.48   misfit: 2.08e+01
# itreação:  92   r: 506.80   dz: 473.56   misfit: 2.08e+01
# itreação:  93   r: 506.78   dz: 473.65   misfit: 2.08e+01
# itreação:  94   r: 506.76   dz: 473.73   misfit: 2.08e+01
# itreação:  95   r: 506.74   dz: 473.81   misfit: 2.08e+01
# itreação:  96   r: 506.72   dz: 473.89   misfit: 2.08e+01
# itreação:  97   r: 506.70   dz: 473.97   misfit: 2.08e+01
# itreação:  98   r: 506.68   dz: 474.06   misfit: 2.08e+01
# itreação:  99   r: 506.66   dz: 474.14   misfit: 2.08e+01
# itreação: 100   r: 506.63   dz: 474.22   misfit: 2.07e+01
# itreação: 101   r: 506.61   dz: 474.30   misfit: 2.07e+01
# itreação: 102   r: 506.59   dz: 474.38   misfit: 2.07e+01
# itreação: 103   r: 506.57   dz: 474.46   misfit: 2.07e+01
# itreação: 104   r: 506.55   dz: 474.54   misfit: 2.07e+01
# itreação: 105   r: 506.53   dz: 474.61   misfit: 2.07e+01
# itreação: 106   r: 506.51   dz: 474.69   misfit: 2.07e+01
# itreação: 107   r: 506.49   dz: 474.77   misfit: 2.07e+01
# itreação: 108   r: 506.47   dz: 474.85   misfit: 2.07e+01
# itreação: 109   r: 506.45   dz: 474.93   misfit: 2.07e+01
# itreação: 110   r: 506.43   dz: 475.00   misfit: 2.07e+01
# itreação: 111   r: 506.41   dz: 475.08   misfit: 2.07e+01
# itreação: 112   r: 506.39   dz: 475.16   misfit: 2.07e+01
# itreação: 113   r: 506.37   dz: 475.23   misfit: 2.07e+01
# itreação: 114   r: 506.35   dz: 475.31   misfit: 2.07e+01
# itreação: 115   r: 506.32   dz: 475.39   misfit: 2.07e+01
# itreação: 116   r: 506.30   dz: 475.46   misfit: 2.06e+01
# itreação: 117   r: 506.28   dz: 475.54   misfit: 2.06e+01
# itreação: 118   r: 506.26   dz: 475.61   misfit: 2.06e+01
# itreação: 119   r: 506.24   dz: 475.69   misfit: 2.06e+01
# itreação: 120   r: 506.22   dz: 475.76   misfit: 2.06e+01
# itreação: 121   r: 506.20   dz: 475.84   misfit: 2.06e+01
# itreação: 122   r: 506.19   dz: 475.91   misfit: 2.06e+01
# itreação: 123   r: 506.17   dz: 475.98   misfit: 2.06e+01
# itreação: 124   r: 506.15   dz: 476.06   misfit: 2.06e+01
# itreação: 125   r: 506.13   dz: 476.13   misfit: 2.06e+01
# itreação: 126   r: 506.11   dz: 476.20   misfit: 2.06e+01
# itreação: 127   r: 506.09   dz: 476.27   misfit: 2.06e+01
# itreação: 128   r: 506.07   dz: 476.35   misfit: 2.06e+01
# itreação: 129   r: 506.05   dz: 476.42   misfit: 2.06e+01
# itreação: 130   r: 506.03   dz: 476.49   misfit: 2.06e+01
# itreação: 131   r: 506.01   dz: 476.56   misfit: 2.06e+01
# itreação: 132   r: 505.99   dz: 476.63   misfit: 2.06e+01
# itreação: 133   r: 505.97   dz: 476.71   misfit: 2.05e+01
# itreação: 134   r: 505.95   dz: 476.78   misfit: 2.05e+01
# itreação: 135   r: 505.93   dz: 476.85   misfit: 2.05e+01
# itreação: 136   r: 505.92   dz: 476.92   misfit: 2.05e+01
# itreação: 137   r: 505.90   dz: 476.99   misfit: 2.05e+01
# itreação: 138   r: 505.88   dz: 477.06   misfit: 2.05e+01
# itreação: 139   r: 505.86   dz: 477.13   misfit: 2.05e+01
# itreação: 140   r: 505.84   dz: 477.20   misfit: 2.05e+01
# itreação: 141   r: 505.82   dz: 477.26   misfit: 2.05e+01
# itreação: 142   r: 505.80   dz: 477.33   misfit: 2.05e+01
# itreação: 143   r: 505.79   dz: 477.40   misfit: 2.05e+01
# itreação: 144   r: 505.77   dz: 477.47   misfit: 2.05e+01
# itreação: 145   r: 505.75   dz: 477.54   misfit: 2.05e+01
# itreação: 146   r: 505.73   dz: 477.61   misfit: 2.05e+01
# itreação: 147   r: 505.71   dz: 477.67   misfit: 2.05e+01
# itreação: 148   r: 505.70   dz: 477.74   misfit: 2.05e+01
# itreação: 149   r: 505.68   dz: 477.81   misfit: 2.05e+01
# itreação: 150   r: 505.66   dz: 477.88   misfit: 2.05e+01
# itreação: 151   r: 505.64   dz: 477.94   misfit: 2.05e+01
# itreação: 152   r: 505.62   dz: 478.01   misfit: 2.05e+01
# itreação: 153   r: 505.61   dz: 478.07   misfit: 2.04e+01
# itreação: 154   r: 505.59   dz: 478.14   misfit: 2.04e+01
# itreação: 155   r: 505.57   dz: 478.21   misfit: 2.04e+01
# itreação: 156   r: 505.55   dz: 478.27   misfit: 2.04e+01
# itreação: 157   r: 505.54   dz: 478.34   misfit: 2.04e+01
# itreação: 158   r: 505.52   dz: 478.40   misfit: 2.04e+01
# itreação: 159   r: 505.50   dz: 478.47   misfit: 2.04e+01
# itreação: 160   r: 505.49   dz: 478.53   misfit: 2.04e+01
# itreação: 161   r: 505.47   dz: 478.60   misfit: 2.04e+01
# itreação: 162   r: 505.45   dz: 478.66   misfit: 2.04e+01
# itreação: 163   r: 505.43   dz: 478.72   misfit: 2.04e+01
# itreação: 164   r: 505.42   dz: 478.79   misfit: 2.04e+01
# itreação: 165   r: 505.40   dz: 478.85   misfit: 2.04e+01
# itreação: 166   r: 505.38   dz: 478.91   misfit: 2.04e+01
# itreação: 167   r: 505.37   dz: 478.98   misfit: 2.04e+01
# itreação: 168   r: 505.35   dz: 479.04   misfit: 2.04e+01
# itreação: 169   r: 505.33   dz: 479.10   misfit: 2.04e+01
# itreação: 170   r: 505.32   dz: 479.16   misfit: 2.04e+01
# itreação: 171   r: 505.30   dz: 479.23   misfit: 2.04e+01
# itreação: 172   r: 505.28   dz: 479.29   misfit: 2.04e+01
# itreação: 173   r: 505.27   dz: 479.35   misfit: 2.04e+01
# itreação: 174   r: 505.25   dz: 479.41   misfit: 2.04e+01
# itreação: 175   r: 505.23   dz: 479.47   misfit: 2.04e+01
# itreação: 176   r: 505.22   dz: 479.53   misfit: 2.03e+01
# itreação: 177   r: 505.20   dz: 479.59   misfit: 2.03e+01
# itreação: 178   r: 505.19   dz: 479.66   misfit: 2.03e+01
# itreação: 179   r: 505.17   dz: 479.72   misfit: 2.03e+01
# itreação: 180   r: 505.15   dz: 479.78   misfit: 2.03e+01
# itreação: 181   r: 505.14   dz: 479.84   misfit: 2.03e+01
# itreação: 182   r: 505.12   dz: 479.90   misfit: 2.03e+01
# itreação: 183   r: 505.11   dz: 479.96   misfit: 2.03e+01
# itreação: 184   r: 505.09   dz: 480.01   misfit: 2.03e+01
# itreação: 185   r: 505.08   dz: 480.07   misfit: 2.03e+01
# itreação: 186   r: 505.06   dz: 480.13   misfit: 2.03e+01
# itreação: 187   r: 505.04   dz: 480.19   misfit: 2.03e+01
# itreação: 188   r: 505.03   dz: 480.25   misfit: 2.03e+01
# itreação: 189   r: 505.01   dz: 480.31   misfit: 2.03e+01
# itreação: 190   r: 505.00   dz: 480.37   misfit: 2.03e+01
# itreação: 191   r: 504.98   dz: 480.42   misfit: 2.03e+01
# itreação: 192   r: 504.97   dz: 480.48   misfit: 2.03e+01
# itreação: 193   r: 504.95   dz: 480.54   misfit: 2.03e+01
# itreação: 194   r: 504.94   dz: 480.60   misfit: 2.03e+01
# itreação: 195   r: 504.92   dz: 480.65   misfit: 2.03e+01
# itreação: 196   r: 504.91   dz: 480.71   misfit: 2.03e+01
# itreação: 197   r: 504.89   dz: 480.77   misfit: 2.03e+01
# itreação: 198   r: 504.88   dz: 480.82   misfit: 2.03e+01
# itreação: 199   r: 504.86   dz: 480.88   misfit: 2.03e+01
# itreação: 200   r: 504.85   dz: 480.94   misfit: 2.03e+01
# itreação: 201   r: 504.83   dz: 480.99   misfit: 2.03e+01
# itreação: 202   r: 504.82   dz: 481.05   misfit: 2.03e+01
# itreação: 203   r: 504.80   dz: 481.11   misfit: 2.03e+01
# itreação: 204   r: 504.79   dz: 481.16   misfit: 2.02e+01
# itreação: 205   r: 504.77   dz: 481.22   misfit: 2.02e+01
# itreação: 206   r: 504.76   dz: 481.27   misfit: 2.02e+01
# itreação: 207   r: 504.74   dz: 481.33   misfit: 2.02e+01
# itreação: 208   r: 504.73   dz: 481.38   misfit: 2.02e+01
# itreação: 209   r: 504.72   dz: 481.43   misfit: 2.02e+01
# itreação: 210   r: 504.70   dz: 481.49   misfit: 2.02e+01
# itreação: 211   r: 504.69   dz: 481.54   misfit: 2.02e+01
# itreação: 212   r: 504.67   dz: 481.60   misfit: 2.02e+01
# itreação: 213   r: 504.66   dz: 481.65   misfit: 2.02e+01
# itreação: 214   r: 504.64   dz: 481.70   misfit: 2.02e+01
# itreação: 215   r: 504.63   dz: 481.76   misfit: 2.02e+01
# itreação: 216   r: 504.62   dz: 481.81   misfit: 2.02e+01
# itreação: 217   r: 504.60   dz: 481.86   misfit: 2.02e+01
# itreação: 218   r: 504.59   dz: 481.92   misfit: 2.02e+01
# itreação: 219   r: 504.57   dz: 481.97   misfit: 2.02e+01
# itreação: 220   r: 504.56   dz: 482.02   misfit: 2.02e+01
# itreação: 221   r: 504.55   dz: 482.08   misfit: 2.02e+01
# itreação: 222   r: 504.53   dz: 482.13   misfit: 2.02e+01
# itreação: 223   r: 504.52   dz: 482.18   misfit: 2.02e+01
# itreação: 224   r: 504.51   dz: 482.23   misfit: 2.02e+01
# itreação: 225   r: 504.49   dz: 482.28   misfit: 2.02e+01
# itreação: 226   r: 504.48   dz: 482.33   misfit: 2.02e+01
# itreação: 227   r: 504.47   dz: 482.39   misfit: 2.02e+01
# itreação: 228   r: 504.45   dz: 482.44   misfit: 2.02e+01
# itreação: 229   r: 504.44   dz: 482.49   misfit: 2.02e+01
# itreação: 230   r: 504.43   dz: 482.54   misfit: 2.02e+01
# itreação: 231   r: 504.41   dz: 482.59   misfit: 2.02e+01
# itreação: 232   r: 504.40   dz: 482.64   misfit: 2.02e+01
# itreação: 233   r: 504.39   dz: 482.69   misfit: 2.02e+01
# itreação: 234   r: 504.37   dz: 482.74   misfit: 2.02e+01
# itreação: 235   r: 504.36   dz: 482.79   misfit: 2.02e+01
# itreação: 236   r: 504.35   dz: 482.84   misfit: 2.02e+01
# itreação: 237   r: 504.33   dz: 482.89   misfit: 2.02e+01
# itreação: 238   r: 504.32   dz: 482.94   misfit: 2.02e+01
# itreação: 239   r: 504.31   dz: 482.99   misfit: 2.01e+01
# itreação: 240   r: 504.29   dz: 483.04   misfit: 2.01e+01
# itreação: 241   r: 504.28   dz: 483.09   misfit: 2.01e+01
# itreação: 242   r: 504.27   dz: 483.13   misfit: 2.01e+01
# itreação: 243   r: 504.26   dz: 483.18   misfit: 2.01e+01
# itreação: 244   r: 504.24   dz: 483.23   misfit: 2.01e+01
# itreação: 245   r: 504.23   dz: 483.28   misfit: 2.01e+01
# itreação: 246   r: 504.22   dz: 483.33   misfit: 2.01e+01
# itreação: 247   r: 504.21   dz: 483.38   misfit: 2.01e+01
# itreação: 248   r: 504.19   dz: 483.42   misfit: 2.01e+01
# itreação: 249   r: 504.18   dz: 483.47   misfit: 2.01e+01
# itreação: 250   r: 504.17   dz: 483.52   misfit: 2.01e+01
# itreação: 251   r: 504.16   dz: 483.57   misfit: 2.01e+01
# itreação: 252   r: 504.14   dz: 483.61   misfit: 2.01e+01
# itreação: 253   r: 504.13   dz: 483.66   misfit: 2.01e+01
# itreação: 254   r: 504.12   dz: 483.71   misfit: 2.01e+01
# itreação: 255   r: 504.11   dz: 483.75   misfit: 2.01e+01
# itreação: 256   r: 504.09   dz: 483.80   misfit: 2.01e+01
# itreação: 257   r: 504.08   dz: 483.85   misfit: 2.01e+01
# itreação: 258   r: 504.07   dz: 483.89   misfit: 2.01e+01
# itreação: 259   r: 504.06   dz: 483.94   misfit: 2.01e+01
# itreação: 260   r: 504.05   dz: 483.99   misfit: 2.01e+01
# itreação: 261   r: 504.03   dz: 484.03   misfit: 2.01e+01
# itreação: 262   r: 504.02   dz: 484.08   misfit: 2.01e+01
# itreação: 263   r: 504.01   dz: 484.12   misfit: 2.01e+01
# itreação: 264   r: 504.00   dz: 484.17   misfit: 2.01e+01
# itreação: 265   r: 503.99   dz: 484.21   misfit: 2.01e+01
# itreação: 266   r: 503.97   dz: 484.26   misfit: 2.01e+01
# itreação: 267   r: 503.96   dz: 484.30   misfit: 2.01e+01
# itreação: 268   r: 503.95   dz: 484.35   misfit: 2.01e+01
# itreação: 269   r: 503.94   dz: 484.39   misfit: 2.01e+01
# itreação: 270   r: 503.93   dz: 484.44   misfit: 2.01e+01
# itreação: 271   r: 503.92   dz: 484.48   misfit: 2.01e+01
# itreação: 272   r: 503.90   dz: 484.53   misfit: 2.01e+01
# itreação: 273   r: 503.89   dz: 484.57   misfit: 2.01e+01
# itreação: 274   r: 503.88   dz: 484.61   misfit: 2.01e+01
# itreação: 275   r: 503.87   dz: 484.66   misfit: 2.01e+01
# itreação: 276   r: 503.86   dz: 484.70   misfit: 2.01e+01
# itreação: 277   r: 503.85   dz: 484.75   misfit: 2.01e+01
# itreação: 278   r: 503.84   dz: 484.79   misfit: 2.01e+01
# itreação: 279   r: 503.82   dz: 484.83   misfit: 2.01e+01
# itreação: 280   r: 503.81   dz: 484.88   misfit: 2.01e+01
# itreação: 281   r: 503.80   dz: 484.92   misfit: 2.01e+01
# itreação: 282   r: 503.79   dz: 484.96   misfit: 2.01e+01
# itreação: 283   r: 503.78   dz: 485.00   misfit: 2.00e+01
# itreação: 284   r: 503.77   dz: 485.05   misfit: 2.00e+01
# itreação: 285   r: 503.76   dz: 485.09   misfit: 2.00e+01
# itreação: 286   r: 503.75   dz: 485.13   misfit: 2.00e+01
# itreação: 287   r: 503.74   dz: 485.17   misfit: 2.00e+01
# itreação: 288   r: 503.72   dz: 485.22   misfit: 2.00e+01
# itreação: 289   r: 503.71   dz: 485.26   misfit: 2.00e+01
# itreação: 290   r: 503.70   dz: 485.30   misfit: 2.00e+01
# itreação: 291   r: 503.69   dz: 485.34   misfit: 2.00e+01
# itreação: 292   r: 503.68   dz: 485.38   misfit: 2.00e+01
# itreação: 293   r: 503.67   dz: 485.42   misfit: 2.00e+01
# itreação: 294   r: 503.66   dz: 485.46   misfit: 2.00e+01
# itreação: 295   r: 503.65   dz: 485.51   misfit: 2.00e+01
# itreação: 296   r: 503.64   dz: 485.55   misfit: 2.00e+01
# itreação: 297   r: 503.63   dz: 485.59   misfit: 2.00e+01
# itreação: 298   r: 503.62   dz: 485.63   misfit: 2.00e+01
# itreação: 299   r: 503.61   dz: 485.67   misfit: 2.00e+01
# itreação: 300   r: 503.60   dz: 485.71   misfit: 2.00e+01
# itreação: 301   r: 503.59   dz: 485.75   misfit: 2.00e+01
# itreação: 302   r: 503.58   dz: 485.79   misfit: 2.00e+01
# itreação: 303   r: 503.56   dz: 485.83   misfit: 2.00e+01
# itreação: 304   r: 503.55   dz: 485.87   misfit: 2.00e+01
# itreação: 305   r: 503.54   dz: 485.91   misfit: 2.00e+01
# itreação: 306   r: 503.53   dz: 485.95   misfit: 2.00e+01
# itreação: 307   r: 503.52   dz: 485.99   misfit: 2.00e+01
# itreação: 308   r: 503.51   dz: 486.03   misfit: 2.00e+01
# itreação: 309   r: 503.50   dz: 486.07   misfit: 2.00e+01
# itreação: 310   r: 503.49   dz: 486.11   misfit: 2.00e+01
# itreação: 311   r: 503.48   dz: 486.14   misfit: 2.00e+01
# itreação: 312   r: 503.47   dz: 486.18   misfit: 2.00e+01
# itreação: 313   r: 503.46   dz: 486.22   misfit: 2.00e+01
# itreação: 314   r: 503.45   dz: 486.26   misfit: 2.00e+01
# itreação: 315   r: 503.44   dz: 486.30   misfit: 2.00e+01
# itreação: 316   r: 503.43   dz: 486.34   misfit: 2.00e+01
# itreação: 317   r: 503.42   dz: 486.38   misfit: 2.00e+01
# itreação: 318   r: 503.41   dz: 486.41   misfit: 2.00e+01
# itreação: 319   r: 503.40   dz: 486.45   misfit: 2.00e+01
# itreação: 320   r: 503.39   dz: 486.49   misfit: 2.00e+01
# itreação: 321   r: 503.38   dz: 486.53   misfit: 2.00e+01
# itreação: 322   r: 503.37   dz: 486.56   misfit: 2.00e+01
# itreação: 323   r: 503.36   dz: 486.60   misfit: 2.00e+01
# itreação: 324   r: 503.35   dz: 486.64   misfit: 2.00e+01
# itreação: 325   r: 503.34   dz: 486.68   misfit: 2.00e+01
# itreação: 326   r: 503.33   dz: 486.71   misfit: 2.00e+01
# itreação: 327   r: 503.33   dz: 486.75   misfit: 2.00e+01
# itreação: 328   r: 503.32   dz: 486.79   misfit: 2.00e+01
# itreação: 329   r: 503.31   dz: 486.83   misfit: 2.00e+01
# itreação: 330   r: 503.30   dz: 486.86   misfit: 2.00e+01
# itreação: 331   r: 503.29   dz: 486.90   misfit: 2.00e+01
# itreação: 332   r: 503.28   dz: 486.93   misfit: 2.00e+01
# itreação: 333   r: 503.27   dz: 486.97   misfit: 2.00e+01
# itreação: 334   r: 503.26   dz: 487.01   misfit: 2.00e+01
# itreação: 335   r: 503.25   dz: 487.04   misfit: 2.00e+01
# itreação: 336   r: 503.24   dz: 487.08   misfit: 2.00e+01
# itreação: 337   r: 503.23   dz: 487.12   misfit: 2.00e+01
# itreação: 338   r: 503.22   dz: 487.15   misfit: 2.00e+01
# itreação: 339   r: 503.21   dz: 487.19   misfit: 2.00e+01
# itreação: 340   r: 503.20   dz: 487.22   misfit: 2.00e+01
# itreação: 341   r: 503.19   dz: 487.26   misfit: 2.00e+01
# itreação: 342   r: 503.18   dz: 487.29   misfit: 2.00e+01
# itreação: 343   r: 503.18   dz: 487.33   misfit: 2.00e+01
# itreação: 344   r: 503.17   dz: 487.36   misfit: 2.00e+01
# itreação: 345   r: 503.16   dz: 487.40   misfit: 2.00e+01
# itreação: 346   r: 503.15   dz: 487.43   misfit: 1.99e+01
# itreação: 347   r: 503.14   dz: 487.47   misfit: 1.99e+01
# itreação: 348   r: 503.13   dz: 487.50   misfit: 1.99e+01
# itreação: 349   r: 503.12   dz: 487.54   misfit: 1.99e+01
# itreação: 350   r: 503.11   dz: 487.57   misfit: 1.99e+01
# itreação: 351   r: 503.10   dz: 487.61   misfit: 1.99e+01
# itreação: 352   r: 503.09   dz: 487.64   misfit: 1.99e+01
# itreação: 353   r: 503.09   dz: 487.67   misfit: 1.99e+01
# itreação: 354   r: 503.08   dz: 487.71   misfit: 1.99e+01
# itreação: 355   r: 503.07   dz: 487.74   misfit: 1.99e+01
# itreação: 356   r: 503.06   dz: 487.78   misfit: 1.99e+01
# itreação: 357   r: 503.05   dz: 487.81   misfit: 1.99e+01
# itreação: 358   r: 503.04   dz: 487.84   misfit: 1.99e+01
# itreação: 359   r: 503.03   dz: 487.88   misfit: 1.99e+01
# itreação: 360   r: 503.02   dz: 487.91   misfit: 1.99e+01
# itreação: 361   r: 503.02   dz: 487.94   misfit: 1.99e+01
# itreação: 362   r: 503.01   dz: 487.98   misfit: 1.99e+01
# itreação: 363   r: 503.00   dz: 488.01   misfit: 1.99e+01
# itreação: 364   r: 502.99   dz: 488.04   misfit: 1.99e+01
# itreação: 365   r: 502.98   dz: 488.08   misfit: 1.99e+01
# itreação: 366   r: 502.97   dz: 488.11   misfit: 1.99e+01
# itreação: 367   r: 502.97   dz: 488.14   misfit: 1.99e+01
# itreação: 368   r: 502.96   dz: 488.17   misfit: 1.99e+01
# itreação: 369   r: 502.95   dz: 488.21   misfit: 1.99e+01
# itreação: 370   r: 502.94   dz: 488.24   misfit: 1.99e+01
# itreação: 371   r: 502.93   dz: 488.27   misfit: 1.99e+01
# itreação: 372   r: 502.92   dz: 488.30   misfit: 1.99e+01
# itreação: 373   r: 502.91   dz: 488.34   misfit: 1.99e+01
# itreação: 374   r: 502.91   dz: 488.37   misfit: 1.99e+01
# itreação: 375   r: 502.90   dz: 488.40   misfit: 1.99e+01
# itreação: 376   r: 502.89   dz: 488.43   misfit: 1.99e+01
# itreação: 377   r: 502.88   dz: 488.46   misfit: 1.99e+01
# itreação: 378   r: 502.87   dz: 488.49   misfit: 1.99e+01
# itreação: 379   r: 502.87   dz: 488.53   misfit: 1.99e+01
# itreação: 380   r: 502.86   dz: 488.56   misfit: 1.99e+01
# itreação: 381   r: 502.85   dz: 488.59   misfit: 1.99e+01
# itreação: 382   r: 502.84   dz: 488.62   misfit: 1.99e+01
# itreação: 383   r: 502.83   dz: 488.65   misfit: 1.99e+01
# itreação: 384   r: 502.83   dz: 488.68   misfit: 1.99e+01
# itreação: 385   r: 502.82   dz: 488.71   misfit: 1.99e+01
# itreação: 386   r: 502.81   dz: 488.74   misfit: 1.99e+01
# itreação: 387   r: 502.80   dz: 488.77   misfit: 1.99e+01
# itreação: 388   r: 502.79   dz: 488.80   misfit: 1.99e+01
# itreação: 389   r: 502.79   dz: 488.84   misfit: 1.99e+01
# itreação: 390   r: 502.78   dz: 488.87   misfit: 1.99e+01
# itreação: 391   r: 502.77   dz: 488.90   misfit: 1.99e+01
# itreação: 392   r: 502.76   dz: 488.93   misfit: 1.99e+01
# itreação: 393   r: 502.75   dz: 488.96   misfit: 1.99e+01
# itreação: 394   r: 502.75   dz: 488.99   misfit: 1.99e+01
# itreação: 395   r: 502.74   dz: 489.02   misfit: 1.99e+01
# itreação: 396   r: 502.73   dz: 489.05   misfit: 1.99e+01
# itreação: 397   r: 502.72   dz: 489.08   misfit: 1.99e+01
# itreação: 398   r: 502.72   dz: 489.11   misfit: 1.99e+01
# itreação: 399   r: 502.71   dz: 489.14   misfit: 1.99e+01
# itreação: 400   r: 502.70   dz: 489.16   misfit: 1.99e+01
# itreação: 401   r: 502.69   dz: 489.19   misfit: 1.99e+01
# itreação: 402   r: 502.69   dz: 489.22   misfit: 1.99e+01
# itreação: 403   r: 502.68   dz: 489.25   misfit: 1.99e+01
# itreação: 404   r: 502.67   dz: 489.28   misfit: 1.99e+01
# itreação: 405   r: 502.66   dz: 489.31   misfit: 1.99e+01
# itreação: 406   r: 502.66   dz: 489.34   misfit: 1.99e+01
# itreação: 407   r: 502.65   dz: 489.37   misfit: 1.99e+01
# itreação: 408   r: 502.64   dz: 489.40   misfit: 1.99e+01
# itreação: 409   r: 502.63   dz: 489.43   misfit: 1.99e+01
# itreação: 410   r: 502.63   dz: 489.45   misfit: 1.99e+01
# itreação: 411   r: 502.62   dz: 489.48   misfit: 1.99e+01
# itreação: 412   r: 502.61   dz: 489.51   misfit: 1.99e+01
# itreação: 413   r: 502.60   dz: 489.54   misfit: 1.99e+01
# itreação: 414   r: 502.60   dz: 489.57   misfit: 1.99e+01
# itreação: 415   r: 502.59   dz: 489.60   misfit: 1.99e+01
# itreação: 416   r: 502.58   dz: 489.62   misfit: 1.99e+01
# itreação: 417   r: 502.58   dz: 489.65   misfit: 1.99e+01
# itreação: 418   r: 502.57   dz: 489.68   misfit: 1.99e+01
# itreação: 419   r: 502.56   dz: 489.71   misfit: 1.99e+01
# itreação: 420   r: 502.55   dz: 489.74   misfit: 1.99e+01
# itreação: 421   r: 502.55   dz: 489.76   misfit: 1.99e+01
# itreação: 422   r: 502.54   dz: 489.79   misfit: 1.99e+01
# itreação: 423   r: 502.53   dz: 489.82   misfit: 1.99e+01
# itreação: 424   r: 502.53   dz: 489.85   misfit: 1.99e+01
# itreação: 425   r: 502.52   dz: 489.87   misfit: 1.99e+01
# itreação: 426   r: 502.51   dz: 489.90   misfit: 1.99e+01
# itreação: 427   r: 502.50   dz: 489.93   misfit: 1.99e+01
# itreação: 428   r: 502.50   dz: 489.95   misfit: 1.99e+01
# itreação: 429   r: 502.49   dz: 489.98   misfit: 1.99e+01
# itreação: 430   r: 502.48   dz: 490.01   misfit: 1.99e+01
# itreação: 431   r: 502.48   dz: 490.04   misfit: 1.99e+01
# itreação: 432   r: 502.47   dz: 490.06   misfit: 1.99e+01
# itreação: 433   r: 502.46   dz: 490.09   misfit: 1.99e+01
# itreação: 434   r: 502.46   dz: 490.12   misfit: 1.99e+01
# itreação: 435   r: 502.45   dz: 490.14   misfit: 1.99e+01
# itreação: 436   r: 502.44   dz: 490.17   misfit: 1.99e+01
# itreação: 437   r: 502.44   dz: 490.19   misfit: 1.99e+01
# itreação: 438   r: 502.43   dz: 490.22   misfit: 1.99e+01
# itreação: 439   r: 502.42   dz: 490.25   misfit: 1.99e+01
# itreação: 440   r: 502.42   dz: 490.27   misfit: 1.99e+01
# itreação: 441   r: 502.41   dz: 490.30   misfit: 1.99e+01
# itreação: 442   r: 502.40   dz: 490.33   misfit: 1.99e+01
# itreação: 443   r: 502.40   dz: 490.35   misfit: 1.99e+01
# itreação: 444   r: 502.39   dz: 490.38   misfit: 1.99e+01
# itreação: 445   r: 502.38   dz: 490.40   misfit: 1.99e+01
# itreação: 446   r: 502.38   dz: 490.43   misfit: 1.99e+01
# itreação: 447   r: 502.37   dz: 490.45   misfit: 1.99e+01
# itreação: 448   r: 502.36   dz: 490.48   misfit: 1.99e+01
# itreação: 449   r: 502.36   dz: 490.50   misfit: 1.99e+01
# itreação: 450   r: 502.35   dz: 490.53   misfit: 1.99e+01
# itreação: 451   r: 502.34   dz: 490.56   misfit: 1.99e+01
# itreação: 452   r: 502.34   dz: 490.58   misfit: 1.98e+01
# itreação: 453   r: 502.33   dz: 490.61   misfit: 1.98e+01
# itreação: 454   r: 502.32   dz: 490.63   misfit: 1.98e+01
# itreação: 455   r: 502.32   dz: 490.66   misfit: 1.98e+01
# itreação: 456   r: 502.31   dz: 490.68   misfit: 1.98e+01
# itreação: 457   r: 502.31   dz: 490.71   misfit: 1.98e+01
# itreação: 458   r: 502.30   dz: 490.73   misfit: 1.98e+01
# itreação: 459   r: 502.29   dz: 490.75   misfit: 1.98e+01
# itreação: 460   r: 502.29   dz: 490.78   misfit: 1.98e+01
# itreação: 461   r: 502.28   dz: 490.80   misfit: 1.98e+01
# itreação: 462   r: 502.27   dz: 490.83   misfit: 1.98e+01
# itreação: 463   r: 502.27   dz: 490.85   misfit: 1.98e+01
# itreação: 464   r: 502.26   dz: 490.88   misfit: 1.98e+01
# itreação: 465   r: 502.25   dz: 490.90   misfit: 1.98e+01
# itreação: 466   r: 502.25   dz: 490.93   misfit: 1.98e+01
# itreação: 467   r: 502.24   dz: 490.95   misfit: 1.98e+01
# itreação: 468   r: 502.24   dz: 490.97   misfit: 1.98e+01
# itreação: 469   r: 502.23   dz: 491.00   misfit: 1.98e+01
# itreação: 470   r: 502.22   dz: 491.02   misfit: 1.98e+01
# itreação: 471   r: 502.22   dz: 491.04   misfit: 1.98e+01
# itreação: 472   r: 502.21   dz: 491.07   misfit: 1.98e+01
# itreação: 473   r: 502.21   dz: 491.09   misfit: 1.98e+01
# itreação: 474   r: 502.20   dz: 491.12   misfit: 1.98e+01
# itreação: 475   r: 502.19   dz: 491.14   misfit: 1.98e+01
# itreação: 476   r: 502.19   dz: 491.16   misfit: 1.98e+01
# itreação: 477   r: 502.18   dz: 491.19   misfit: 1.98e+01
# itreação: 478   r: 502.18   dz: 491.21   misfit: 1.98e+01
# itreação: 479   r: 502.17   dz: 491.23   misfit: 1.98e+01
# itreação: 480   r: 502.16   dz: 491.26   misfit: 1.98e+01
# itreação: 481   r: 502.16   dz: 491.28   misfit: 1.98e+01
# itreação: 482   r: 502.15   dz: 491.30   misfit: 1.98e+01
# itreação: 483   r: 502.15   dz: 491.32   misfit: 1.98e+01
# itreação: 484   r: 502.14   dz: 491.35   misfit: 1.98e+01
# itreação: 485   r: 502.13   dz: 491.37   misfit: 1.98e+01
# itreação: 486   r: 502.13   dz: 491.39   misfit: 1.98e+01
# itreação: 487   r: 502.12   dz: 491.42   misfit: 1.98e+01
# itreação: 488   r: 502.12   dz: 491.44   misfit: 1.98e+01
# itreação: 489   r: 502.11   dz: 491.46   misfit: 1.98e+01
# itreação: 490   r: 502.11   dz: 491.48   misfit: 1.98e+01
# itreação: 491   r: 502.10   dz: 491.51   misfit: 1.98e+01
# itreação: 492   r: 502.09   dz: 491.53   misfit: 1.98e+01
# itreação: 493   r: 502.09   dz: 491.55   misfit: 1.98e+01
# itreação: 494   r: 502.08   dz: 491.57   misfit: 1.98e+01
# itreação: 495   r: 502.08   dz: 491.59   misfit: 1.98e+01
# itreação: 496   r: 502.07   dz: 491.62   misfit: 1.98e+01
# itreação: 497   r: 502.07   dz: 491.64   misfit: 1.98e+01
# itreação: 498   r: 502.06   dz: 491.66   misfit: 1.98e+01
# itreação: 499   r: 502.05   dz: 491.68   misfit: 1.98e+01
# itreação: 500   r: 502.05   dz: 491.70   misfit: 1.98e+01
# itreação: 501   r: 502.04   dz: 491.73   misfit: 1.98e+01
# itreação: 502   r: 502.04   dz: 491.75   misfit: 1.98e+01
# itreação: 503   r: 502.03   dz: 491.77   misfit: 1.98e+01
# itreação: 504   r: 502.03   dz: 491.79   misfit: 1.98e+01
# itreação: 505   r: 502.02   dz: 491.81   misfit: 1.98e+01
# itreação: 506   r: 502.02   dz: 491.83   misfit: 1.98e+01
# itreação: 507   r: 502.01   dz: 491.85   misfit: 1.98e+01
# itreação: 508   r: 502.01   dz: 491.88   misfit: 1.98e+01
# itreação: 509   r: 502.00   dz: 491.90   misfit: 1.98e+01
# itreação: 510   r: 501.99   dz: 491.92   misfit: 1.98e+01
# itreação: 511   r: 501.99   dz: 491.94   misfit: 1.98e+01
# itreação: 512   r: 501.98   dz: 491.96   misfit: 1.98e+01
# itreação: 513   r: 501.98   dz: 491.98   misfit: 1.98e+01
# itreação: 514   r: 501.97   dz: 492.00   misfit: 1.98e+01
# itreação: 515   r: 501.97   dz: 492.02   misfit: 1.98e+01
# itreação: 516   r: 501.96   dz: 492.04   misfit: 1.98e+01
# itreação: 517   r: 501.96   dz: 492.06   misfit: 1.98e+01
# itreação: 518   r: 501.95   dz: 492.09   misfit: 1.98e+01
# itreação: 519   r: 501.95   dz: 492.11   misfit: 1.98e+01
# itreação: 520   r: 501.94   dz: 492.13   misfit: 1.98e+01
# itreação: 521   r: 501.94   dz: 492.15   misfit: 1.98e+01
# itreação: 522   r: 501.93   dz: 492.17   misfit: 1.98e+01
# itreação: 523   r: 501.93   dz: 492.19   misfit: 1.98e+01
# itreação: 524   r: 501.92   dz: 492.21   misfit: 1.98e+01
# itreação: 525   r: 501.92   dz: 492.23   misfit: 1.98e+01
# itreação: 526   r: 501.91   dz: 492.25   misfit: 1.98e+01
# itreação: 527   r: 501.91   dz: 492.27   misfit: 1.98e+01
# itreação: 528   r: 501.90   dz: 492.29   misfit: 1.98e+01
# itreação: 529   r: 501.89   dz: 492.31   misfit: 1.98e+01
# itreação: 530   r: 501.89   dz: 492.33   misfit: 1.98e+01
# itreação: 531   r: 501.88   dz: 492.35   misfit: 1.98e+01
# itreação: 532   r: 501.88   dz: 492.37   misfit: 1.98e+01
# itreação: 533   r: 501.87   dz: 492.39   misfit: 1.98e+01
# itreação: 534   r: 501.87   dz: 492.41   misfit: 1.98e+01
# itreação: 535   r: 501.86   dz: 492.43   misfit: 1.98e+01
# itreação: 536   r: 501.86   dz: 492.45   misfit: 1.98e+01
# itreação: 537   r: 501.85   dz: 492.47   misfit: 1.98e+01
# itreação: 538   r: 501.85   dz: 492.49   misfit: 1.98e+01
# itreação: 539   r: 501.84   dz: 492.51   misfit: 1.98e+01
# itreação: 540   r: 501.84   dz: 492.52   misfit: 1.98e+01
# itreação: 541   r: 501.83   dz: 492.54   misfit: 1.98e+01
# itreação: 542   r: 501.83   dz: 492.56   misfit: 1.98e+01
# itreação: 543   r: 501.83   dz: 492.58   misfit: 1.98e+01
# itreação: 544   r: 501.82   dz: 492.60   misfit: 1.98e+01
# itreação: 545   r: 501.82   dz: 492.62   misfit: 1.98e+01
# itreação: 546   r: 501.81   dz: 492.64   misfit: 1.98e+01
# itreação: 547   r: 501.81   dz: 492.66   misfit: 1.98e+01
# itreação: 548   r: 501.80   dz: 492.68   misfit: 1.98e+01
# itreação: 549   r: 501.80   dz: 492.70   misfit: 1.98e+01
# itreação: 550   r: 501.79   dz: 492.71   misfit: 1.98e+01
# itreação: 551   r: 501.79   dz: 492.73   misfit: 1.98e+01
# itreação: 552   r: 501.78   dz: 492.75   misfit: 1.98e+01
# itreação: 553   r: 501.78   dz: 492.77   misfit: 1.98e+01
# itreação: 554   r: 501.77   dz: 492.79   misfit: 1.98e+01
# itreação: 555   r: 501.77   dz: 492.81   misfit: 1.98e+01
# itreação: 556   r: 501.76   dz: 492.83   misfit: 1.98e+01
# itreação: 557   r: 501.76   dz: 492.84   misfit: 1.98e+01
# itreação: 558   r: 501.75   dz: 492.86   misfit: 1.98e+01
# itreação: 559   r: 501.75   dz: 492.88   misfit: 1.98e+01
# itreação: 560   r: 501.74   dz: 492.90   misfit: 1.98e+01
# itreação: 561   r: 501.74   dz: 492.92   misfit: 1.98e+01
# itreação: 562   r: 501.73   dz: 492.94   misfit: 1.98e+01
# itreação: 563   r: 501.73   dz: 492.95   misfit: 1.98e+01
# itreação: 564   r: 501.73   dz: 492.97   misfit: 1.98e+01
# itreação: 565   r: 501.72   dz: 492.99   misfit: 1.98e+01
# itreação: 566   r: 501.72   dz: 493.01   misfit: 1.98e+01
# itreação: 567   r: 501.71   dz: 493.03   misfit: 1.98e+01
# itreação: 568   r: 501.71   dz: 493.04   misfit: 1.98e+01
# itreação: 569   r: 501.70   dz: 493.06   misfit: 1.98e+01
# itreação: 570   r: 501.70   dz: 493.08   misfit: 1.98e+01
# itreação: 571   r: 501.69   dz: 493.10   misfit: 1.98e+01
# itreação: 572   r: 501.69   dz: 493.11   misfit: 1.98e+01
# itreação: 573   r: 501.68   dz: 493.13   misfit: 1.98e+01
# itreação: 574   r: 501.68   dz: 493.15   misfit: 1.98e+01
# itreação: 575   r: 501.68   dz: 493.17   misfit: 1.98e+01
# itreação: 576   r: 501.67   dz: 493.18   misfit: 1.98e+01
# itreação: 577   r: 501.67   dz: 493.20   misfit: 1.98e+01
# itreação: 578   r: 501.66   dz: 493.22   misfit: 1.98e+01
# itreação: 579   r: 501.66   dz: 493.24   misfit: 1.98e+01
# itreação: 580   r: 501.65   dz: 493.25   misfit: 1.98e+01
# itreação: 581   r: 501.65   dz: 493.27   misfit: 1.98e+01
# itreação: 582   r: 501.65   dz: 493.29   misfit: 1.98e+01
# itreação: 583   r: 501.64   dz: 493.30   misfit: 1.98e+01
# itreação: 584   r: 501.64   dz: 493.32   misfit: 1.98e+01
# itreação: 585   r: 501.63   dz: 493.34   misfit: 1.98e+01
# itreação: 586   r: 501.63   dz: 493.36   misfit: 1.98e+01
# itreação: 587   r: 501.62   dz: 493.37   misfit: 1.98e+01
# itreação: 588   r: 501.62   dz: 493.39   misfit: 1.98e+01
# itreação: 589   r: 501.62   dz: 493.41   misfit: 1.98e+01
# itreação: 590   r: 501.61   dz: 493.42   misfit: 1.98e+01
# itreação: 591   r: 501.61   dz: 493.44   misfit: 1.98e+01
# itreação: 592   r: 501.60   dz: 493.46   misfit: 1.98e+01
# itreação: 593   r: 501.60   dz: 493.47   misfit: 1.98e+01
# itreação: 594   r: 501.59   dz: 493.49   misfit: 1.98e+01
# itreação: 595   r: 501.59   dz: 493.51   misfit: 1.98e+01
# itreação: 596   r: 501.59   dz: 493.52   misfit: 1.98e+01
# itreação: 597   r: 501.58   dz: 493.54   misfit: 1.98e+01
# itreação: 598   r: 501.58   dz: 493.55   misfit: 1.98e+01
# itreação: 599   r: 501.57   dz: 493.57   misfit: 1.98e+01
# itreação: 600   r: 501.57   dz: 493.59   misfit: 1.98e+01
# itreação: 601   r: 501.56   dz: 493.60   misfit: 1.98e+01
# itreação: 602   r: 501.56   dz: 493.62   misfit: 1.98e+01
# itreação: 603   r: 501.56   dz: 493.64   misfit: 1.98e+01
# itreação: 604   r: 501.55   dz: 493.65   misfit: 1.98e+01
# itreação: 605   r: 501.55   dz: 493.67   misfit: 1.98e+01
# itreação: 606   r: 501.54   dz: 493.68   misfit: 1.98e+01
# itreação: 607   r: 501.54   dz: 493.70   misfit: 1.98e+01
# itreação: 608   r: 501.54   dz: 493.72   misfit: 1.98e+01
# itreação: 609   r: 501.53   dz: 493.73   misfit: 1.98e+01
# itreação: 610   r: 501.53   dz: 493.75   misfit: 1.98e+01
# itreação: 611   r: 501.52   dz: 493.76   misfit: 1.98e+01
# itreação: 612   r: 501.52   dz: 493.78   misfit: 1.98e+01
# itreação: 613   r: 501.52   dz: 493.79   misfit: 1.98e+01
# itreação: 614   r: 501.51   dz: 493.81   misfit: 1.98e+01
# itreação: 615   r: 501.51   dz: 493.83   misfit: 1.98e+01
# itreação: 616   r: 501.50   dz: 493.84   misfit: 1.98e+01
# itreação: 617   r: 501.50   dz: 493.86   misfit: 1.98e+01
# itreação: 618   r: 501.50   dz: 493.87   misfit: 1.98e+01
# itreação: 619   r: 501.49   dz: 493.89   misfit: 1.98e+01
# itreação: 620   r: 501.49   dz: 493.90   misfit: 1.98e+01
# itreação: 621   r: 501.49   dz: 493.92   misfit: 1.98e+01
# itreação: 622   r: 501.48   dz: 493.93   misfit: 1.98e+01
# itreação: 623   r: 501.48   dz: 493.95   misfit: 1.98e+01
# itreação: 624   r: 501.47   dz: 493.96   misfit: 1.98e+01
# itreação: 625   r: 501.47   dz: 493.98   misfit: 1.98e+01
# itreação: 626   r: 501.47   dz: 493.99   misfit: 1.98e+01
# itreação: 627   r: 501.46   dz: 494.01   misfit: 1.98e+01
# itreação: 628   r: 501.46   dz: 494.02   misfit: 1.98e+01
# itreação: 629   r: 501.45   dz: 494.04   misfit: 1.98e+01
# itreação: 630   r: 501.45   dz: 494.05   misfit: 1.98e+01
# itreação: 631   r: 501.45   dz: 494.07   misfit: 1.98e+01
# itreação: 632   r: 501.44   dz: 494.08   misfit: 1.98e+01
# itreação: 633   r: 501.44   dz: 494.10   misfit: 1.98e+01
# itreação: 634   r: 501.44   dz: 494.11   misfit: 1.98e+01
# itreação: 635   r: 501.43   dz: 494.13   misfit: 1.98e+01
# itreação: 636   r: 501.43   dz: 494.14   misfit: 1.98e+01
# itreação: 637   r: 501.42   dz: 494.16   misfit: 1.98e+01
# itreação: 638   r: 501.42   dz: 494.17   misfit: 1.98e+01
# itreação: 639   r: 501.42   dz: 494.18   misfit: 1.98e+01
# itreação: 640   r: 501.41   dz: 494.20   misfit: 1.98e+01
# itreação: 641   r: 501.41   dz: 494.21   misfit: 1.98e+01
# itreação: 642   r: 501.41   dz: 494.23   misfit: 1.98e+01
# itreação: 643   r: 501.40   dz: 494.24   misfit: 1.98e+01
# itreação: 644   r: 501.40   dz: 494.26   misfit: 1.98e+01
# itreação: 645   r: 501.40   dz: 494.27   misfit: 1.98e+01
# itreação: 646   r: 501.39   dz: 494.29   misfit: 1.98e+01
# itreação: 647   r: 501.39   dz: 494.30   misfit: 1.98e+01
# itreação: 648   r: 501.38   dz: 494.31   misfit: 1.98e+01
# itreação: 649   r: 501.38   dz: 494.33   misfit: 1.98e+01
# itreação: 650   r: 501.38   dz: 494.34   misfit: 1.98e+01
# itreação: 651   r: 501.37   dz: 494.36   misfit: 1.98e+01
# itreação: 652   r: 501.37   dz: 494.37   misfit: 1.98e+01
# itreação: 653   r: 501.37   dz: 494.38   misfit: 1.98e+01
# itreação: 654   r: 501.36   dz: 494.40   misfit: 1.98e+01
# itreação: 655   r: 501.36   dz: 494.41   misfit: 1.98e+01
# itreação: 656   r: 501.36   dz: 494.43   misfit: 1.98e+01
# itreação: 657   r: 501.35   dz: 494.44   misfit: 1.98e+01
# itreação: 658   r: 501.35   dz: 494.45   misfit: 1.98e+01
# itreação: 659   r: 501.35   dz: 494.47   misfit: 1.98e+01
# itreação: 660   r: 501.34   dz: 494.48   misfit: 1.98e+01
# itreação: 661   r: 501.34   dz: 494.49   misfit: 1.98e+01
# itreação: 662   r: 501.34   dz: 494.51   misfit: 1.98e+01
# itreação: 663   r: 501.33   dz: 494.52   misfit: 1.98e+01
# itreação: 664   r: 501.33   dz: 494.53   misfit: 1.98e+01
# itreação: 665   r: 501.33   dz: 494.55   misfit: 1.98e+01
# itreação: 666   r: 501.32   dz: 494.56   misfit: 1.98e+01
# itreação: 667   r: 501.32   dz: 494.57   misfit: 1.98e+01
# itreação: 668   r: 501.32   dz: 494.59   misfit: 1.98e+01
# itreação: 669   r: 501.31   dz: 494.60   misfit: 1.98e+01
# itreação: 670   r: 501.31   dz: 494.61   misfit: 1.98e+01
# itreação: 671   r: 501.30   dz: 494.63   misfit: 1.98e+01
# itreação: 672   r: 501.30   dz: 494.64   misfit: 1.98e+01
# itreação: 673   r: 501.30   dz: 494.65   misfit: 1.98e+01
# itreação: 674   r: 501.29   dz: 494.67   misfit: 1.98e+01
# itreação: 675   r: 501.29   dz: 494.68   misfit: 1.98e+01
# itreação: 676   r: 501.29   dz: 494.69   misfit: 1.98e+01
# itreação: 677   r: 501.29   dz: 494.71   misfit: 1.98e+01
# itreação: 678   r: 501.28   dz: 494.72   misfit: 1.98e+01
# itreação: 679   r: 501.28   dz: 494.73   misfit: 1.98e+01
# itreação: 680   r: 501.28   dz: 494.74   misfit: 1.98e+01
# itreação: 681   r: 501.27   dz: 494.76   misfit: 1.98e+01
# itreação: 682   r: 501.27   dz: 494.77   misfit: 1.98e+01
# itreação: 683   r: 501.27   dz: 494.78   misfit: 1.98e+01
# itreação: 684   r: 501.26   dz: 494.80   misfit: 1.98e+01
# itreação: 685   r: 501.26   dz: 494.81   misfit: 1.98e+01
# itreação: 686   r: 501.26   dz: 494.82   misfit: 1.98e+01
# itreação: 687   r: 501.25   dz: 494.83   misfit: 1.98e+01
# itreação: 688   r: 501.25   dz: 494.85   misfit: 1.98e+01
# itreação: 689   r: 501.25   dz: 494.86   misfit: 1.98e+01
# itreação: 690   r: 501.24   dz: 494.87   misfit: 1.98e+01
# itreação: 691   r: 501.24   dz: 494.88   misfit: 1.98e+01
# itreação: 692   r: 501.24   dz: 494.90   misfit: 1.98e+01
# itreação: 693   r: 501.23   dz: 494.91   misfit: 1.98e+01
# itreação: 694   r: 501.23   dz: 494.92   misfit: 1.98e+01
# itreação: 695   r: 501.23   dz: 494.93   misfit: 1.98e+01
# itreação: 696   r: 501.22   dz: 494.95   misfit: 1.98e+01
# itreação: 697   r: 501.22   dz: 494.96   misfit: 1.98e+01
# itreação: 698   r: 501.22   dz: 494.97   misfit: 1.98e+01
# itreação: 699   r: 501.22   dz: 494.98   misfit: 1.98e+01
# itreação: 700   r: 501.21   dz: 494.99   misfit: 1.98e+01
# itreação: 701   r: 501.21   dz: 495.01   misfit: 1.98e+01
# itreação: 702   r: 501.21   dz: 495.02   misfit: 1.98e+01
# itreação: 703   r: 501.20   dz: 495.03   misfit: 1.98e+01
# itreação: 704   r: 501.20   dz: 495.04   misfit: 1.98e+01
# itreação: 705   r: 501.20   dz: 495.05   misfit: 1.98e+01
# itreação: 706   r: 501.19   dz: 495.07   misfit: 1.98e+01
# itreação: 707   r: 501.19   dz: 495.08   misfit: 1.98e+01
# itreação: 708   r: 501.19   dz: 495.09   misfit: 1.98e+01
# itreação: 709   r: 501.18   dz: 495.10   misfit: 1.98e+01
# itreação: 710   r: 501.18   dz: 495.11   misfit: 1.98e+01
# itreação: 711   r: 501.18   dz: 495.13   misfit: 1.98e+01
# itreação: 712   r: 501.18   dz: 495.14   misfit: 1.98e+01
# itreação: 713   r: 501.17   dz: 495.15   misfit: 1.98e+01
# itreação: 714   r: 501.17   dz: 495.16   misfit: 1.98e+01
# itreação: 715   r: 501.17   dz: 495.17   misfit: 1.98e+01
# itreação: 716   r: 501.16   dz: 495.18   misfit: 1.98e+01
# itreação: 717   r: 501.16   dz: 495.20   misfit: 1.98e+01
# itreação: 718   r: 501.16   dz: 495.21   misfit: 1.98e+01
# itreação: 719   r: 501.16   dz: 495.22   misfit: 1.98e+01
# itreação: 720   r: 501.15   dz: 495.23   misfit: 1.98e+01
# itreação: 721   r: 501.15   dz: 495.24   misfit: 1.98e+01
# itreação: 722   r: 501.15   dz: 495.25   misfit: 1.98e+01
# itreação: 723   r: 501.14   dz: 495.26   misfit: 1.98e+01
# itreação: 724   r: 501.14   dz: 495.28   misfit: 1.98e+01
# itreação: 725   r: 501.14   dz: 495.29   misfit: 1.98e+01
# itreação: 726   r: 501.13   dz: 495.30   misfit: 1.98e+01
# itreação: 727   r: 501.13   dz: 495.31   misfit: 1.98e+01
# itreação: 728   r: 501.13   dz: 495.32   misfit: 1.98e+01
# itreação: 729   r: 501.13   dz: 495.33   misfit: 1.98e+01
# itreação: 730   r: 501.12   dz: 495.34   misfit: 1.98e+01
# itreação: 731   r: 501.12   dz: 495.35   misfit: 1.98e+01
# itreação: 732   r: 501.12   dz: 495.37   misfit: 1.98e+01
# itreação: 733   r: 501.12   dz: 495.38   misfit: 1.98e+01
# itreação: 734   r: 501.11   dz: 495.39   misfit: 1.98e+01
# itreação: 735   r: 501.11   dz: 495.40   misfit: 1.98e+01
# itreação: 736   r: 501.11   dz: 495.41   misfit: 1.98e+01
# itreação: 737   r: 501.10   dz: 495.42   misfit: 1.98e+01
# itreação: 738   r: 501.10   dz: 495.43   misfit: 1.98e+01
# itreação: 739   r: 501.10   dz: 495.44   misfit: 1.98e+01
# itreação: 740   r: 501.10   dz: 495.45   misfit: 1.98e+01
# itreação: 741   r: 501.09   dz: 495.46   misfit: 1.98e+01
# itreação: 742   r: 501.09   dz: 495.48   misfit: 1.98e+01
# itreação: 743   r: 501.09   dz: 495.49   misfit: 1.98e+01
# itreação: 744   r: 501.08   dz: 495.50   misfit: 1.98e+01
# itreação: 745   r: 501.08   dz: 495.51   misfit: 1.98e+01
# itreação: 746   r: 501.08   dz: 495.52   misfit: 1.98e+01
# itreação: 747   r: 501.08   dz: 495.53   misfit: 1.98e+01
# itreação: 748   r: 501.07   dz: 495.54   misfit: 1.98e+01
# itreação: 749   r: 501.07   dz: 495.55   misfit: 1.98e+01
# itreação: 750   r: 501.07   dz: 495.56   misfit: 1.98e+01
# itreação: 751   r: 501.07   dz: 495.57   misfit: 1.98e+01
# itreação: 752   r: 501.06   dz: 495.58   misfit: 1.98e+01
# itreação: 753   r: 501.06   dz: 495.59   misfit: 1.98e+01
# itreação: 754   r: 501.06   dz: 495.60   misfit: 1.98e+01
# itreação: 755   r: 501.06   dz: 495.61   misfit: 1.98e+01
# itreação: 756   r: 501.05   dz: 495.62   misfit: 1.98e+01
# itreação: 757   r: 501.05   dz: 495.63   misfit: 1.98e+01
# itreação: 758   r: 501.05   dz: 495.64   misfit: 1.98e+01
# itreação: 759   r: 501.05   dz: 495.65   misfit: 1.98e+01
# itreação: 760   r: 501.04   dz: 495.66   misfit: 1.98e+01
# itreação: 761   r: 501.04   dz: 495.67   misfit: 1.98e+01
# itreação: 762   r: 501.04   dz: 495.68   misfit: 1.98e+01
# itreação: 763   r: 501.03   dz: 495.69   misfit: 1.98e+01
# itreação: 764   r: 501.03   dz: 495.71   misfit: 1.98e+01
# itreação: 765   r: 501.03   dz: 495.72   misfit: 1.98e+01
# itreação: 766   r: 501.03   dz: 495.73   misfit: 1.98e+01
# itreação: 767   r: 501.02   dz: 495.74   misfit: 1.98e+01
# itreação: 768   r: 501.02   dz: 495.75   misfit: 1.98e+01
# itreação: 769   r: 501.02   dz: 495.76   misfit: 1.98e+01
# itreação: 770   r: 501.02   dz: 495.77   misfit: 1.98e+01
# itreação: 771   r: 501.01   dz: 495.78   misfit: 1.98e+01
# itreação: 772   r: 501.01   dz: 495.79   misfit: 1.98e+01
# itreação: 773   r: 501.01   dz: 495.80   misfit: 1.98e+01
# itreação: 774   r: 501.01   dz: 495.80   misfit: 1.98e+01
# itreação: 775   r: 501.00   dz: 495.81   misfit: 1.98e+01
# itreação: 776   r: 501.00   dz: 495.82   misfit: 1.98e+01
# itreação: 777   r: 501.00   dz: 495.83   misfit: 1.98e+01
# itreação: 778   r: 501.00   dz: 495.84   misfit: 1.98e+01
# itreação: 779   r: 500.99   dz: 495.85   misfit: 1.98e+01
# itreação: 780   r: 500.99   dz: 495.86   misfit: 1.98e+01
# itreação: 781   r: 500.99   dz: 495.87   misfit: 1.98e+01
# itreação: 782   r: 500.99   dz: 495.88   misfit: 1.98e+01
# itreação: 783   r: 500.98   dz: 495.89   misfit: 1.98e+01
# itreação: 784   r: 500.98   dz: 495.90   misfit: 1.98e+01
# itreação: 785   r: 500.98   dz: 495.91   misfit: 1.98e+01
# itreação: 786   r: 500.98   dz: 495.92   misfit: 1.98e+01
# itreação: 787   r: 500.98   dz: 495.93   misfit: 1.98e+01
# itreação: 788   r: 500.97   dz: 495.94   misfit: 1.98e+01
# itreação: 789   r: 500.97   dz: 495.95   misfit: 1.98e+01
# itreação: 790   r: 500.97   dz: 495.96   misfit: 1.98e+01
# itreação: 791   r: 500.97   dz: 495.97   misfit: 1.98e+01
# itreação: 792   r: 500.96   dz: 495.98   misfit: 1.98e+01
# itreação: 793   r: 500.96   dz: 495.99   misfit: 1.98e+01
# itreação: 794   r: 500.96   dz: 496.00   misfit: 1.98e+01
# itreação: 795   r: 500.96   dz: 496.01   misfit: 1.98e+01
# itreação: 796   r: 500.95   dz: 496.01   misfit: 1.98e+01
# itreação: 797   r: 500.95   dz: 496.02   misfit: 1.98e+01
# itreação: 798   r: 500.95   dz: 496.03   misfit: 1.98e+01
# itreação: 799   r: 500.95   dz: 496.04   misfit: 1.98e+01
# itreação: 800   r: 500.94   dz: 496.05   misfit: 1.98e+01
# itreação: 801   r: 500.94   dz: 496.06   misfit: 1.98e+01
# itreação: 802   r: 500.94   dz: 496.07   misfit: 1.98e+01
# itreação: 803   r: 500.94   dz: 496.08   misfit: 1.98e+01
# itreação: 804   r: 500.94   dz: 496.09   misfit: 1.98e+01
# itreação: 805   r: 500.93   dz: 496.10   misfit: 1.98e+01
# itreação: 806   r: 500.93   dz: 496.11   misfit: 1.98e+01
# itreação: 807   r: 500.93   dz: 496.11   misfit: 1.98e+01
# itreação: 808   r: 500.93   dz: 496.12   misfit: 1.98e+01
# itreação: 809   r: 500.92   dz: 496.13   misfit: 1.98e+01
# itreação: 810   r: 500.92   dz: 496.14   misfit: 1.98e+01
# itreação: 811   r: 500.92   dz: 496.15   misfit: 1.98e+01
# itreação: 812   r: 500.92   dz: 496.16   misfit: 1.98e+01
# itreação: 813   r: 500.92   dz: 496.17   misfit: 1.98e+01
# itreação: 814   r: 500.91   dz: 496.18   misfit: 1.98e+01
# itreação: 815   r: 500.91   dz: 496.19   misfit: 1.98e+01
# itreação: 816   r: 500.91   dz: 496.19   misfit: 1.98e+01
# itreação: 817   r: 500.91   dz: 496.20   misfit: 1.98e+01
# itreação: 818   r: 500.90   dz: 496.21   misfit: 1.98e+01
# itreação: 819   r: 500.90   dz: 496.22   misfit: 1.98e+01
# itreação: 820   r: 500.90   dz: 496.23   misfit: 1.98e+01
# itreação: 821   r: 500.90   dz: 496.24   misfit: 1.98e+01
# itreação: 822   r: 500.90   dz: 496.25   misfit: 1.98e+01
# itreação: 823   r: 500.89   dz: 496.26   misfit: 1.98e+01
# itreação: 824   r: 500.89   dz: 496.26   misfit: 1.98e+01
# itreação: 825   r: 500.89   dz: 496.27   misfit: 1.97e+01
# itreação: 826   r: 500.89   dz: 496.28   misfit: 1.97e+01
# itreação: 827   r: 500.88   dz: 496.29   misfit: 1.97e+01
# itreação: 828   r: 500.88   dz: 496.30   misfit: 1.97e+01
# itreação: 829   r: 500.88   dz: 496.31   misfit: 1.97e+01
# itreação: 830   r: 500.88   dz: 496.31   misfit: 1.97e+01
# itreação: 831   r: 500.88   dz: 496.32   misfit: 1.97e+01
# itreação: 832   r: 500.87   dz: 496.33   misfit: 1.97e+01
# itreação: 833   r: 500.87   dz: 496.34   misfit: 1.97e+01
# itreação: 834   r: 500.87   dz: 496.35   misfit: 1.97e+01
# itreação: 835   r: 500.87   dz: 496.36   misfit: 1.97e+01
# itreação: 836   r: 500.87   dz: 496.36   misfit: 1.97e+01
# itreação: 837   r: 500.86   dz: 496.37   misfit: 1.97e+01
# itreação: 838   r: 500.86   dz: 496.38   misfit: 1.97e+01
# itreação: 839   r: 500.86   dz: 496.39   misfit: 1.97e+01
# itreação: 840   r: 500.86   dz: 496.40   misfit: 1.97e+01
# itreação: 841   r: 500.86   dz: 496.41   misfit: 1.97e+01
# itreação: 842   r: 500.85   dz: 496.41   misfit: 1.97e+01
# itreação: 843   r: 500.85   dz: 496.42   misfit: 1.97e+01
# itreação: 844   r: 500.85   dz: 496.43   misfit: 1.97e+01
# itreação: 845   r: 500.85   dz: 496.44   misfit: 1.97e+01
# itreação: 846   r: 500.85   dz: 496.45   misfit: 1.97e+01
# itreação: 847   r: 500.84   dz: 496.45   misfit: 1.97e+01
# itreação: 848   r: 500.84   dz: 496.46   misfit: 1.97e+01
# itreação: 849   r: 500.84   dz: 496.47   misfit: 1.97e+01
# itreação: 850   r: 500.84   dz: 496.48   misfit: 1.97e+01
# itreação: 851   r: 500.84   dz: 496.49   misfit: 1.97e+01
# itreação: 852   r: 500.83   dz: 496.49   misfit: 1.97e+01
# itreação: 853   r: 500.83   dz: 496.50   misfit: 1.97e+01
# itreação: 854   r: 500.83   dz: 496.51   misfit: 1.97e+01
# itreação: 855   r: 500.83   dz: 496.52   misfit: 1.97e+01
# itreação: 856   r: 500.83   dz: 496.53   misfit: 1.97e+01
# itreação: 857   r: 500.82   dz: 496.53   misfit: 1.97e+01
# itreação: 858   r: 500.82   dz: 496.54   misfit: 1.97e+01
# itreação: 859   r: 500.82   dz: 496.55   misfit: 1.97e+01
# itreação: 860   r: 500.82   dz: 496.56   misfit: 1.97e+01
# itreação: 861   r: 500.82   dz: 496.56   misfit: 1.97e+01
# itreação: 862   r: 500.81   dz: 496.57   misfit: 1.97e+01
# itreação: 863   r: 500.81   dz: 496.58   misfit: 1.97e+01
# itreação: 864   r: 500.81   dz: 496.59   misfit: 1.97e+01
# itreação: 865   r: 500.81   dz: 496.59   misfit: 1.97e+01
# itreação: 866   r: 500.81   dz: 496.60   misfit: 1.97e+01
# itreação: 867   r: 500.80   dz: 496.61   misfit: 1.97e+01
# itreação: 868   r: 500.80   dz: 496.62   misfit: 1.97e+01
# itreação: 869   r: 500.80   dz: 496.62   misfit: 1.97e+01
# itreação: 870   r: 500.80   dz: 496.63   misfit: 1.97e+01
# itreação: 871   r: 500.80   dz: 496.64   misfit: 1.97e+01
# itreação: 872   r: 500.79   dz: 496.65   misfit: 1.97e+01
# itreação: 873   r: 500.79   dz: 496.65   misfit: 1.97e+01
# itreação: 874   r: 500.79   dz: 496.66   misfit: 1.97e+01
# itreação: 875   r: 500.79   dz: 496.67   misfit: 1.97e+01
# itreação: 876   r: 500.79   dz: 496.68   misfit: 1.97e+01
# itreação: 877   r: 500.79   dz: 496.68   misfit: 1.97e+01
# itreação: 878   r: 500.78   dz: 496.69   misfit: 1.97e+01
# itreação: 879   r: 500.78   dz: 496.70   misfit: 1.97e+01
# itreação: 880   r: 500.78   dz: 496.71   misfit: 1.97e+01
# itreação: 881   r: 500.78   dz: 496.71   misfit: 1.97e+01
# itreação: 882   r: 500.78   dz: 496.72   misfit: 1.97e+01
# itreação: 883   r: 500.77   dz: 496.73   misfit: 1.97e+01
# itreação: 884   r: 500.77   dz: 496.74   misfit: 1.97e+01
# itreação: 885   r: 500.77   dz: 496.74   misfit: 1.97e+01
# itreação: 886   r: 500.77   dz: 496.75   misfit: 1.97e+01
# itreação: 887   r: 500.77   dz: 496.76   misfit: 1.97e+01
# itreação: 888   r: 500.77   dz: 496.76   misfit: 1.97e+01
# itreação: 889   r: 500.76   dz: 496.77   misfit: 1.97e+01
# itreação: 890   r: 500.76   dz: 496.78   misfit: 1.97e+01
# itreação: 891   r: 500.76   dz: 496.79   misfit: 1.97e+01
# itreação: 892   r: 500.76   dz: 496.79   misfit: 1.97e+01
# itreação: 893   r: 500.76   dz: 496.80   misfit: 1.97e+01
# itreação: 894   r: 500.75   dz: 496.81   misfit: 1.97e+01
# itreação: 895   r: 500.75   dz: 496.81   misfit: 1.97e+01
# itreação: 896   r: 500.75   dz: 496.82   misfit: 1.97e+01
# itreação: 897   r: 500.75   dz: 496.83   misfit: 1.97e+01
# itreação: 898   r: 500.75   dz: 496.83   misfit: 1.97e+01
# itreação: 899   r: 500.75   dz: 496.84   misfit: 1.97e+01
# itreação: 900   r: 500.74   dz: 496.85   misfit: 1.97e+01
# itreação: 901   r: 500.74   dz: 496.86   misfit: 1.97e+01
# itreação: 902   r: 500.74   dz: 496.86   misfit: 1.97e+01
# itreação: 903   r: 500.74   dz: 496.87   misfit: 1.97e+01
# itreação: 904   r: 500.74   dz: 496.88   misfit: 1.97e+01
# itreação: 905   r: 500.74   dz: 496.88   misfit: 1.97e+01
# itreação: 906   r: 500.73   dz: 496.89   misfit: 1.97e+01
# itreação: 907   r: 500.73   dz: 496.90   misfit: 1.97e+01
# itreação: 908   r: 500.73   dz: 496.90   misfit: 1.97e+01
# itreação: 909   r: 500.73   dz: 496.91   misfit: 1.97e+01
# itreação: 910   r: 500.73   dz: 496.92   misfit: 1.97e+01
# itreação: 911   r: 500.73   dz: 496.92   misfit: 1.97e+01
# itreação: 912   r: 500.72   dz: 496.93   misfit: 1.97e+01
# itreação: 913   r: 500.72   dz: 496.94   misfit: 1.97e+01
# itreação: 914   r: 500.72   dz: 496.94   misfit: 1.97e+01
# itreação: 915   r: 500.72   dz: 496.95   misfit: 1.97e+01
# itreação: 916   r: 500.72   dz: 496.96   misfit: 1.97e+01
# itreação: 917   r: 500.71   dz: 496.96   misfit: 1.97e+01
# itreação: 918   r: 500.71   dz: 496.97   misfit: 1.97e+01
# itreação: 919   r: 500.71   dz: 496.98   misfit: 1.97e+01
# itreação: 920   r: 500.71   dz: 496.98   misfit: 1.97e+01
# itreação: 921   r: 500.71   dz: 496.99   misfit: 1.97e+01
# itreação: 922   r: 500.71   dz: 497.00   misfit: 1.97e+01
# itreação: 923   r: 500.71   dz: 497.00   misfit: 1.97e+01
# itreação: 924   r: 500.70   dz: 497.01   misfit: 1.97e+01
# itreação: 925   r: 500.70   dz: 497.02   misfit: 1.97e+01
# itreação: 926   r: 500.70   dz: 497.02   misfit: 1.97e+01
# itreação: 927   r: 500.70   dz: 497.03   misfit: 1.97e+01
# itreação: 928   r: 500.70   dz: 497.03   misfit: 1.97e+01
# itreação: 929   r: 500.70   dz: 497.04   misfit: 1.97e+01
# itreação: 930   r: 500.69   dz: 497.05   misfit: 1.97e+01
# itreação: 931   r: 500.69   dz: 497.05   misfit: 1.97e+01
# itreação: 932   r: 500.69   dz: 497.06   misfit: 1.97e+01
# itreação: 933   r: 500.69   dz: 497.07   misfit: 1.97e+01
# itreação: 934   r: 500.69   dz: 497.07   misfit: 1.97e+01
# itreação: 935   r: 500.69   dz: 497.08   misfit: 1.97e+01
# itreação: 936   r: 500.68   dz: 497.08   misfit: 1.97e+01
# itreação: 937   r: 500.68   dz: 497.09   misfit: 1.97e+01
# itreação: 938   r: 500.68   dz: 497.10   misfit: 1.97e+01
# itreação: 939   r: 500.68   dz: 497.10   misfit: 1.97e+01
# itreação: 940   r: 500.68   dz: 497.11   misfit: 1.97e+01
# itreação: 941   r: 500.68   dz: 497.12   misfit: 1.97e+01
# itreação: 942   r: 500.67   dz: 497.12   misfit: 1.97e+01
# itreação: 943   r: 500.67   dz: 497.13   misfit: 1.97e+01
# itreação: 944   r: 500.67   dz: 497.13   misfit: 1.97e+01
# itreação: 945   r: 500.67   dz: 497.14   misfit: 1.97e+01
# itreação: 946   r: 500.67   dz: 497.15   misfit: 1.97e+01
# itreação: 947   r: 500.67   dz: 497.15   misfit: 1.97e+01
# itreação: 948   r: 500.67   dz: 497.16   misfit: 1.97e+01
# itreação: 949   r: 500.66   dz: 497.16   misfit: 1.97e+01
# itreação: 950   r: 500.66   dz: 497.17   misfit: 1.97e+01
# itreação: 951   r: 500.66   dz: 497.18   misfit: 1.97e+01
# itreação: 952   r: 500.66   dz: 497.18   misfit: 1.97e+01
# itreação: 953   r: 500.66   dz: 497.19   misfit: 1.97e+01
# itreação: 954   r: 500.66   dz: 497.19   misfit: 1.97e+01
# itreação: 955   r: 500.66   dz: 497.20   misfit: 1.97e+01
# itreação: 956   r: 500.65   dz: 497.21   misfit: 1.97e+01
# itreação: 957   r: 500.65   dz: 497.21   misfit: 1.97e+01
# itreação: 958   r: 500.65   dz: 497.22   misfit: 1.97e+01
# itreação: 959   r: 500.65   dz: 497.22   misfit: 1.97e+01
# itreação: 960   r: 500.65   dz: 497.23   misfit: 1.97e+01
# itreação: 961   r: 500.65   dz: 497.24   misfit: 1.97e+01
# itreação: 962   r: 500.64   dz: 497.24   misfit: 1.97e+01
# itreação: 963   r: 500.64   dz: 497.25   misfit: 1.97e+01
# itreação: 964   r: 500.64   dz: 497.25   misfit: 1.97e+01
# itreação: 965   r: 500.64   dz: 497.26   misfit: 1.97e+01
# itreação: 966   r: 500.64   dz: 497.26   misfit: 1.97e+01
# itreação: 967   r: 500.64   dz: 497.27   misfit: 1.97e+01
# itreação: 968   r: 500.64   dz: 497.28   misfit: 1.97e+01
# itreação: 969   r: 500.63   dz: 497.28   misfit: 1.97e+01
# itreação: 970   r: 500.63   dz: 497.29   misfit: 1.97e+01
# itreação: 971   r: 500.63   dz: 497.29   misfit: 1.97e+01
# itreação: 972   r: 500.63   dz: 497.30   misfit: 1.97e+01
# itreação: 973   r: 500.63   dz: 497.30   misfit: 1.97e+01
# itreação: 974   r: 500.63   dz: 497.31   misfit: 1.97e+01
# itreação: 975   r: 500.63   dz: 497.32   misfit: 1.97e+01
# itreação: 976   r: 500.62   dz: 497.32   misfit: 1.97e+01
# itreação: 977   r: 500.62   dz: 497.33   misfit: 1.97e+01
# itreação: 978   r: 500.62   dz: 497.33   misfit: 1.97e+01
# itreação: 979   r: 500.62   dz: 497.34   misfit: 1.97e+01
# itreação: 980   r: 500.62   dz: 497.34   misfit: 1.97e+01
# itreação: 981   r: 500.62   dz: 497.35   misfit: 1.97e+01
# itreação: 982   r: 500.62   dz: 497.35   misfit: 1.97e+01
# itreação: 983   r: 500.62   dz: 497.36   misfit: 1.97e+01
# itreação: 984   r: 500.61   dz: 497.37   misfit: 1.97e+01
# itreação: 985   r: 500.61   dz: 497.37   misfit: 1.97e+01
# itreação: 986   r: 500.61   dz: 497.38   misfit: 1.97e+01
# itreação: 987   r: 500.61   dz: 497.38   misfit: 1.97e+01
# itreação: 988   r: 500.61   dz: 497.39   misfit: 1.97e+01
# itreação: 989   r: 500.61   dz: 497.39   misfit: 1.97e+01
# itreação: 990   r: 500.61   dz: 497.40   misfit: 1.97e+01
# itreação: 991   r: 500.60   dz: 497.40   misfit: 1.97e+01
# itreação: 992   r: 500.60   dz: 497.41   misfit: 1.97e+01
# itreação: 993   r: 500.60   dz: 497.41   misfit: 1.97e+01
# itreação: 994   r: 500.60   dz: 497.42   misfit: 1.97e+01
# itreação: 995   r: 500.60   dz: 497.42   misfit: 1.97e+01
# itreação: 996   r: 500.60   dz: 497.43   misfit: 1.97e+01
# itreação: 997   r: 500.60   dz: 497.44   misfit: 1.97e+01
# itreação: 998   r: 500.59   dz: 497.44   misfit: 1.97e+01
# itreação: 999   r: 500.59   dz: 497.45   misfit: 1.97e+01

# %% [markdown]
# # Plots de resultados

# %%
res_norm = (res - np.mean(res))/np.std(res)
res_plot = res.reshape(shape)
xp = xp.reshape(shape)
yp = yp.reshape(shape)
dpred = data.reshape(shape)
dobs = data_noise.reshape(shape)

# %%
#plot
plt.figure(figsize=(5,5))
plt.plot(p1_list, p2_list, '.w-', markersize=8, label='Estimado')
plt.plot(r_true, dz_true, 'oy', label='Verdadeiro')
plt.title('SD - Geofisica', fontsize=18)
plt.contourf(r_plot, dz_plot, phi_eq, 40, cmap='jet')
plt.xlabel('$r$', fontsize=18)
plt.ylabel('$dz$', fontsize=18)
plt.colorbar(pad=0.01, aspect=20, shrink=1).set_label('nT', fontsize=18)
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, facecolor='gray', edgecolor='black')
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Convergencia', fontsize = 18)
plt.ylabel('Funcao objetivo', fontsize = 18)
plt.xlabel('Iteracao', fontsize = 18)
plt.plot(phi_list, 'bo-', label='Estimado')

plt.subplot(1, 3, 2)
plt.title('Estimativas de  r', fontsize = 18)
plt.xlabel('Iteracao', fontsize = 18)
plt.ylabel('r', fontsize = 18)
plt.plot(p1_list, 'bo-', label='Estimado')
plt.plot(np.zeros(len(p1_list)) + r_true, 'r-', linewidth=2, label='Verdadeiro')
plt.legend(loc=0, fontsize=15)

plt.subplot(1, 3, 3)
plt.title('Estimativas de  dz', fontsize = 18)
plt.xlabel('Iteracao', fontsize = 18)
plt.ylabel('dz', fontsize = 18)
plt.plot(p2_list, 'bo-', label='Estimado')
plt.plot(np.zeros(len(p1_list)) + dz_true, 'r-', linewidth=2, label='Verdadeiro')
plt.legend(loc=0, fontsize=15)
plt.show()

# %%
# plot
plt.figure(figsize=(20,5))
plt.subplot(1, 3, 1)
plt.title('Dado predito', fontsize=20)
plt.contourf(yp.reshape(shape), xp.reshape(shape), dpred, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 2)
plt.title('Dado observado', fontsize=20)
plt.contourf(yp.reshape(shape), xp.reshape(shape), dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.ax.tick_params(labelsize=13)

plt.subplot(1, 3, 3)
plt.title('SD - ajuste', fontsize=20)
plt.contourf(yp.reshape(shape), xp.reshape(shape), res_plot, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(m)', fontsize=18)
plt.ylabel('$x$(m)', fontsize=18)
clb = plt.colorbar(pad=0.01, aspect=20, shrink=1)
clb.set_label('nT', fontsize=18)
clb.ax.tick_params(labelsize=13)
plt.show()

# %%
plt.plot(figsize=(30,25))
plt.title('Histogram', fontsize = 20)
plt.xlabel('$\mu$ = %.7f  $\sigma$ = %.7f' % (np.mean(res_norm), np.std(res_norm)), fontsize=20)
nbins = int((np.max(res_norm) - np.min(res_norm)))
n, bins, patches = plt.hist(res_norm,bins=nbins, normed=True, color='blue')
gauss = normpdf(bins, np.mean(res_norm), np.std(res_norm))
plt.plot(bins, gauss, 'k--', linewidth=2.)
plt.ylim(0.,0.5)
plt.xlim(-10., 10.)
plt.show()
